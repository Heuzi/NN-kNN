# %% [markdown]
# # NN‑kNN: Regression Sample Notebook
#
# This notebook demonstrates how to use **NN‑kNN** for a regression task.
# It trains on a synthetic dataset and evaluates with RMSE and an observed vs. predicted plot.
#
# **Prereqs:** `nnknn_model.py` should be in the same folder as this notebook.

# %%
import sys
print(sys.executable)
# Out:
# c:\venvs\nnknn311\Scripts\python.exe

# %%
import os, sys
from pathlib import Path
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
from datasets.reg_data import Reg_data, standardize_tensor

# Detect Colab
try:
    import google.colab  # type: ignore
    IN_COLAB = True
except Exception:
    IN_COLAB = False

if IN_COLAB:
    # Assumes drive is already mounted in a previous cell
    PROJECT_ROOT = Path("/content/drive/MyDrive/NN-kNN")
    DATA_ROOT    = Path("/content/datasets")
    CHECKPOINTS  = PROJECT_ROOT / "checkpoints"
    print("Running on Colab.")
else:
    PROJECT_ROOT = Path(os.getcwd())          # notebook's current folder as project root
    DATA_ROOT    = PROJECT_ROOT / "datasets"
    CHECKPOINTS  = PROJECT_ROOT / "checkpoints"
    print("Running locally.")

# Make project importable and set CWD to project root for consistent relative paths
# Add PROJECT_ROOT to sys.path *before* importing from within the project
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
os.chdir(PROJECT_ROOT)


from model.nnknn_model import NN_KNN_Model, train_model, default_args, GlocalFeatureWeight
from model.mlkr import run_mlkr_sklearn

print("PROJECT_ROOT =", PROJECT_ROOT)
print("DATA_ROOT     =", DATA_ROOT)
print("CHECKPOINTS  =", CHECKPOINTS)

# Optional: pick device
try:
    import torch
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device:", device)
except Exception as e:
    print("Torch not available (only matters if you need it):", e)
# Out:
# Running locally.
# PROJECT_ROOT = g:\My Drive\NN-kNN
# DATA_ROOT     = g:\My Drive\NN-kNN\datasets
# CHECKPOINTS  = g:\My Drive\NN-kNN\checkpoints
# Using device: cuda

# %% [markdown]
# # Data Sets

# %% [markdown]
# ## Basic Setup

# %%
import os, random
import numpy as np
import torch

def seed_everything(seed: int = 42, deterministic: bool = True):
    # --- Python / OS ---
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed)

    # --- NumPy ---
    np.random.seed(seed)

    # --- PyTorch (CPU + GPU) ---
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    if deterministic:
        # cuDNN settings (conv nets, etc.)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

        # For Ampere+ GPUs: make matmul deterministic-ish
        # (needed for some ops; safe to set)
        os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

        # Enforce deterministic algorithms (will throw if something is nondeterministic)
        torch.use_deterministic_algorithms(True)

        # Optional: avoid TF32 differences across runs (can change numerics slightly)
        torch.backends.cuda.matmul.allow_tf32 = False
        torch.backends.cudnn.allow_tf32 = False

seed_everything(42, deterministic=True)

# %%
import numpy as np
import matplotlib.pyplot as plt

regime_weights = False

def plot_y_distribution(y, bin_width=0.1, title="y distribution", show_kde=False):
    """
    Plot a histogram of y with fixed bin width (default 0.1).

    Args:
        y: list | np.ndarray | pd.Series | torch.Tensor
        bin_width: float, width of each bin
        title: str
        show_kde: bool, overlay a simple kernel density (optional)
    """
    # to numpy
    try:
        import torch
        if isinstance(y, torch.Tensor):
            y = y.detach().cpu().numpy()
    except Exception:
        pass
    y = np.asarray(y, dtype=float).ravel()
    y = y[~np.isnan(y)]

    # bins
    y_min, y_max = np.min(y), np.max(y)
    # include the rightmost edge
    bins = np.arange(np.floor(y_min/bin_width)*bin_width,
                     np.ceil(y_max/bin_width)*bin_width + bin_width,
                     bin_width)

    # plot
    plt.figure(figsize=(7,4.5))
    counts, edges, _ = plt.hist(y, bins=bins, edgecolor='black', alpha=0.8)
    plt.xlabel("y")
    plt.ylabel("count")
    plt.title(f"{title} (bin={bin_width})")

    # optional KDE (very light, no seaborn)
    if show_kde:
        from scipy.stats import gaussian_kde
        xs = np.linspace(edges[0], edges[-1], 512)
        kde = gaussian_kde(y, bw_method='scott')
        # scale KDE to histogram counts
        plt.plot(xs, kde(xs) * len(y) * bin_width, linewidth=2)

    plt.tight_layout()
    plt.show()
    return counts, edges

# %% [markdown]
# ## Generate a synthetic regression dataset
# Two variants are shown below. Uncomment the one you prefer:
# - Linear with noise
# - Nonlinear (sine) with noise

# %% [markdown]
# ### Linear Regression

# %%
# --- Choose one synthetic dataset ---

N = 3000 # N = 3000
D = 5
torch.manual_seed(42)

# Linear with noise (default)
X = torch.randn(N, D)
true_w = torch.tensor([2.5, -1.7, 0.0, 0.9, 3.2]).view(-1, 1)
rand_scale = 1.0 #1.0 # 0.5
y = X @ true_w + rand_scale*torch.randn(N, 1)  # shape [N,1]

# # Nonlinear (sine) with noise — comment out the linear block above and use this instead
# N = 3000
# X = torch.linspace(-3.0, 3.0, N).unsqueeze(1)
# y = torch.sin(2 * X) + 0.2*torch.randn_like(X)

print(X.shape, y.shape)
#a tensor for the true feature weights
# Out:
# torch.Size([3000, 5]) torch.Size([3000, 1])

# %%
# Use absolute value (or squared) as similarity weights
true_feature_weights = true_w.squeeze().abs()  # shape [D]
# Optionally normalize to sum to 1, so comparable for different artificially generated datasets
true_feature_weights = true_feature_weights / true_feature_weights.sum()

print("True feature weights for similarity:", true_feature_weights)
# Out:
# True feature weights for similarity: tensor([0.3012, 0.2048, 0.0000, 0.1084, 0.3855])

# %% [markdown]
# ### Mixture of two linear models

# %%
import torch

#important flag
regime_weights = True

# --- Config ---
torch.manual_seed(42)
N = 3000         # total samples
D = 4            # number of features
noise_scale = 0.0

# --- Define two different weight vectors (two regimes) ---
# Regime 1: depends on features 0,1,2
w1 = torch.tensor([2.5, -1.5,  0.0, 0.0]).view(D, 1)

# Regime 2: depends on features 3,4,5
w2 = torch.tensor([0.0, 0.0,  -2.0, 1.5 ]).view(D, 1)

# (Optional) store normalized "true feature weights" per regime for later comparison
w1_abs = w1.squeeze().abs()
w2_abs = w2.squeeze().abs()
true_feature_weights_regime1 = w1_abs / w1_abs.sum()
true_feature_weights_regime2 = w2_abs / w2_abs.sum()

true_feature_weights_glocal = torch.stack(
    [true_feature_weights_regime1, true_feature_weights_regime2], dim=0
)  # shape [2, D]
print("True glocal feature weights (regime 1, regime 2):")
print(true_feature_weights_glocal)

# --- Generate X ---
X = torch.randn(N, D)  # standard normal features

# --- Assign each sample to a regime (50/50) ---
regime_labels = torch.zeros(N, dtype=torch.long)
regime_labels[: N // 2] = 0  # first half: regime 1
regime_labels[N // 2 :] = 1  # second half: regime 2

# Randomly permute so they are mixed
perm = torch.randperm(N)
regime_labels = regime_labels[perm]
X = X[perm]

# --- Generate y based on the assigned regime ---
y = torch.zeros(N, 1)

# Regime 1 samples
idx1 = (regime_labels == 0)
X1 = X[idx1]
y[idx1] = X1 @ w1 + noise_scale * torch.randn(X1.size(0), 1)

# Regime 2 samples
idx2 = (regime_labels == 1)
X2 = X[idx2]
y[idx2] = X2 @ w2 + noise_scale * torch.randn(X2.size(0), 1)

print("X shape:", X.shape)
print("y shape:", y.shape)
print("Regime 1 samples:", idx1.sum().item(), "Regime 2 samples:", idx2.sum().item())
# Out:
# True glocal feature weights (regime 1, regime 2):
# tensor([[0.6250, 0.3750, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.5714, 0.4286]])
# X shape: torch.Size([3000, 4])
# y shape: torch.Size([3000, 1])
# Regime 1 samples: 1500 Regime 2 samples: 1500

# %% [markdown]
# ### Redundant Features
#
# x0 is with s1, and x1, x2, are working equally strongly on s2. s1 and s2 are equally strong signal. In my experiment, I will also modify a little the workflow. Stage 1: I will first set both w0 w1 to be 0. Stage 2.1: Then w1 to unfreeze,. Stage 2.2: Then manually set w1 and retrain. Stage 3: from stage 2.2, Then w0 to unfreeze; from stage 2.2, then manually w0 and retrain.

# %% [markdown]
# Goal:
#
# Two independent latent signals,
# 𝑠
# 1
# s
# 1
# 	​
#
#  and
# 𝑠
# 2
# s
# 2
# 	​
#
# , equally strong in
# 𝑦
# y.
#
# x0: good sensor for
# 𝑠
# 1
# s
# 1
# 	​
#
# .
#
# x1, x2: equally strong sensors for
# 𝑠
# 2
# s
# 2
# 	​
#
# .
#
# x3, x4: noise.
#
# So both “axes” (s1 and s2) are equally important for prediction, but which sensors you emphasize is an explanation choice.

# %%
N = 1500
D = 5
torch.manual_seed(42)

# Latent signals
s1 = torch.randn(N, 1)  # first underlying factor
s2 = torch.randn(N, 1)  # second underlying factor

# Sensors:
# x0: good sensor for s1
# x1, x2: equally good sensors for s2
x0 = s1 + 0.05 * torch.randn(N, 1)        # feature 0: s1 + small noise
x1 = s2 + 0.05 * torch.randn(N, 1)        # feature 1: s2 + small noise
x2 = s2 + 0.05 * torch.randn(N, 1)        # feature 2: s2 + small noise (redundant with x1)
# x3 = torch.randn(N, 1)                    # feature 3: pure noise

X = torch.cat([x0, x1, x2], dim=1)   # [N, 4]

# Target: s1 and s2 equally strong in y
rand_scale = 0.1
y = 1.0 * s1 + 1.0 * s2 + rand_scale * torch.randn(N, 1)

print(X.shape, y.shape)

# "Expert" feature weights:
# we eventually want the model to treat x0 as the main s1 sensor,
# and x1/x2 as main s2 sensors, e.g., symmetric on s2.
true_w = torch.tensor([2.0, 1.0, 1.0]).view(-1, 1)

true_feature_weights = true_w.squeeze().abs()
true_feature_weights = true_feature_weights / true_feature_weights.sum()
print("True feature weights for similarity:", true_feature_weights)
# Out:
# torch.Size([1500, 3]) torch.Size([1500, 1])
# True feature weights for similarity: tensor([0.5000, 0.2500, 0.2500])

# %% [markdown]
# ## Split Data

# %%
# Simple manual split (80/20)
n_train = int(0.8 * X.size(0))
indices = torch.randperm(X.size(0))
train_idx, val_idx = indices[:n_train], indices[n_train:]

X_train, y_train = X[train_idx], y[train_idx].squeeze(1)  # y shape [N]
X_val,   y_val   = X[val_idx],   y[val_idx].squeeze(1)

if regime_weights:
    regime_labels_train = regime_labels[train_idx]
    regime_labels_val = regime_labels[val_idx]

print('Train:', X_train.shape, y_train.shape, '| Val:', X_val.shape, y_val.shape)
# Out:
# Train: torch.Size([2400, 5]) torch.Size([2400]) | Val: torch.Size([600, 5]) torch.Size([600])

# %%
# Example:
counts, edges = plot_y_distribution(y, bin_width=0.1)

# %%
y.std()
# Out:
# tensor(4.4950)

# %% [markdown]
# ## Various Reg Data

# %%
dataset_name = 'califonia_housing'  
# dataset_name = 'body_fat'
# dataset_name = 'student_performance'
# dataset_name = 'airfoil'
# dataset_name = 'car'
# dataset_name = 'psych_depression_physical_symptons_reg'

Xs, ys = Reg_data(dataset_name)   # Xs, ys are already standardized

print(Xs.shape, ys.shape)
print("y mean:", ys.mean().item(), "y std:", ys.std().item())
print("Raw y min/max:", ys.min().item(), ys.max().item())
# Out:
# torch.Size([20640, 8]) torch.Size([20640])
# y mean: 2.0685579776763916 y std: 1.1539561748504639
# Raw y min/max: 0.1499900072813034 5.000010013580322

# %%
# for dataset "psych_depression_physical_symptons"
columns = ['1. Most of the time I have difficulty concentrating on simple tasks', "2. I don't feel like doing my daily duties", '3. My friends or family have told me that I look different', '4. When I think about the future it is difficult for me to imagine it clearly', '5. People around me often ask me how I feel', '6. I consider that my life is full of good things', '7. My hobbies are still important to me', "8. I'm still as punctual as I have always been", '9. If I had the chance, I would spend all day in my bed', '10. I have found that I can spend a lot of time scrolling the screen \nof my cell phone without searching or stopping at anything in particular', '11. When someone asks me something, I have noticed that I take longer than normal to\nrespond', '12. I have noticed my body shaken without any cause', '13. I felt more encouraged to do my daily activities before', "14. Sometimes I wake up sad and I can't explain why", '15. In recent months I usually reproach myself for things from the past', '16. I think my thoughts are strange or different from before', '17. I feel guilty about the decisions that I have made', "18. I don't feel as comfortable with my body as I did before", "19. I don't feel successful compared to others", '20. It is difficult for me to make decisions even if they are simple', "21. I'm capable of achieving what I propose to myself", '22. It is not difficult for me to understand something the first time', '23. I have thought more than before about what my death would be like', '24. Being dead seems to be a solution to some problems', '25. I would rather stay home than go out with my friends', '26. I like to attend family gatherings', '27. I feel excited when thinking about my life project', '28. The decisions I have made so far have been the right ones', '29. I am able to carry out my activities as I have always been', '30. I like to be in touch with my friends and family through social media', '31. It is easy for me to choose a photograph of myself to show it on social media', '32. I am proud of what I have achieved so far', '33. I have trouble remembering things easily', '34. In recent months I have had discussions with my schoolmates or colleagues', '35. I constantly imagine that something will go wrong at my work or at school', '36. I am afraid of being worng when doing my homework', "37. I'm not too worried about what might happen in a few weeks", "38. Lately it's hard for me to calm down", '39. Everything will be alright', '40. I can easily blank my mind', '41. I am bothered by insignificant things that were not important before', '42. I find it uncomfortable to be in a crowded place', '43. Sometimes i feel trapped', '44. I am easily frightened by unexpected noises', '45. I have difficulties to do one task at a time', '46. I have the feeling that I am forgetting to do something', '47. I can clearly express to others how I feel', '48. I can sleep easily', '49. I enjoy every moment of the day', '50. I imagine that at any moment a disaster of the\nnature may occur', '51. Sometimes I feel like I get tired easily', '52. Being locked in an elevator would be the worst thing that could happen to me', "53. I'm bothered by people walking slowly in front of me ", "54. I don't usually get upset if something doesn't go as expected", '55. Sometimes it is as if some conversations with friends or family become\ninterrogations', '56. I manage my schedule as I always have', '57. It bothers me to feel that people on the street approach me', '58. I have no difficulty understanding what people explain to me', '59. I consider that I am good at controlling my emotions', '60. In new situations I feel calm and encouraged', '61. Sometimes I forget what I wanted to say because I have several thoughts at the same time', '62. I would like to know what will happen in the future', '63. When I get angry I can easily explode', '64. I can put down my cell phone and dedicate myself to reading without distractions', '65. I worry that people will not understand what I mean.', '66. Sometimes I do not listen to what people say to me because I am thinking about other things', '67. I get angry easily', "68. I'm afraid that something bad could happen to me", '69. It is not important for me to meet set dates', '70. I like to think clearly before giving my opinion', '71. I use lies just to get out of certain problems', '72. If I have the opportunity to get in line to avoid wasting time, I do it', '73. I have difficulty making elaborate plans', '74. People have problems because of themselves', '75. No me parece importante lo que los otros piensen sobre mí', '76. Laws are not as important as others think', '77. I would regret betraying a friend', '78. I prefer that a negotiation supports the largest possible number of people involved', '79. It is easy for me to work in a team', '80. It is important to help people when they need it', '81. I have punched someone or thought of doing it', '82. If it was necessary I would pretend to be someone else to get something', '83. I consider it important to ensure my physical safety and that of those around me', '84. After an argument I usually go over what happened in my head', '85. I have a hard time controlling myself when I get angry', '86. Loyalty is important', "87. If I can help a person I will stop what I'm doing to help him", '88', '89. It makes me laugh when my superiors at school or at work demand something', '90. Deceiving people is not wrong if it is to achieve something important', '91. I like to greet my neighbors', '92. It does not seem serious to me to have some debts', '93. People steal because they have needs', '94. I lose control easily', "95. Neighbors must put up with each other's noises without complaining", '96. Littering on public roads is wrong', '97. People who commit crimes have their reasons for doing it', '98. It is normal to change jobs several times a year', '99. It is important to respect turns', '100. I could pretend to be someone else to achieve what I want', '101. I consider it important that all people have the same rights', '102. I have a hard time taking  "no" for an answer']

# %%
counts, edges = plot_y_distribution(ys, bin_width=0.1)

# %%
X = Xs
y = ys
# Simple manual split (80/20)
n_train = int(0.8 * X.size(0))
indices = torch.randperm(X.size(0))
train_idx, val_idx = indices[:n_train], indices[n_train:]

X_train, y_train = X[train_idx], y[train_idx]  # y shape [N]
X_val,   y_val   = X[val_idx],   y[val_idx]

print('Train:', X_train.shape, y_train.shape, '| Val:', X_val.shape, y_val.shape)
# Out:
# Train: torch.Size([16512, 8]) torch.Size([16512]) | Val: torch.Size([4128, 8]) torch.Size([4128])

# %% [markdown]
# ## Standardize Data

# %%
X_train_raw, X_val_raw = X_train.clone(), X_val.clone()
y_train_raw, y_val_raw = y_train.clone(), y_val.clone()
y_mean_raw = y_train_raw.mean().item()
y_std_raw  = y_train_raw.std().item()

# X: per-feature z-score using TRAIN stats only (overwrite)
X_train, X_mean, X_std = standardize_tensor(X_train, dim=0, return_stats=True)
X_val = standardize_tensor(X_val, dim=0, mean=X_mean, std=X_std)

# y: scalar z-score using TRAIN stats only (overwrite)
y_train, y_mean, y_std = standardize_tensor(y_train.view(-1, 1), dim=0, return_stats=True)
y_train = y_train.view(-1)
y_val = standardize_tensor(y_val.view(-1, 1), dim=0, mean=y_mean, std=y_std).view(-1)

# --- Aliases to keep older cells working ---
X_train_z, X_val_z = X_train, X_val
y_train_z, y_val_z = y_train, y_val
y_train_norm, y_val_norm = y_train, y_val

# --- Sanity checks (should be ~0 mean, ~1 std) ---
print("X_train mean abs (avg):", X_train.mean(0).abs().mean().item())
print("X_train std  (min/mean/max):",
      X_train.std(0).min().item(), X_train.std(0).mean().item(), X_train.std(0).max().item())
print("y_train mean/std:", y_train.mean().item(), y_train.std().item())
# Out:
# X_train mean abs (avg): 2.6035161226900527e-07
# X_train std  (min/mean/max): 0.9999999403953552 1.0 1.0
# y_train mean/std: 9.35654309586198e-09 1.0

# %% [markdown]
# # Model Code

# %% [markdown]
# ## Configure NN‑kNN for regression

# %%
cfg = {
    **default_args,
    "task_type": "regression",

    "case_score_mode": "bias_minus_distance",  
    # "hard_knn",      # start here (closest to KNN)
    # other options you can try:
    # "bias_minus_distance"
    # "neg_distance_logw"
    # "sigmoid"                (your old style, if you want it back)
    # "hard_knn"               (uniform KNN weights)

    "softmax_over_cases": True,      # model enforces True in regression; kept explicit for clarity
    "tau": 1.0,                      # attention sharpness over cases, lower -> sharper
    "case_normalizer": "softmax",  # 'softmax' | 'sparsemax' | 'entmax15'
    # "case_norm_warmup_epochs": 0,       # 50–200 is a good sweep， 0 if no warm-up
    # "case_norm_warmup_type": "softmax",   # warm-up normalizer
    
    #for locality regularization in regression
    "regression_locality": True,  # Whether to use locality regularization in regression training
    "lambda_base": 1.0,
    # "lambda_kl": 0.0,        # weight for KL(p||w) attention-to-label proximity (regression only)
    "locality_alpha" : 2.0,    # exponent for distance in locality regularization
    "lambda_expdist": 0.1,   #1.0, weight for expected distance loss (regression only)
    # "lambda_balance": 0.0,    # weight for signed-bias regularizer (regression only)
    # "lambda_cover": 0.0,     #0.5, weight for coverage loss (regression
    # "lambda_pair": 0.0,      #0.5, weight for pos>neg pairwise hinge (regression only)
    # "lambda_ent": 0.0,  # 0.0,      #1e-3, tiny entropy penalty (encourages sparse attention tails)
    # "eps_sigma_multiplier": 0.1, #0.2,0.4 multiplier for sigma_y to define "close" and "far" in pairwise loss
    # "pairwise_margin": 0.05, # required gap: w_pos - w_neg >= margin

    # "locality_warmup_epochs": 0,   # epochs with locality off
    # "locality_ramp_epochs": 0,   # linearly ramp to full strength
    # "locality_schedule": "linear",  # (only linear implemented below)

    # "pre_topk_mask": False,   # enable the pre-normalization K-sparsification, if turned on, this influences nn-cdh to only adapt to top_k neighbors
    # "top_k": 40,         # K for Neighbor Agreement / nDCG in validation and also for explanation mode

    ## NEW
    # "bias_manual_set": True,
    # "bias_manual_value": 0.0,
    # #loss in the main training loop
    # "lambda_case_bias": 1e-3, #1e-3,    # weight for L2 regularization on case bias terms

    # "glocal_fw_set_num": 1, #1
    # "neg_weight_flag": False,        # regression should NOT use negative class weights
    # "sampling_cases_flag": False,    # use all cases for stable regression
    # "case_activation_by_top_k_average": True,  # use percentile-based bias finder
    # "top_k_for_default_case_activation": 20, #mark.
    # "case_activation_default_percentage": 0.1,
    "training_epochs": 7000,
    "batch_size": 64,
    "feature_extractor_lr": 1e-3, #1e-3,1e-4,1e-3,
    "glocal_weightor_lr": 1e-3, #1e-3,5e-4, 1e-3, influence feature weights and glocal weights
    "case_net_lr": 3e-4, #3e-4,1e-4,1e-5,
    "checkpoint_path": "nnknn_regression_best.pth",
    "patience": 80,

    #default feature extractor
    "post_mlp_enabled": False,
    # "post_mlp_dims": (64, 32),
    # "post_mlp_dropout": 0.1,
    # "post_mlp_activation": "relu",

    #Turn them all True or False to turn on/off nn_cdh adaptation
    "nn_cdh_pretrain": True,  # Whether to pretrain nn_cdh adapter
    "use_nn_cdh": True,
    "cdh_aggregate": True,  # "weighted_sum" | "attention"

    "explanation_mode": True
}

# No feature extractor for tabular demo
feature_extractor = None

# %% [markdown]
# ## Redundant Features: Alternative Train: Feature Injection Experiment

# %%
alternative_training_for_feature_injection_exp = False

# %%
# if alternative_training_for_feature_injection_exp:
#     cfg = {
#         **default_args,
#         "task_type": "regression",
#         "softmax_over_cases": True,      # model enforces True in regression; kept explicit for clarity
#         "tau": 1.0,                      # attention sharpness over cases, lower -> sharper
#         "case_normalizer": "sparsemax", #"sparsemax",  # 'softmax' | 'sparsemax' | 'entmax15'

#         ###NEWLY ADDED###!!!!
#         "post_mlp_enabled": False,
#         "post_mlp_dims": (32, 16),
#         "post_mlp_dropout": 0.1,
#         "post_mlp_activation": "relu",

#         #loss in the main training loop
#         "lambda_case_bias": 1e-3,    # weight for L2 regularization on case bias terms

#         #for locality regularization in regression
#         "regression_locality": True,  # Whether to use locality regularization in regression training
#         "lambda_base": 1.0,
#         "lambda_kl": 0.0,        # weight for KL(p||w) attention-to-label proximity (regression only)
#         "locality_alpha" : 2.0,    # exponent for distance in locality regularization
#         "lambda_expdist": 0.3,   #1.0, weight for expected distance loss (regression only)
#         "lambda_balance": 0.3,    # weight for signed-bias regularizer (regression only)
#         "lambda_cover": 0.0,     #0.5, weight for coverage loss (regression
#         "lambda_pair": 0.0,      #0.5, weight for pos>neg pairwise hinge (regression only)
#         "lambda_ent": 1e-3,  # 0.0,      #1e-3, tiny entropy penalty (encourages sparse attention tails)
#         "eps_sigma_multiplier": 0.1, #0.2,0.4 multiplier for sigma_y to define "close" and "far" in pairwise loss
#         "pairwise_margin": 0.05, # required gap: w_pos - w_neg >= margin

#         "pre_topk_mask": False,   # enable the pre-normalization K-sparsification, if turned on, this influences nn-cdh to only adapt to top_k neighbors
#         "top_k": 20,         # K for Neighbor Agreement / nDCG in validation and also for explanation mode

#         "glocal_fw_set_num": 1, #1
#         "neg_weight_flag": False,        # regression should NOT use negative class weights
#         "sampling_cases_flag": False,    # use all cases for stable regression

#         "case_activation_by_top_k_average": False,  # use percentile-based bias finder
#         "top_k_for_default_case_activation": 10, #mark.
#         "case_activation_default_percentage": 0.1,
#         "training_epochs": 800,
#         "batch_size": 64,
#         "feature_extractor_lr": 1e-4, #1e-4,1e-3,
#         "glocal_weightor_lr": 5e-4, #1e-3, influence feature weights and glocal weights
#         "case_net_lr": 1e-4, #1e-4,1e-3,
#         "checkpoint_path": "nnknn_regression_best.pth",
#         "patience": 40,

#         "nn_cdh_pretrain": False,  # Whether to pretrain nn_cdh adapter
#         "use_nn_cdh": False,

#         "explanation_mode": True
#     }

#     # No feature extractor for tabular demo
#     feature_extractor = None
#     # y_mean = y_train.mean()
#     # y_std = y_train.std().clamp(min=1e-6)
#     # y_train_norm = (y_train - y_mean) / y_std
#     # y_val_norm   = (y_val   - y_mean) / y_std
#     y_train_norm = y_train
#     y_val_norm   = y_val

# %%
if alternative_training_for_feature_injection_exp:
    ## ============================================================
    ## Feature Injection Experiment (A, B.1, B.2, C.1, C.2) with normalized y
    ## ============================================================

    import copy
    import torch
    import torch.nn as nn
    import torch.nn.functional as F
    from torch.utils.data import TensorDataset, DataLoader

    # --- Use normalized y, consistent with main training ---
    X_train_dev = X_train.to(device)
    X_val_dev   = X_val.to(device)
    y_train_dev = y_train_norm.to(device)
    y_val_dev   = y_val_norm.to(device)

    D = X_train_dev.shape[1]
    assert true_feature_weights.shape[0] == D, "Dim mismatch between true_feature_weights and X."

    # Make a cfg copy for this experiment; turn off NN-CDH (keep locality as in cfg)
    cfg_inj = {**cfg}
    cfg_inj["use_nn_cdh"] = False  # keep NN-CDH out of this toy experiment
    cfg_inj["regression_locality"] = False  #ablation, model is easier to learn

    batch_size = cfg_inj.get("batch_size", 256)
    criterion  = nn.MSELoss()

    train_loader = DataLoader(
        TensorDataset(X_train_dev, y_train_dev),
        batch_size=batch_size,
        shuffle=True
    )
    val_loader = DataLoader(
        TensorDataset(X_val_dev, y_val_dev),
        batch_size=batch_size,
        shuffle=False
    )

    def make_model_with_glocal(glocal_weightor, cfg_local):
        """
        Build an NN_KNN_Model for regression with given glocal_weightor.
        Uses normalized y, no NN-CDH (adapter=None).
        """
        ys = y_train_dev.float().unsqueeze(1)  # [N, 1]
        model = NN_KNN_Model(
            X_train_dev, ys,
            feature_extractor=feature_extractor,
            glocal_weightor=glocal_weightor,
            nn_cdh=None,
            **cfg_local
        ).to(device)
        return model

    def build_optimizer_like_train_model(model, glocal_weightor, feature_extractor, adapter, cfg_local):
        """
        Build an Adam optimizer with the same parameter grouping / LRs
        as in train_model.
        """
        # Separate parameters for different learning rates
        feature_extractor_params = []
        if feature_extractor is not None:
            feature_extractor_params = list(feature_extractor.parameters())

        glocal_weightor_params = []
        if glocal_weightor is not None:
            glocal_weightor_params = list(glocal_weightor.parameters())

        adapter_params = []
        if adapter is not None:
            adapter_params = list(adapter.parameters())

        shared_ids = {id(p) for p in (feature_extractor_params + glocal_weightor_params + adapter_params)}
        case_net_params = [p for p in model.parameters() if id(p) not in shared_ids]

        fe_lr       = cfg_local.get("feature_extractor_lr", default_args["feature_extractor_lr"])
        glocal_lr   = cfg_local.get("glocal_weightor_lr",  default_args["glocal_weightor_lr"])
        adapter_lr  = cfg_local.get("adapter_lr",          default_args["adapter_lr"])
        case_net_lr = cfg_local.get("case_net_lr",         default_args["case_net_lr"])

        optimizer = torch.optim.Adam([
            {'params': feature_extractor_params, 'lr': fe_lr},
            {'params': glocal_weightor_params,   'lr': glocal_lr},
            {'params': adapter_params,           'lr': adapter_lr},
            {'params': case_net_params,          'lr': case_net_lr},
        ], weight_decay=1e-5)

        return optimizer

    def train_phase(model, optimizer, num_epochs, frozen_feature_idxs=None):
        """
        Train for num_epochs; optionally freeze a list of feature indices
        in glocal_weightor.feature_weights by zeroing their gradients.
        """
        if frozen_feature_idxs is None:
            frozen_feature_idxs = []
        for epoch in range(num_epochs):
            model.train()
            for xb, yb in train_loader:
                xb, yb = xb.to(device), yb.to(device)
                optimizer.zero_grad()
                final_predictions, predicted_solution, pre_adapted_solution, topk_cases, topk_labels, topk_acts = model(xb)
                loss = criterion(final_predictions.squeeze(1), yb.float())
                loss.backward()
                if frozen_feature_idxs:
                    with torch.no_grad():
                        if model.glocal_weightor.feature_weights.grad is not None:
                            for j in frozen_feature_idxs:
                                model.glocal_weightor.feature_weights.grad[:, j] = 0.0
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.5)
                optimizer.step()

    def eval_model(model):
        model.eval()
        preds = []
        with torch.no_grad():
            for xb, yb in val_loader:
                xb = xb.to(device)
                final_predictions, predicted_solution, pre_adapted_solution, topk_cases, topk_labels, topk_acts = model(xb)
                preds.append(final_predictions.detach().cpu().view(-1))
        preds = torch.cat(preds, dim=0)
        y = y_val_dev.cpu().view(-1)
        mse = F.mse_loss(preds, y).item()
        ss_res = torch.sum((y - preds) ** 2).item()
        ss_tot = torch.sum((y - y.mean()) ** 2).item()
        r2 = 1.0 - ss_res / ss_tot
        return mse, r2

    def print_feature_weights(prefix, model):
        w = model.glocal_weightor.feature_weights.detach().cpu().view(-1)
        print(f"{prefix} glocal feature weights:", w.numpy())

    glocal_fw_set_num = cfg_inj.get("glocal_fw_set_num", 1)

    # =========================================
    # Stage A: mis-specified prior (w0 = w1 = 0), both frozen
    # =========================================
    print("\n=== Feature Injection: Stage A (w0 = w1 = 0, both frozen) ===")

    glocal_A = GlocalFeatureWeight(feature_dim=D, set_num=glocal_fw_set_num).to(device)

    with torch.no_grad():
        # Start from true_feature_weights but set w0 and w1 to 0
        # w_init = true_feature_weights.to(device).clone()
        # w_init[0] = 0.0
        # w_init[1] = 0.0
        glocal_A.feature_weights.data[0][0] = 0.0
        glocal_A.feature_weights.data[0][1] = 0.0

    model_A = make_model_with_glocal(glocal_A, cfg_inj)
    optimizer_A = build_optimizer_like_train_model(
        model=model_A,
        glocal_weightor=glocal_A,
        feature_extractor=feature_extractor,
        adapter=None,
        cfg_local=cfg_inj
    )

    print_feature_weights("Initial (A)", model_A)
    # Freeze both feature 0 and 1
    train_phase(model_A, optimizer_A, num_epochs=80, frozen_feature_idxs=[0, 1])
    print_feature_weights("After training (A)", model_A)
    mse_A, r2_A = eval_model(model_A)
    print(f"Stage A   - Val MSE: {mse_A:.4f} | Val R²: {r2_A:.4f}")

    # Save checkpoint after A so B.1/B.2 start from the same point
    state_A = copy.deepcopy(model_A.state_dict())

    # Post-hoc fine-tuning budget
    E_extra = 20  # adjust as needed (smaller = clearer injection effect)

    # =========================================
    # Stage B.1: from A, unfreeze w1 (w0 still frozen), no manual edit
    # =========================================
    print("\n=== Feature Injection: Stage B.1 (unfreeze w1, w0 frozen, no manual edit) ===")

    # temporary glocal, will be overwritten by state_A
    glocal_B1 = GlocalFeatureWeight(feature_dim=D, set_num=glocal_fw_set_num).to(device)
    model_B1 = make_model_with_glocal(glocal_B1, cfg_inj)
    model_B1.load_state_dict(state_A)

    optimizer_B1 = build_optimizer_like_train_model(
        model=model_B1,
        glocal_weightor=glocal_B1,
        feature_extractor=feature_extractor,
        adapter=None,
        cfg_local=cfg_inj
    )

    print_feature_weights("Start (B.1)", model_B1)
    # Only freeze w0; w1 now learns
    train_phase(model_B1, optimizer_B1, num_epochs=E_extra, frozen_feature_idxs=[0])
    print_feature_weights("After training (B.1)", model_B1)
    mse_B1, r2_B1 = eval_model(model_B1)
    print(f"Stage B.1 - Val MSE: {mse_B1:.4f} | Val R²: {r2_B1:.4f}")

    # =========================================
    # Stage B.2: from A, manual edit w1 toward true weights, then unfreeze w1 (w0 frozen)
    # =========================================
    print("\n=== Feature Injection: Stage B.2 (manual edit w1 toward true weights + retrain, w0 frozen) ===")

    glocal_B2 = GlocalFeatureWeight(feature_dim=D, set_num=glocal_fw_set_num).to(device)
    model_B2 = make_model_with_glocal(glocal_B2, cfg_inj)
    model_B2.load_state_dict(state_A)

    print_feature_weights("Start (B.2, pre-edit)", model_B2)
    with torch.no_grad():
        w     = model_B2.glocal_weightor.feature_weights.data[0]
        w_tgt = true_feature_weights.to(device)

        # How strongly to move toward our desired values
        alpha_up   = 0.7  # for pushing w1 up
        alpha_down = 0.7  # for pushing w2 down

        # 1) Push w1 toward its "expert" value (favor x1 as main s2 sensor)
        w[1] = (1 - alpha_up) * w[1] + alpha_up * w_tgt[1]

        # 2) Push w2 toward a *smaller* value (discourage relying on x2)
        #    e.g., some fraction of its expert weight, or even close to 0
        desired_w2 = 0.3 * w_tgt[2]   # make x2 clearly less important than x1
        w[2] = (1 - alpha_down) * w[2] + alpha_down * desired_w2

        # 3) Ensure w2 is strictly lower than w1 (just in case)
        if w[2] >= w[1]:
            w[2] = 0.5 * w[1]

        model_B2.glocal_weightor.feature_weights.data[0] = w
        print("Manually nudged w1 up and w2 down:", w.cpu().numpy())

    print_feature_weights("After manual edit (B.2)", model_B2)

    optimizer_B2 = build_optimizer_like_train_model(
        model=model_B2,
        glocal_weightor=glocal_B2,
        feature_extractor=feature_extractor,
        adapter=None,
        cfg_local=cfg_inj
    )

    # Freeze w0, let w1 (and others) adapt
    train_phase(model_B2, optimizer_B2, num_epochs=E_extra, frozen_feature_idxs=[0])
    print_feature_weights("After training (B.2)", model_B2)
    mse_B2, r2_B2 = eval_model(model_B2)
    print(f"Stage B.2 - Val MSE: {mse_B2:.4f} | Val R²: {r2_B2:.4f}")

    # Save checkpoint after B.2 to start C.1 / C.2 from the same s2 configuration
    state_B2 = copy.deepcopy(model_B2.state_dict())

    # =========================================
    # Stage C.1: from B.2, unfreeze w0 (no manual edit on w0)
    # =========================================
    print("\n=== Feature Injection: Stage C.1 (from B.2, unfreeze w0, no manual edit) ===")

    glocal_C1 = GlocalFeatureWeight(feature_dim=D, set_num=glocal_fw_set_num).to(device)
    model_C1 = make_model_with_glocal(glocal_C1, cfg_inj)
    model_C1.load_state_dict(state_B2)

    optimizer_C1 = build_optimizer_like_train_model(
        model=model_C1,
        glocal_weightor=glocal_C1,
        feature_extractor=feature_extractor,
        adapter=None,
        cfg_local=cfg_inj
    )

    print_feature_weights("Start (C.1)", model_C1)
    # Now no frozen indices: both w0 and w1 can adapt
    train_phase(model_C1, optimizer_C1, num_epochs=E_extra, frozen_feature_idxs=[])
    print_feature_weights("After training (C.1)", model_C1)
    mse_C1, r2_C1 = eval_model(model_C1)
    print(f"Stage C.1 - Val MSE: {mse_C1:.4f} | Val R²: {r2_C1:.4f}")

    # =========================================
    # Stage C.2: from B.2, manual edit w0 toward true weights, then unfreeze w0
    # =========================================
    print("\n=== Feature Injection: Stage C.2 (from B.2, manual edit w0 toward true weights + retrain) ===")

    glocal_C2 = GlocalFeatureWeight(feature_dim=D, set_num=glocal_fw_set_num).to(device)
    model_C2 = make_model_with_glocal(glocal_C2, cfg_inj)
    model_C2.load_state_dict(state_B2)

    print_feature_weights("Start (C.2, pre-edit)", model_C2)
    with torch.no_grad():
        w       = model_C2.glocal_weightor.feature_weights.data[0]
        w_tgt   = true_feature_weights.to(device)
        alpha   = 0.7
        w[0]    = (1 - alpha) * w[0] + alpha * w_tgt[0]
        model_C2.glocal_weightor.feature_weights.data[0] = w
        print("Manually nudged w0 toward true weight.", w.cpu().numpy())
    print_feature_weights("After manual edit (C.2)", model_C2)

    optimizer_C2 = build_optimizer_like_train_model(
        model=model_C2,
        glocal_weightor=glocal_C2,
        feature_extractor=feature_extractor,
        adapter=None,
        cfg_local=cfg_inj
    )

    train_phase(model_C2, optimizer_C2, num_epochs=E_extra, frozen_feature_idxs=[])
    print_feature_weights("After training (C.2)", model_C2)
    mse_C2, r2_C2 = eval_model(model_C2)
    print(f"Stage C.2 - Val MSE: {mse_C2:.4f} | Val R²: {r2_C2:.4f}")

    print("\n=== Feature Injection Summary (normalized y) ===")
    print("Lower MSE / higher R² is better.")
    print(f"A    : MSE={mse_A:.4f}  | R²={r2_A:.4f}")
    print(f"B.1  : MSE={mse_B1:.4f} | R²={r2_B1:.4f}")
    print(f"B.2  : MSE={mse_B2:.4f} | R²={r2_B2:.4f}")
    print(f"C.1  : MSE={mse_C1:.4f} | R²={r2_C1:.4f}")
    print(f"C.2  : MSE={mse_C2:.4f} | R²={r2_C2:.4f}")
# Out:
# === Feature Injection: Stage A (w0 = w1 = 0, both frozen) ===
# cases trainable: False
# labels trainable: False
# Enforcing softmax_over_cases = True for regression task.
# Initial (A) glocal feature weights: [0. 0. 1.]
# After training (A) glocal feature weights: [0.         0.         0.31237462]
# Stage A   - Val MSE: 0.5285 | Val R²: 0.4814
#
# === Feature Injection: Stage B.1 (unfreeze w1, w0 frozen, no manual edit) ===
# cases trainable: False
# labels trainable: False
# Enforcing softmax_over_cases = True for regression task.
# Start (B.1) glocal feature weights: [0.         0.         0.31237462]
# After training (B.1) glocal feature weights: [ 0.         -0.00045897  0.3184318 ]
# Stage B.1 - Val MSE: 0.5290 | Val R²: 0.4809
#
# === Feature Injection: Stage B.2 (manual edit w1 toward true weights + retrain, w0 frozen) ===
# cases trainable: False
# labels trainable: False
# Enforcing softmax_over_cases = True for regression task.
# Start (B.2, pre-edit) glocal feature weights: [0.         0.         0.31237462]
# Manually nudged w1 up and w2 down: [0.        0.175     0.1462124]
# After manual edit (B.2) glocal feature weights: [0.        0.175     0.1462124]
# After training (B.2) glocal feature weights: [0.         0.11742885 0.21331751]
# Stage B.2 - Val MSE: 0.5361 | Val R²: 0.4740
#
# === Feature Injection: Stage C.1 (from B.2, unfreeze w0, no manual edit) ===
# cases trainable: False
# labels trainable: False
# Enforcing softmax_over_cases = True for regression task.
# Start (C.1) glocal feature weights: [0.         0.11742885 0.21331751]
# After training (C.1) glocal feature weights: [0.10072634 0.0550006  0.05680293]
# Stage C.1 - Val MSE: 0.0096 | Val R²: 0.9906
#
# === Feature Injection: Stage C.2 (from B.2, manual edit w0 toward true weights + retrain) ===
# cases trainable: False
# labels trainable: False
# Enforcing softmax_over_cases = True for regression task.
# Start (C.2, pre-edit) glocal feature weights: [0.         0.11742885 0.21331751]
# Manually nudged w0 toward true weight. [0.35       0.11742885 0.21331751]
# After manual edit (C.2) glocal feature weights: [0.35       0.11742885 0.21331751]
# After training (C.2) glocal feature weights: [0.42455345 0.16923977 0.18667679]
# Stage C.2 - Val MSE: 0.0092 | Val R²: 0.9909
#
# === Feature Injection Summary (normalized y) ===
# Lower MSE / higher R² is better.
# A    : MSE=0.5285  | R²=0.4814
# B.1  : MSE=0.5290 | R²=0.4809
# B.2  : MSE=0.5361 | R²=0.4740
# C.1  : MSE=0.0096 | R²=0.9906
# C.2  : MSE=0.0092 | R²=0.9909

# %% [markdown]
# ## Train

# %%
if regime_weights:
    cfg["glocal_init_from_true"] = False
    cfg["glocal_init_alpha"] = 1.0   # for a stronger nudge; adjust 0–1
    # After you define true_feature_weights_glocal for the two-regime dataset
    cfg["true_feature_weights_glocal"] = true_feature_weights_glocal  # [S_true, D]

    # (Optional) if you also run single-regime experiments in the same notebook:
    # cfg["true_feature_weights"] = true_feature_weights  # [D], if you have it

# %%
#already standardized y
# y_mean = y_train.mean()
# y_std = y_train.std().clamp(min=1e-6)
y_train_norm = y_train # (y_train - y_mean) / y_std
y_val_norm   = y_val   # (y_val   - y_mean) / y_std

# %%
#train with normalized y
best_acc, glocal_weightor, model = train_model(
    X_train, y_train_norm, X_val, y_val_norm,
    feature_extractor=feature_extractor,
    cfg=cfg
)

print('Best (R^2 proxy in logs).')
# Out:
# [NN-CDH-AGG] Epoch    1 train_loss=1.433506 val_loss=0.757668
# [NN-CDH-AGG] Epoch    2 train_loss=0.641391 val_loss=0.593557
# [NN-CDH-AGG] Epoch    3 train_loss=0.572848 val_loss=0.555317
# [NN-CDH-AGG] Epoch    4 train_loss=0.545038 val_loss=0.534629
# [NN-CDH-AGG] Epoch    5 train_loss=0.528906 val_loss=0.523220
# [NN-CDH-AGG] Epoch    6 train_loss=0.519968 val_loss=0.515709
# [NN-CDH-AGG] Epoch    7 train_loss=0.515224 val_loss=0.511955
# [NN-CDH-AGG] Epoch    8 train_loss=0.512274 val_loss=0.509337
# [NN-CDH-AGG] Epoch    9 train_loss=0.510152 val_loss=0.507754
# [NN-CDH-AGG] Epoch   10 train_loss=0.508453 val_loss=0.506356
# [NN-CDH-AGG] Epoch   11 train_loss=0.506874 val_loss=0.505068
# [NN-CDH-AGG] Epoch   12 train_loss=0.505541 val_loss=0.503632
# [NN-CDH-AGG] Epoch   13 train_loss=0.504372 val_loss=0.503282
# [NN-CDH-AGG] Epoch   14 train_loss=0.503145 val_loss=0.501679
# [NN-CDH-AGG] Epoch   15 train_loss=0.502022 val_loss=0.500572
# [NN-CDH-AGG] Epoch   16 train_loss=0.500777 val_loss=0.500167
# [NN-CDH-AGG] Epoch   17 train_loss=0.499449 val_loss=0.500124
# [NN-CDH-AGG] Epoch   18 train_loss=0.498155 val_loss=0.498419
# [NN-CDH-AGG] Epoch   19 train_loss=0.496845 val_loss=0.497285
# [NN-CDH-AGG] Epoch   20 train_loss=0.495408 val_loss=0.495888
# [NN-CDH-AGG] Epoch   21 train_loss=0.494286 val_loss=0.494314
# [NN-CDH-AGG] Epoch   22 train_loss=0.492974 val_loss=0.493803
# [NN-CDH-AGG] Epoch   23 train_loss=0.491638 val_loss=0.492662
# [NN-CDH-AGG] Epoch   24 train_loss=0.490478 val_loss=0.491698
# [NN-CDH-AGG] Epoch   25 train_loss=0.489422 val_loss=0.490368
# [NN-CDH-AGG] Epoch   26 train_loss=0.488308 val_loss=0.489316
# [NN-CDH-AGG] Epoch   27 train_loss=0.486822 val_loss=0.488890
# [NN-CDH-AGG] Epoch   28 train_loss=0.485646 val_loss=0.487484
# [NN-CDH-AGG] Epoch   29 train_loss=0.484133 val_loss=0.486367
# [NN-CDH-AGG] Epoch   30 train_loss=0.482776 val_loss=0.484863
# [NN-CDH-AGG] Epoch   31 train_loss=0.481356 val_loss=0.483262
# [NN-CDH-AGG] Epoch   32 train_loss=0.479819 val_loss=0.482666
# [NN-CDH-AGG] Epoch   33 train_loss=0.478432 val_loss=0.480573
# [NN-CDH-AGG] Epoch   34 train_loss=0.476824 val_loss=0.479239
# [NN-CDH-AGG] Epoch   35 train_loss=0.475366 val_loss=0.477789
# [NN-CDH-AGG] Epoch   36 train_loss=0.473872 val_loss=0.475509
# [NN-CDH-AGG] Epoch   37 train_loss=0.472376 val_loss=0.474130
# [NN-CDH-AGG] Epoch   38 train_loss=0.470765 val_loss=0.472931
# [NN-CDH-AGG] Epoch   39 train_loss=0.469045 val_loss=0.471939
# [NN-CDH-AGG] Epoch   40 train_loss=0.467329 val_loss=0.469834
# [NN-CDH-AGG] Epoch   41 train_loss=0.465679 val_loss=0.467676
# [NN-CDH-AGG] Epoch   42 train_loss=0.463904 val_loss=0.466946
# [NN-CDH-AGG] Epoch   43 train_loss=0.462426 val_loss=0.465194
# [NN-CDH-AGG] Epoch   44 train_loss=0.460851 val_loss=0.463794
# [NN-CDH-AGG] Epoch   45 train_loss=0.459018 val_loss=0.462378
# [NN-CDH-AGG] Epoch   46 train_loss=0.457745 val_loss=0.460832
# [NN-CDH-AGG] Epoch   47 train_loss=0.456289 val_loss=0.459708
# [NN-CDH-AGG] Epoch   48 train_loss=0.454845 val_loss=0.458527
# [NN-CDH-AGG] Epoch   49 train_loss=0.453529 val_loss=0.456593
# [NN-CDH-AGG] Epoch   50 train_loss=0.452255 val_loss=0.455598
# [NN-CDH-AGG] Epoch   51 train_loss=0.450898 val_loss=0.454590
# [NN-CDH-AGG] Epoch   52 train_loss=0.449655 val_loss=0.454834
# [NN-CDH-AGG] Epoch   53 train_loss=0.448641 val_loss=0.452199
# [NN-CDH-AGG] Epoch   54 train_loss=0.447702 val_loss=0.450812
# [NN-CDH-AGG] Epoch   55 train_loss=0.446360 val_loss=0.450951
# [NN-CDH-AGG] Epoch   56 train_loss=0.445567 val_loss=0.449718
# [NN-CDH-AGG] Epoch   57 train_loss=0.444695 val_loss=0.447821
# [NN-CDH-AGG] Epoch   58 train_loss=0.443777 val_loss=0.449105
# [NN-CDH-AGG] Epoch   59 train_loss=0.442966 val_loss=0.447036
# [NN-CDH-AGG] Epoch   60 train_loss=0.442172 val_loss=0.445637
# [NN-CDH-AGG] Epoch   61 train_loss=0.441384 val_loss=0.445303
# [NN-CDH-AGG] Epoch   62 train_loss=0.440643 val_loss=0.445207
# [NN-CDH-AGG] Epoch   63 train_loss=0.440084 val_loss=0.443327
# [NN-CDH-AGG] Epoch   64 train_loss=0.439449 val_loss=0.442641
# [NN-CDH-AGG] Epoch   65 train_loss=0.438781 val_loss=0.441957
# [NN-CDH-AGG] Epoch   66 train_loss=0.438048 val_loss=0.442575
# [NN-CDH-AGG] Epoch   67 train_loss=0.437385 val_loss=0.441058
# [NN-CDH-AGG] Epoch   68 train_loss=0.436940 val_loss=0.440369
# [NN-CDH-AGG] Epoch   69 train_loss=0.436285 val_loss=0.439052
# [NN-CDH-AGG] Epoch   70 train_loss=0.435756 val_loss=0.439256
# [NN-CDH-AGG] Epoch   71 train_loss=0.435141 val_loss=0.438844
# [NN-CDH-AGG] Epoch   72 train_loss=0.434517 val_loss=0.437875
# [NN-CDH-AGG] Epoch   73 train_loss=0.433964 val_loss=0.436862
# [NN-CDH-AGG] Epoch   74 train_loss=0.433382 val_loss=0.436439
# [NN-CDH-AGG] Epoch   75 train_loss=0.432994 val_loss=0.436423
# [NN-CDH-AGG] Epoch   76 train_loss=0.432300 val_loss=0.435923
# [NN-CDH-AGG] Epoch   77 train_loss=0.431781 val_loss=0.435515
# [NN-CDH-AGG] Epoch   78 train_loss=0.431241 val_loss=0.434380
# [NN-CDH-AGG] Epoch   79 train_loss=0.430630 val_loss=0.433838
# [NN-CDH-AGG] Epoch   80 train_loss=0.430161 val_loss=0.434347
# [NN-CDH-AGG] Epoch   81 train_loss=0.429798 val_loss=0.433031
# [NN-CDH-AGG] Epoch   82 train_loss=0.429194 val_loss=0.432185
# [NN-CDH-AGG] Epoch   83 train_loss=0.428720 val_loss=0.431681
# [NN-CDH-AGG] Epoch   84 train_loss=0.428270 val_loss=0.431286
# [NN-CDH-AGG] Epoch   85 train_loss=0.427756 val_loss=0.431501
# [NN-CDH-AGG] Epoch   86 train_loss=0.427316 val_loss=0.431001
# [NN-CDH-AGG] Epoch   87 train_loss=0.426973 val_loss=0.430025
# [NN-CDH-AGG] Epoch   88 train_loss=0.426599 val_loss=0.430197
# [NN-CDH-AGG] Epoch   89 train_loss=0.426000 val_loss=0.429517
# [NN-CDH-AGG] Epoch   90 train_loss=0.425586 val_loss=0.428878
# [NN-CDH-AGG] Epoch   91 train_loss=0.425259 val_loss=0.428742
# [NN-CDH-AGG] Epoch   92 train_loss=0.424618 val_loss=0.429337
# [NN-CDH-AGG] Epoch   93 train_loss=0.424428 val_loss=0.427996
# [NN-CDH-AGG] Epoch   94 train_loss=0.423690 val_loss=0.427767
# [NN-CDH-AGG] Epoch   95 train_loss=0.423602 val_loss=0.427425
# [NN-CDH-AGG] Epoch   96 train_loss=0.423126 val_loss=0.427104
# [NN-CDH-AGG] Epoch   97 train_loss=0.422685 val_loss=0.426479
# [NN-CDH-AGG] Epoch   98 train_loss=0.422352 val_loss=0.427018
# [NN-CDH-AGG] Epoch   99 train_loss=0.421901 val_loss=0.425717
# [NN-CDH-AGG] Epoch  100 train_loss=0.421569 val_loss=0.425811
# [NN-CDH-AGG] Epoch  101 train_loss=0.421015 val_loss=0.424528
# [NN-CDH-AGG] Epoch  102 train_loss=0.420798 val_loss=0.423973
# [NN-CDH-AGG] Epoch  103 train_loss=0.420361 val_loss=0.423267
# [NN-CDH-AGG] Epoch  104 train_loss=0.419879 val_loss=0.423070
# [NN-CDH-AGG] Epoch  105 train_loss=0.419543 val_loss=0.423173
# [NN-CDH-AGG] Epoch  106 train_loss=0.418976 val_loss=0.422390
# [NN-CDH-AGG] Epoch  107 train_loss=0.418753 val_loss=0.421724
# [NN-CDH-AGG] Epoch  108 train_loss=0.418470 val_loss=0.421596
# [NN-CDH-AGG] Epoch  109 train_loss=0.418098 val_loss=0.421427
# [NN-CDH-AGG] Epoch  110 train_loss=0.417686 val_loss=0.421249
# [NN-CDH-AGG] Epoch  111 train_loss=0.417261 val_loss=0.420232
# [NN-CDH-AGG] Epoch  112 train_loss=0.417005 val_loss=0.420056
# [NN-CDH-AGG] Epoch  113 train_loss=0.416623 val_loss=0.420318
# [NN-CDH-AGG] Epoch  114 train_loss=0.416338 val_loss=0.419431
# [NN-CDH-AGG] Epoch  115 train_loss=0.416160 val_loss=0.420416
# [NN-CDH-AGG] Epoch  116 train_loss=0.415759 val_loss=0.419340
# [NN-CDH-AGG] Epoch  117 train_loss=0.415535 val_loss=0.418655
# [NN-CDH-AGG] Epoch  118 train_loss=0.415041 val_loss=0.418444
# [NN-CDH-AGG] Epoch  119 train_loss=0.415028 val_loss=0.418729
# [NN-CDH-AGG] Epoch  120 train_loss=0.414497 val_loss=0.417943
# [NN-CDH-AGG] Epoch  121 train_loss=0.414341 val_loss=0.417286
# [NN-CDH-AGG] Epoch  122 train_loss=0.414031 val_loss=0.418042
# [NN-CDH-AGG] Epoch  123 train_loss=0.413570 val_loss=0.417647
# [NN-CDH-AGG] Epoch  124 train_loss=0.413419 val_loss=0.416269
# [NN-CDH-AGG] Epoch  125 train_loss=0.413058 val_loss=0.417049
# [NN-CDH-AGG] Epoch  126 train_loss=0.412695 val_loss=0.416456
# [NN-CDH-AGG] Epoch  127 train_loss=0.412373 val_loss=0.416034
# [NN-CDH-AGG] Epoch  128 train_loss=0.412290 val_loss=0.415311
# [NN-CDH-AGG] Epoch  129 train_loss=0.412013 val_loss=0.416262
# [NN-CDH-AGG] Epoch  130 train_loss=0.411668 val_loss=0.414727
# [NN-CDH-AGG] Epoch  131 train_loss=0.411691 val_loss=0.414637
# [NN-CDH-AGG] Epoch  132 train_loss=0.411431 val_loss=0.414566
# [NN-CDH-AGG] Epoch  133 train_loss=0.411090 val_loss=0.414991
# [NN-CDH-AGG] Epoch  134 train_loss=0.410958 val_loss=0.413901
# [NN-CDH-AGG] Epoch  135 train_loss=0.410623 val_loss=0.414052
# [NN-CDH-AGG] Epoch  136 train_loss=0.410483 val_loss=0.413419
# [NN-CDH-AGG] Epoch  137 train_loss=0.410159 val_loss=0.413872
# [NN-CDH-AGG] Epoch  138 train_loss=0.410113 val_loss=0.413192
# [NN-CDH-AGG] Epoch  139 train_loss=0.409880 val_loss=0.414147
# [NN-CDH-AGG] Epoch  140 train_loss=0.409712 val_loss=0.413799
# [NN-CDH-AGG] Epoch  141 train_loss=0.409673 val_loss=0.413907
# [NN-CDH-AGG] Epoch  142 train_loss=0.409447 val_loss=0.413262
# [NN-CDH-AGG] Epoch  143 train_loss=0.409105 val_loss=0.412711
# [NN-CDH-AGG] Epoch  144 train_loss=0.409325 val_loss=0.412625
# [NN-CDH-AGG] Epoch  145 train_loss=0.409034 val_loss=0.414081
# [NN-CDH-AGG] Epoch  146 train_loss=0.409148 val_loss=0.413030
# [NN-CDH-AGG] Epoch  147 train_loss=0.408517 val_loss=0.412985
# [NN-CDH-AGG] Epoch  148 train_loss=0.408677 val_loss=0.412578
# [NN-CDH-AGG] Epoch  149 train_loss=0.408469 val_loss=0.413208
# [NN-CDH-AGG] Epoch  150 train_loss=0.408321 val_loss=0.413223
# [NN-CDH-AGG] Epoch  151 train_loss=0.408045 val_loss=0.413626
# [NN-CDH-AGG] Epoch  152 train_loss=0.408337 val_loss=0.411986
# [NN-CDH-AGG] Epoch  153 train_loss=0.407866 val_loss=0.412283
# [NN-CDH-AGG] Epoch  154 train_loss=0.408232 val_loss=0.413715
# [NN-CDH-AGG] Epoch  155 train_loss=0.407650 val_loss=0.412029
# [NN-CDH-AGG] Epoch  156 train_loss=0.407188 val_loss=0.413236
# [NN-CDH-AGG] Epoch  157 train_loss=0.407532 val_loss=0.412164
# [NN-CDH-AGG] Epoch  158 train_loss=0.407305 val_loss=0.412311
# [NN-CDH-AGG] Epoch  159 train_loss=0.407168 val_loss=0.411687
# [NN-CDH-AGG] Epoch  160 train_loss=0.407000 val_loss=0.412294
# [NN-CDH-AGG] Epoch  161 train_loss=0.406877 val_loss=0.412523
# [NN-CDH-AGG] Epoch  162 train_loss=0.406702 val_loss=0.413291
# [NN-CDH-AGG] Epoch  163 train_loss=0.406599 val_loss=0.412064
# [NN-CDH-AGG] Epoch  164 train_loss=0.406622 val_loss=0.411247
# [NN-CDH-AGG] Epoch  165 train_loss=0.406406 val_loss=0.411299
# [NN-CDH-AGG] Epoch  166 train_loss=0.406408 val_loss=0.411432
# [NN-CDH-AGG] Epoch  167 train_loss=0.406186 val_loss=0.411093
# [NN-CDH-AGG] Epoch  168 train_loss=0.406031 val_loss=0.411291
# [NN-CDH-AGG] Epoch  169 train_loss=0.405863 val_loss=0.412181
# [NN-CDH-AGG] Epoch  170 train_loss=0.405745 val_loss=0.411523
# [NN-CDH-AGG] Epoch  171 train_loss=0.405852 val_loss=0.410809
# [NN-CDH-AGG] Epoch  172 train_loss=0.405585 val_loss=0.411878
# [NN-CDH-AGG] Epoch  173 train_loss=0.405533 val_loss=0.411422
# [NN-CDH-AGG] Epoch  174 train_loss=0.405661 val_loss=0.410948
# [NN-CDH-AGG] Epoch  175 train_loss=0.405399 val_loss=0.411522
# [NN-CDH-AGG] Epoch  176 train_loss=0.405174 val_loss=0.410810
# [NN-CDH-AGG] Epoch  177 train_loss=0.405268 val_loss=0.411096
# [NN-CDH-AGG] Epoch  178 train_loss=0.405168 val_loss=0.410813
# [NN-CDH-AGG] Epoch  179 train_loss=0.404981 val_loss=0.410987
# [NN-CDH-AGG] Epoch  180 train_loss=0.404919 val_loss=0.411412
# [NN-CDH-AGG] Epoch  181 train_loss=0.404916 val_loss=0.410811
# [NN-CDH-AGG] Early stopping triggered.
# [NN-CDH-AGG] Final val_loss: 0.4108105919273325
# cases trainable: False
# labels trainable: False
# Enforcing softmax_over_cases = True for regression task.
# Number of feature extractor parameters: 0
# Number of glocal weightor parameters: 1
# torch.Size([1, 8])
# Number of adapter parameters: 12
# torch.Size([16, 16])
# torch.Size([16])
# torch.Size([8, 16])
# torch.Size([8])
# torch.Size([1, 8])
# torch.Size([1])
# torch.Size([16, 9])
# torch.Size([16])
# torch.Size([8, 16])
# torch.Size([8])
# torch.Size([1, 8])
# torch.Size([1])
# Number of case_net_params: 3
# torch.Size([16512])
# torch.Size([16512])
# torch.Size([16512, 1])
# *****************
# Training started for training_epochs epochs with batch size 64
#
# [Stage 1] Retrieval-only training for up to 7000 epochs (patience=80)
# [Stage1] Epoch 1 - Val R²: 0.3402 | Reg Val Loss: 0.7585
# [Stage1] New best (epoch 1) Val Loss: 0.7585 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 2 - Val R²: 0.3860 | Reg Val Loss: 0.7125
# [Stage1] New best (epoch 2) Val Loss: 0.7125 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 3 - Val R²: 0.4236 | Reg Val Loss: 0.6747
# [Stage1] New best (epoch 3) Val Loss: 0.6747 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 4 - Val R²: 0.4547 | Reg Val Loss: 0.6424
# [Stage1] New best (epoch 4) Val Loss: 0.6424 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 5 - Val R²: 0.4777 | Reg Val Loss: 0.6189
# [Stage1] New best (epoch 5) Val Loss: 0.6189 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 6 - Val R²: 0.4963 | Reg Val Loss: 0.6003
# [Stage1] New best (epoch 6) Val Loss: 0.6003 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 7 - Val R²: 0.5118 | Reg Val Loss: 0.5847
# [Stage1] New best (epoch 7) Val Loss: 0.5847 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 8 - Val R²: 0.5249 | Reg Val Loss: 0.5712
# [Stage1] New best (epoch 8) Val Loss: 0.5712 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 9 - Val R²: 0.5358 | Reg Val Loss: 0.5598
# [Stage1] New best (epoch 9) Val Loss: 0.5598 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 10 - Val R²: 0.5450 | Reg Val Loss: 0.5500
# [Stage1] New best (epoch 10) Val Loss: 0.5500 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 11 - Val R²: 0.5529 | Reg Val Loss: 0.5415
# [Stage1] New best (epoch 11) Val Loss: 0.5415 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 12 - Val R²: 0.5606 | Reg Val Loss: 0.5333
# [Stage1] New best (epoch 12) Val Loss: 0.5333 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 13 - Val R²: 0.5671 | Reg Val Loss: 0.5266
# [Stage1] New best (epoch 13) Val Loss: 0.5266 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 14 - Val R²: 0.5730 | Reg Val Loss: 0.5201
# [Stage1] New best (epoch 14) Val Loss: 0.5201 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 15 - Val R²: 0.5774 | Reg Val Loss: 0.5151
# [Stage1] New best (epoch 15) Val Loss: 0.5151 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 16 - Val R²: 0.5809 | Reg Val Loss: 0.5108
# [Stage1] New best (epoch 16) Val Loss: 0.5108 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 17 - Val R²: 0.5843 | Reg Val Loss: 0.5069
# [Stage1] New best (epoch 17) Val Loss: 0.5069 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 18 - Val R²: 0.5873 | Reg Val Loss: 0.5034
# [Stage1] New best (epoch 18) Val Loss: 0.5034 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 19 - Val R²: 0.5900 | Reg Val Loss: 0.5001
# [Stage1] New best (epoch 19) Val Loss: 0.5001 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 20 - Val R²: 0.5925 | Reg Val Loss: 0.4972
# [Stage1] New best (epoch 20) Val Loss: 0.4972 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 21 - Val R²: 0.5954 | Reg Val Loss: 0.4939
# [Stage1] New best (epoch 21) Val Loss: 0.4939 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 22 - Val R²: 0.5981 | Reg Val Loss: 0.4905
# [Stage1] New best (epoch 22) Val Loss: 0.4905 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 23 - Val R²: 0.5999 | Reg Val Loss: 0.4883
# [Stage1] New best (epoch 23) Val Loss: 0.4883 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 24 - Val R²: 0.6019 | Reg Val Loss: 0.4860
# [Stage1] New best (epoch 24) Val Loss: 0.4860 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 25 - Val R²: 0.6035 | Reg Val Loss: 0.4853
# [Stage1] New best (epoch 25) Val Loss: 0.4853 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 26 - Val R²: 0.6051 | Reg Val Loss: 0.4832
# [Stage1] New best (epoch 26) Val Loss: 0.4832 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 27 - Val R²: 0.6067 | Reg Val Loss: 0.4813
# [Stage1] New best (epoch 27) Val Loss: 0.4813 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 28 - Val R²: 0.6083 | Reg Val Loss: 0.4795
# [Stage1] New best (epoch 28) Val Loss: 0.4795 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 29 - Val R²: 0.6096 | Reg Val Loss: 0.4778
# [Stage1] New best (epoch 29) Val Loss: 0.4778 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 30 - Val R²: 0.6110 | Reg Val Loss: 0.4761
# [Stage1] New best (epoch 30) Val Loss: 0.4761 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 31 - Val R²: 0.6122 | Reg Val Loss: 0.4746
# [Stage1] New best (epoch 31) Val Loss: 0.4746 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 32 - Val R²: 0.6134 | Reg Val Loss: 0.4730
# [Stage1] New best (epoch 32) Val Loss: 0.4730 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 33 - Val R²: 0.6147 | Reg Val Loss: 0.4714
# [Stage1] New best (epoch 33) Val Loss: 0.4714 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 34 - Val R²: 0.6157 | Reg Val Loss: 0.4700
# [Stage1] New best (epoch 34) Val Loss: 0.4700 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 35 - Val R²: 0.6170 | Reg Val Loss: 0.4686
# [Stage1] New best (epoch 35) Val Loss: 0.4686 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 36 - Val R²: 0.6179 | Reg Val Loss: 0.4673
# [Stage1] New best (epoch 36) Val Loss: 0.4673 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 37 - Val R²: 0.6191 | Reg Val Loss: 0.4660
# [Stage1] New best (epoch 37) Val Loss: 0.4660 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 38 - Val R²: 0.6201 | Reg Val Loss: 0.4648
# [Stage1] New best (epoch 38) Val Loss: 0.4648 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 39 - Val R²: 0.6209 | Reg Val Loss: 0.4638
# [Stage1] New best (epoch 39) Val Loss: 0.4638 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 40 - Val R²: 0.6218 | Reg Val Loss: 0.4626
# [Stage1] New best (epoch 40) Val Loss: 0.4626 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 41 - Val R²: 0.6228 | Reg Val Loss: 0.4615
# [Stage1] New best (epoch 41) Val Loss: 0.4615 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 42 - Val R²: 0.6238 | Reg Val Loss: 0.4604
# [Stage1] New best (epoch 42) Val Loss: 0.4604 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 43 - Val R²: 0.6245 | Reg Val Loss: 0.4595
# [Stage1] New best (epoch 43) Val Loss: 0.4595 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 44 - Val R²: 0.6253 | Reg Val Loss: 0.4585
# [Stage1] New best (epoch 44) Val Loss: 0.4585 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 45 - Val R²: 0.6259 | Reg Val Loss: 0.4577
# [Stage1] New best (epoch 45) Val Loss: 0.4577 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 46 - Val R²: 0.6268 | Reg Val Loss: 0.4567
# [Stage1] New best (epoch 46) Val Loss: 0.4567 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 47 - Val R²: 0.6275 | Reg Val Loss: 0.4557
# [Stage1] New best (epoch 47) Val Loss: 0.4557 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 48 - Val R²: 0.6282 | Reg Val Loss: 0.4549
# [Stage1] New best (epoch 48) Val Loss: 0.4549 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 49 - Val R²: 0.6290 | Reg Val Loss: 0.4540
# [Stage1] New best (epoch 49) Val Loss: 0.4540 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 50 - Val R²: 0.6298 | Reg Val Loss: 0.4531
# [Stage1] New best (epoch 50) Val Loss: 0.4531 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 51 - Val R²: 0.6303 | Reg Val Loss: 0.4524
# [Stage1] New best (epoch 51) Val Loss: 0.4524 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 52 - Val R²: 0.6311 | Reg Val Loss: 0.4516
# [Stage1] New best (epoch 52) Val Loss: 0.4516 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 53 - Val R²: 0.6317 | Reg Val Loss: 0.4509
# [Stage1] New best (epoch 53) Val Loss: 0.4509 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 54 - Val R²: 0.6323 | Reg Val Loss: 0.4501
# [Stage1] New best (epoch 54) Val Loss: 0.4501 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 55 - Val R²: 0.6330 | Reg Val Loss: 0.4494
# [Stage1] New best (epoch 55) Val Loss: 0.4494 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 56 - Val R²: 0.6336 | Reg Val Loss: 0.4487
# [Stage1] New best (epoch 56) Val Loss: 0.4487 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 57 - Val R²: 0.6342 | Reg Val Loss: 0.4479
# [Stage1] New best (epoch 57) Val Loss: 0.4479 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 58 - Val R²: 0.6347 | Reg Val Loss: 0.4473
# [Stage1] New best (epoch 58) Val Loss: 0.4473 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 59 - Val R²: 0.6354 | Reg Val Loss: 0.4465
# [Stage1] New best (epoch 59) Val Loss: 0.4465 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 60 - Val R²: 0.6358 | Reg Val Loss: 0.4460
# [Stage1] New best (epoch 60) Val Loss: 0.4460 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 61 - Val R²: 0.6365 | Reg Val Loss: 0.4453
# [Stage1] New best (epoch 61) Val Loss: 0.4453 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 62 - Val R²: 0.6370 | Reg Val Loss: 0.4447
# [Stage1] New best (epoch 62) Val Loss: 0.4447 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 63 - Val R²: 0.6376 | Reg Val Loss: 0.4441
# [Stage1] New best (epoch 63) Val Loss: 0.4441 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 64 - Val R²: 0.6381 | Reg Val Loss: 0.4434
# [Stage1] New best (epoch 64) Val Loss: 0.4434 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 65 - Val R²: 0.6386 | Reg Val Loss: 0.4429
# [Stage1] New best (epoch 65) Val Loss: 0.4429 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 66 - Val R²: 0.6391 | Reg Val Loss: 0.4422
# [Stage1] New best (epoch 66) Val Loss: 0.4422 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 67 - Val R²: 0.6396 | Reg Val Loss: 0.4416
# [Stage1] New best (epoch 67) Val Loss: 0.4416 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 68 - Val R²: 0.6401 | Reg Val Loss: 0.4411
# [Stage1] New best (epoch 68) Val Loss: 0.4411 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 69 - Val R²: 0.6407 | Reg Val Loss: 0.4404
# [Stage1] New best (epoch 69) Val Loss: 0.4404 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 70 - Val R²: 0.6410 | Reg Val Loss: 0.4400
# [Stage1] New best (epoch 70) Val Loss: 0.4400 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 71 - Val R²: 0.6415 | Reg Val Loss: 0.4394
# [Stage1] New best (epoch 71) Val Loss: 0.4394 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 72 - Val R²: 0.6419 | Reg Val Loss: 0.4388
# [Stage1] New best (epoch 72) Val Loss: 0.4388 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 73 - Val R²: 0.6424 | Reg Val Loss: 0.4383
# [Stage1] New best (epoch 73) Val Loss: 0.4383 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 74 - Val R²: 0.6430 | Reg Val Loss: 0.4376
# [Stage1] New best (epoch 74) Val Loss: 0.4376 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 75 - Val R²: 0.6434 | Reg Val Loss: 0.4371
# [Stage1] New best (epoch 75) Val Loss: 0.4371 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 76 - Val R²: 0.6438 | Reg Val Loss: 0.4366
# [Stage1] New best (epoch 76) Val Loss: 0.4366 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 77 - Val R²: 0.6442 | Reg Val Loss: 0.4361
# [Stage1] New best (epoch 77) Val Loss: 0.4361 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 78 - Val R²: 0.6446 | Reg Val Loss: 0.4356
# [Stage1] New best (epoch 78) Val Loss: 0.4356 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 79 - Val R²: 0.6450 | Reg Val Loss: 0.4352
# [Stage1] New best (epoch 79) Val Loss: 0.4352 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 80 - Val R²: 0.6454 | Reg Val Loss: 0.4347
# [Stage1] New best (epoch 80) Val Loss: 0.4347 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 81 - Val R²: 0.6458 | Reg Val Loss: 0.4342
# [Stage1] New best (epoch 81) Val Loss: 0.4342 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 82 - Val R²: 0.6461 | Reg Val Loss: 0.4339
# [Stage1] New best (epoch 82) Val Loss: 0.4339 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 83 - Val R²: 0.6465 | Reg Val Loss: 0.4333
# [Stage1] New best (epoch 83) Val Loss: 0.4333 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 84 - Val R²: 0.6470 | Reg Val Loss: 0.4329
# [Stage1] New best (epoch 84) Val Loss: 0.4329 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 85 - Val R²: 0.6474 | Reg Val Loss: 0.4325
# [Stage1] New best (epoch 85) Val Loss: 0.4325 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 86 - Val R²: 0.6478 | Reg Val Loss: 0.4321
# [Stage1] New best (epoch 86) Val Loss: 0.4321 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 87 - Val R²: 0.6482 | Reg Val Loss: 0.4317
# [Stage1] New best (epoch 87) Val Loss: 0.4317 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 88 - Val R²: 0.6485 | Reg Val Loss: 0.4312
# [Stage1] New best (epoch 88) Val Loss: 0.4312 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 89 - Val R²: 0.6488 | Reg Val Loss: 0.4309
# [Stage1] New best (epoch 89) Val Loss: 0.4309 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 90 - Val R²: 0.6491 | Reg Val Loss: 0.4306
# [Stage1] New best (epoch 90) Val Loss: 0.4306 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 91 - Val R²: 0.6496 | Reg Val Loss: 0.4300
# [Stage1] New best (epoch 91) Val Loss: 0.4300 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 92 - Val R²: 0.6500 | Reg Val Loss: 0.4296
# [Stage1] New best (epoch 92) Val Loss: 0.4296 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 93 - Val R²: 0.6503 | Reg Val Loss: 0.4292
# [Stage1] New best (epoch 93) Val Loss: 0.4292 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 94 - Val R²: 0.6506 | Reg Val Loss: 0.4288
# [Stage1] New best (epoch 94) Val Loss: 0.4288 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 95 - Val R²: 0.6509 | Reg Val Loss: 0.4285
# [Stage1] New best (epoch 95) Val Loss: 0.4285 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 96 - Val R²: 0.6512 | Reg Val Loss: 0.4282
# [Stage1] New best (epoch 96) Val Loss: 0.4282 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 97 - Val R²: 0.6515 | Reg Val Loss: 0.4278
# [Stage1] New best (epoch 97) Val Loss: 0.4278 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 98 - Val R²: 0.6518 | Reg Val Loss: 0.4274
# [Stage1] New best (epoch 98) Val Loss: 0.4274 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 99 - Val R²: 0.6522 | Reg Val Loss: 0.4271
# [Stage1] New best (epoch 99) Val Loss: 0.4271 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 100 - Val R²: 0.6525 | Reg Val Loss: 0.4268
# [Stage1] New best (epoch 100) Val Loss: 0.4268 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 101 - Val R²: 0.6527 | Reg Val Loss: 0.4265
# [Stage1] New best (epoch 101) Val Loss: 0.4265 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 102 - Val R²: 0.6531 | Reg Val Loss: 0.4261
# [Stage1] New best (epoch 102) Val Loss: 0.4261 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 103 - Val R²: 0.6533 | Reg Val Loss: 0.4258
# [Stage1] New best (epoch 103) Val Loss: 0.4258 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 104 - Val R²: 0.6537 | Reg Val Loss: 0.4254
# [Stage1] New best (epoch 104) Val Loss: 0.4254 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 105 - Val R²: 0.6539 | Reg Val Loss: 0.4251
# [Stage1] New best (epoch 105) Val Loss: 0.4251 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 106 - Val R²: 0.6542 | Reg Val Loss: 0.4249
# [Stage1] New best (epoch 106) Val Loss: 0.4249 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 107 - Val R²: 0.6546 | Reg Val Loss: 0.4245
# [Stage1] New best (epoch 107) Val Loss: 0.4245 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 108 - Val R²: 0.6549 | Reg Val Loss: 0.4242
# [Stage1] New best (epoch 108) Val Loss: 0.4242 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 109 - Val R²: 0.6551 | Reg Val Loss: 0.4239
# [Stage1] New best (epoch 109) Val Loss: 0.4239 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 110 - Val R²: 0.6553 | Reg Val Loss: 0.4236
# [Stage1] New best (epoch 110) Val Loss: 0.4236 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 111 - Val R²: 0.6556 | Reg Val Loss: 0.4233
# [Stage1] New best (epoch 111) Val Loss: 0.4233 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 112 - Val R²: 0.6559 | Reg Val Loss: 0.4230
# [Stage1] New best (epoch 112) Val Loss: 0.4230 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 113 - Val R²: 0.6562 | Reg Val Loss: 0.4226
# [Stage1] New best (epoch 113) Val Loss: 0.4226 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 114 - Val R²: 0.6564 | Reg Val Loss: 0.4223
# [Stage1] New best (epoch 114) Val Loss: 0.4223 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 115 - Val R²: 0.6567 | Reg Val Loss: 0.4221
# [Stage1] New best (epoch 115) Val Loss: 0.4221 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 116 - Val R²: 0.6569 | Reg Val Loss: 0.4217
# [Stage1] New best (epoch 116) Val Loss: 0.4217 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 117 - Val R²: 0.6572 | Reg Val Loss: 0.4214
# [Stage1] New best (epoch 117) Val Loss: 0.4214 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 118 - Val R²: 0.6575 | Reg Val Loss: 0.4212
# [Stage1] New best (epoch 118) Val Loss: 0.4212 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 119 - Val R²: 0.6576 | Reg Val Loss: 0.4209
# [Stage1] New best (epoch 119) Val Loss: 0.4209 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 120 - Val R²: 0.6579 | Reg Val Loss: 0.4206
# [Stage1] New best (epoch 120) Val Loss: 0.4206 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 121 - Val R²: 0.6582 | Reg Val Loss: 0.4204
# [Stage1] New best (epoch 121) Val Loss: 0.4204 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 122 - Val R²: 0.6583 | Reg Val Loss: 0.4202
# [Stage1] New best (epoch 122) Val Loss: 0.4202 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 123 - Val R²: 0.6585 | Reg Val Loss: 0.4200
# [Stage1] New best (epoch 123) Val Loss: 0.4200 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 124 - Val R²: 0.6588 | Reg Val Loss: 0.4197
# [Stage1] New best (epoch 124) Val Loss: 0.4197 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 125 - Val R²: 0.6590 | Reg Val Loss: 0.4195
# [Stage1] New best (epoch 125) Val Loss: 0.4195 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 126 - Val R²: 0.6593 | Reg Val Loss: 0.4192
# [Stage1] New best (epoch 126) Val Loss: 0.4192 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 127 - Val R²: 0.6595 | Reg Val Loss: 0.4189
# [Stage1] New best (epoch 127) Val Loss: 0.4189 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 128 - Val R²: 0.6597 | Reg Val Loss: 0.4186
# [Stage1] New best (epoch 128) Val Loss: 0.4186 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 129 - Val R²: 0.6600 | Reg Val Loss: 0.4184
# [Stage1] New best (epoch 129) Val Loss: 0.4184 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 130 - Val R²: 0.6601 | Reg Val Loss: 0.4183
# [Stage1] New best (epoch 130) Val Loss: 0.4183 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 131 - Val R²: 0.6604 | Reg Val Loss: 0.4179
# [Stage1] New best (epoch 131) Val Loss: 0.4179 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 132 - Val R²: 0.6605 | Reg Val Loss: 0.4178
# [Stage1] New best (epoch 132) Val Loss: 0.4178 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 133 - Val R²: 0.6608 | Reg Val Loss: 0.4175
# [Stage1] New best (epoch 133) Val Loss: 0.4175 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 134 - Val R²: 0.6610 | Reg Val Loss: 0.4173
# [Stage1] New best (epoch 134) Val Loss: 0.4173 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 135 - Val R²: 0.6612 | Reg Val Loss: 0.4171
# [Stage1] New best (epoch 135) Val Loss: 0.4171 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 136 - Val R²: 0.6613 | Reg Val Loss: 0.4168
# [Stage1] New best (epoch 136) Val Loss: 0.4168 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 137 - Val R²: 0.6616 | Reg Val Loss: 0.4166
# [Stage1] New best (epoch 137) Val Loss: 0.4166 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 138 - Val R²: 0.6618 | Reg Val Loss: 0.4164
# [Stage1] New best (epoch 138) Val Loss: 0.4164 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 139 - Val R²: 0.6620 | Reg Val Loss: 0.4162
# [Stage1] New best (epoch 139) Val Loss: 0.4162 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 140 - Val R²: 0.6622 | Reg Val Loss: 0.4159
# [Stage1] New best (epoch 140) Val Loss: 0.4159 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 141 - Val R²: 0.6624 | Reg Val Loss: 0.4157
# [Stage1] New best (epoch 141) Val Loss: 0.4157 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 142 - Val R²: 0.6626 | Reg Val Loss: 0.4155
# [Stage1] New best (epoch 142) Val Loss: 0.4155 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 143 - Val R²: 0.6628 | Reg Val Loss: 0.4153
# [Stage1] New best (epoch 143) Val Loss: 0.4153 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 144 - Val R²: 0.6629 | Reg Val Loss: 0.4152
# [Stage1] New best (epoch 144) Val Loss: 0.4152 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 145 - Val R²: 0.6633 | Reg Val Loss: 0.4148
# [Stage1] New best (epoch 145) Val Loss: 0.4148 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 146 - Val R²: 0.6634 | Reg Val Loss: 0.4146
# [Stage1] New best (epoch 146) Val Loss: 0.4146 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 147 - Val R²: 0.6635 | Reg Val Loss: 0.4144
# [Stage1] New best (epoch 147) Val Loss: 0.4144 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 148 - Val R²: 0.6637 | Reg Val Loss: 0.4143
# [Stage1] New best (epoch 148) Val Loss: 0.4143 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 149 - Val R²: 0.6639 | Reg Val Loss: 0.4141
# [Stage1] New best (epoch 149) Val Loss: 0.4141 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 150 - Val R²: 0.6640 | Reg Val Loss: 0.4140
# [Stage1] New best (epoch 150) Val Loss: 0.4140 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 151 - Val R²: 0.6641 | Reg Val Loss: 0.4139
# [Stage1] New best (epoch 151) Val Loss: 0.4139 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 152 - Val R²: 0.6644 | Reg Val Loss: 0.4136
# [Stage1] New best (epoch 152) Val Loss: 0.4136 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 153 - Val R²: 0.6645 | Reg Val Loss: 0.4135
# [Stage1] New best (epoch 153) Val Loss: 0.4135 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 154 - Val R²: 0.6646 | Reg Val Loss: 0.4133
# [Stage1] New best (epoch 154) Val Loss: 0.4133 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 155 - Val R²: 0.6647 | Reg Val Loss: 0.4133
# [Stage1] New best (epoch 155) Val Loss: 0.4133 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 156 - Val R²: 0.6649 | Reg Val Loss: 0.4130
# [Stage1] New best (epoch 156) Val Loss: 0.4130 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 157 - Val R²: 0.6650 | Reg Val Loss: 0.4128
# [Stage1] New best (epoch 157) Val Loss: 0.4128 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 158 - Val R²: 0.6652 | Reg Val Loss: 0.4127
# [Stage1] New best (epoch 158) Val Loss: 0.4127 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 159 - Val R²: 0.6654 | Reg Val Loss: 0.4125
# [Stage1] New best (epoch 159) Val Loss: 0.4125 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 160 - Val R²: 0.6656 | Reg Val Loss: 0.4123
# [Stage1] New best (epoch 160) Val Loss: 0.4123 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 161 - Val R²: 0.6657 | Reg Val Loss: 0.4122
# [Stage1] New best (epoch 161) Val Loss: 0.4122 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 162 - Val R²: 0.6659 | Reg Val Loss: 0.4120
# [Stage1] New best (epoch 162) Val Loss: 0.4120 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 163 - Val R²: 0.6660 | Reg Val Loss: 0.4118
# [Stage1] New best (epoch 163) Val Loss: 0.4118 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 164 - Val R²: 0.6660 | Reg Val Loss: 0.4117
# [Stage1] New best (epoch 164) Val Loss: 0.4117 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 165 - Val R²: 0.6663 | Reg Val Loss: 0.4114
# [Stage1] New best (epoch 165) Val Loss: 0.4114 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 166 - Val R²: 0.6665 | Reg Val Loss: 0.4113
# [Stage1] New best (epoch 166) Val Loss: 0.4113 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 167 - Val R²: 0.6666 | Reg Val Loss: 0.4112
# [Stage1] New best (epoch 167) Val Loss: 0.4112 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 168 - Val R²: 0.6667 | Reg Val Loss: 0.4110
# [Stage1] New best (epoch 168) Val Loss: 0.4110 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 169 - Val R²: 0.6669 | Reg Val Loss: 0.4109
# [Stage1] New best (epoch 169) Val Loss: 0.4109 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 170 - Val R²: 0.6670 | Reg Val Loss: 0.4107
# [Stage1] New best (epoch 170) Val Loss: 0.4107 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 171 - Val R²: 0.6671 | Reg Val Loss: 0.4106
# [Stage1] New best (epoch 171) Val Loss: 0.4106 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 172 - Val R²: 0.6672 | Reg Val Loss: 0.4105
# [Stage1] New best (epoch 172) Val Loss: 0.4105 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 173 - Val R²: 0.6673 | Reg Val Loss: 0.4104
# [Stage1] New best (epoch 173) Val Loss: 0.4104 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 174 - Val R²: 0.6674 | Reg Val Loss: 0.4103
# [Stage1] New best (epoch 174) Val Loss: 0.4103 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 175 - Val R²: 0.6676 | Reg Val Loss: 0.4100
# [Stage1] New best (epoch 175) Val Loss: 0.4100 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 176 - Val R²: 0.6677 | Reg Val Loss: 0.4099
# [Stage1] New best (epoch 176) Val Loss: 0.4099 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 177 - Val R²: 0.6677 | Reg Val Loss: 0.4099
# [Stage1] No improv. Best so far: 0.4099 (epoch 176)
# [Stage1] Epoch 178 - Val R²: 0.6678 | Reg Val Loss: 0.4098
# [Stage1] New best (epoch 178) Val Loss: 0.4098 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 179 - Val R²: 0.6681 | Reg Val Loss: 0.4095
# [Stage1] New best (epoch 179) Val Loss: 0.4095 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 180 - Val R²: 0.6681 | Reg Val Loss: 0.4094
# [Stage1] New best (epoch 180) Val Loss: 0.4094 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 181 - Val R²: 0.6683 | Reg Val Loss: 0.4093
# [Stage1] New best (epoch 181) Val Loss: 0.4093 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 182 - Val R²: 0.6684 | Reg Val Loss: 0.4091
# [Stage1] New best (epoch 182) Val Loss: 0.4091 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 183 - Val R²: 0.6686 | Reg Val Loss: 0.4090
# [Stage1] New best (epoch 183) Val Loss: 0.4090 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 184 - Val R²: 0.6687 | Reg Val Loss: 0.4089
# [Stage1] New best (epoch 184) Val Loss: 0.4089 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 185 - Val R²: 0.6687 | Reg Val Loss: 0.4088
# [Stage1] New best (epoch 185) Val Loss: 0.4088 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 186 - Val R²: 0.6688 | Reg Val Loss: 0.4087
# [Stage1] New best (epoch 186) Val Loss: 0.4087 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 187 - Val R²: 0.6689 | Reg Val Loss: 0.4086
# [Stage1] New best (epoch 187) Val Loss: 0.4086 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 188 - Val R²: 0.6690 | Reg Val Loss: 0.4085
# [Stage1] New best (epoch 188) Val Loss: 0.4085 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 189 - Val R²: 0.6692 | Reg Val Loss: 0.4083
# [Stage1] New best (epoch 189) Val Loss: 0.4083 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 190 - Val R²: 0.6692 | Reg Val Loss: 0.4082
# [Stage1] New best (epoch 190) Val Loss: 0.4082 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 191 - Val R²: 0.6693 | Reg Val Loss: 0.4081
# [Stage1] New best (epoch 191) Val Loss: 0.4081 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 192 - Val R²: 0.6694 | Reg Val Loss: 0.4080
# [Stage1] New best (epoch 192) Val Loss: 0.4080 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 193 - Val R²: 0.6695 | Reg Val Loss: 0.4079
# [Stage1] New best (epoch 193) Val Loss: 0.4079 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 194 - Val R²: 0.6696 | Reg Val Loss: 0.4078
# [Stage1] New best (epoch 194) Val Loss: 0.4078 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 195 - Val R²: 0.6697 | Reg Val Loss: 0.4077
# [Stage1] New best (epoch 195) Val Loss: 0.4077 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 196 - Val R²: 0.6698 | Reg Val Loss: 0.4076
# [Stage1] New best (epoch 196) Val Loss: 0.4076 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 197 - Val R²: 0.6700 | Reg Val Loss: 0.4074
# [Stage1] New best (epoch 197) Val Loss: 0.4074 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 198 - Val R²: 0.6699 | Reg Val Loss: 0.4074
# [Stage1] New best (epoch 198) Val Loss: 0.4074 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 199 - Val R²: 0.6701 | Reg Val Loss: 0.4072
# [Stage1] New best (epoch 199) Val Loss: 0.4072 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 200 - Val R²: 0.6701 | Reg Val Loss: 0.4072
# [Stage1] New best (epoch 200) Val Loss: 0.4072 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 201 - Val R²: 0.6702 | Reg Val Loss: 0.4071
# [Stage1] New best (epoch 201) Val Loss: 0.4071 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 202 - Val R²: 0.6703 | Reg Val Loss: 0.4070
# [Stage1] New best (epoch 202) Val Loss: 0.4070 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 203 - Val R²: 0.6705 | Reg Val Loss: 0.4068
# [Stage1] New best (epoch 203) Val Loss: 0.4068 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 204 - Val R²: 0.6705 | Reg Val Loss: 0.4068
# [Stage1] New best (epoch 204) Val Loss: 0.4068 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 205 - Val R²: 0.6706 | Reg Val Loss: 0.4066
# [Stage1] New best (epoch 205) Val Loss: 0.4066 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 206 - Val R²: 0.6707 | Reg Val Loss: 0.4066
# [Stage1] New best (epoch 206) Val Loss: 0.4066 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 207 - Val R²: 0.6707 | Reg Val Loss: 0.4065
# [Stage1] New best (epoch 207) Val Loss: 0.4065 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 208 - Val R²: 0.6710 | Reg Val Loss: 0.4063
# [Stage1] New best (epoch 208) Val Loss: 0.4063 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 209 - Val R²: 0.6710 | Reg Val Loss: 0.4063
# [Stage1] New best (epoch 209) Val Loss: 0.4063 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 210 - Val R²: 0.6710 | Reg Val Loss: 0.4062
# [Stage1] New best (epoch 210) Val Loss: 0.4062 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 211 - Val R²: 0.6711 | Reg Val Loss: 0.4062
# [Stage1] New best (epoch 211) Val Loss: 0.4062 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 212 - Val R²: 0.6711 | Reg Val Loss: 0.4061
# [Stage1] New best (epoch 212) Val Loss: 0.4061 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 213 - Val R²: 0.6713 | Reg Val Loss: 0.4059
# [Stage1] New best (epoch 213) Val Loss: 0.4059 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 214 - Val R²: 0.6713 | Reg Val Loss: 0.4059
# [Stage1] New best (epoch 214) Val Loss: 0.4059 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 215 - Val R²: 0.6714 | Reg Val Loss: 0.4058
# [Stage1] New best (epoch 215) Val Loss: 0.4058 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 216 - Val R²: 0.6716 | Reg Val Loss: 0.4056
# [Stage1] New best (epoch 216) Val Loss: 0.4056 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 217 - Val R²: 0.6716 | Reg Val Loss: 0.4056
# [Stage1] No improv. Best so far: 0.4056 (epoch 216)
# [Stage1] Epoch 218 - Val R²: 0.6716 | Reg Val Loss: 0.4056
# [Stage1] New best (epoch 218) Val Loss: 0.4056 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 219 - Val R²: 0.6718 | Reg Val Loss: 0.4054
# [Stage1] New best (epoch 219) Val Loss: 0.4054 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 220 - Val R²: 0.6718 | Reg Val Loss: 0.4053
# [Stage1] New best (epoch 220) Val Loss: 0.4053 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 221 - Val R²: 0.6718 | Reg Val Loss: 0.4054
# [Stage1] No improv. Best so far: 0.4053 (epoch 220)
# [Stage1] Epoch 222 - Val R²: 0.6720 | Reg Val Loss: 0.4052
# [Stage1] New best (epoch 222) Val Loss: 0.4052 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 223 - Val R²: 0.6720 | Reg Val Loss: 0.4052
# [Stage1] New best (epoch 223) Val Loss: 0.4052 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 224 - Val R²: 0.6722 | Reg Val Loss: 0.4050
# [Stage1] New best (epoch 224) Val Loss: 0.4050 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 225 - Val R²: 0.6722 | Reg Val Loss: 0.4049
# [Stage1] New best (epoch 225) Val Loss: 0.4049 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 226 - Val R²: 0.6722 | Reg Val Loss: 0.4050
# [Stage1] No improv. Best so far: 0.4049 (epoch 225)
# [Stage1] Epoch 227 - Val R²: 0.6723 | Reg Val Loss: 0.4048
# [Stage1] New best (epoch 227) Val Loss: 0.4048 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 228 - Val R²: 0.6723 | Reg Val Loss: 0.4048
# [Stage1] New best (epoch 228) Val Loss: 0.4048 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 229 - Val R²: 0.6723 | Reg Val Loss: 0.4048
# [Stage1] New best (epoch 229) Val Loss: 0.4048 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 230 - Val R²: 0.6725 | Reg Val Loss: 0.4047
# [Stage1] New best (epoch 230) Val Loss: 0.4047 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 231 - Val R²: 0.6725 | Reg Val Loss: 0.4046
# [Stage1] New best (epoch 231) Val Loss: 0.4046 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 232 - Val R²: 0.6725 | Reg Val Loss: 0.4046
# [Stage1] New best (epoch 232) Val Loss: 0.4046 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 233 - Val R²: 0.6726 | Reg Val Loss: 0.4045
# [Stage1] New best (epoch 233) Val Loss: 0.4045 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 234 - Val R²: 0.6727 | Reg Val Loss: 0.4044
# [Stage1] New best (epoch 234) Val Loss: 0.4044 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 235 - Val R²: 0.6727 | Reg Val Loss: 0.4044
# [Stage1] No improv. Best so far: 0.4044 (epoch 234)
# [Stage1] Epoch 236 - Val R²: 0.6728 | Reg Val Loss: 0.4043
# [Stage1] New best (epoch 236) Val Loss: 0.4043 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 237 - Val R²: 0.6728 | Reg Val Loss: 0.4043
# [Stage1] No improv. Best so far: 0.4043 (epoch 236)
# [Stage1] Epoch 238 - Val R²: 0.6729 | Reg Val Loss: 0.4042
# [Stage1] New best (epoch 238) Val Loss: 0.4042 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 239 - Val R²: 0.6730 | Reg Val Loss: 0.4041
# [Stage1] New best (epoch 239) Val Loss: 0.4041 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 240 - Val R²: 0.6730 | Reg Val Loss: 0.4040
# [Stage1] New best (epoch 240) Val Loss: 0.4040 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 241 - Val R²: 0.6731 | Reg Val Loss: 0.4040
# [Stage1] New best (epoch 241) Val Loss: 0.4040 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 242 - Val R²: 0.6731 | Reg Val Loss: 0.4040
# [Stage1] No improv. Best so far: 0.4040 (epoch 241)
# [Stage1] Epoch 243 - Val R²: 0.6730 | Reg Val Loss: 0.4040
# [Stage1] No improv. Best so far: 0.4040 (epoch 241)
# [Stage1] Epoch 244 - Val R²: 0.6731 | Reg Val Loss: 0.4039
# [Stage1] New best (epoch 244) Val Loss: 0.4039 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 245 - Val R²: 0.6732 | Reg Val Loss: 0.4039
# [Stage1] New best (epoch 245) Val Loss: 0.4039 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 246 - Val R²: 0.6732 | Reg Val Loss: 0.4038
# [Stage1] New best (epoch 246) Val Loss: 0.4038 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 247 - Val R²: 0.6733 | Reg Val Loss: 0.4037
# [Stage1] New best (epoch 247) Val Loss: 0.4037 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 248 - Val R²: 0.6733 | Reg Val Loss: 0.4037
# [Stage1] No improv. Best so far: 0.4037 (epoch 247)
# [Stage1] Epoch 249 - Val R²: 0.6734 | Reg Val Loss: 0.4036
# [Stage1] New best (epoch 249) Val Loss: 0.4036 — saved: nnknn_regression_best_retr.pth
# [Stage1] Epoch 250 - Val R²: 0.6734 | Reg Val Loss: 0.4037
# [Stage1] No improv. Best so far: 0.4036 (epoch 249)
# ...
# [Stage1] Epoch 763 - Val R²: 0.6757 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 764 - Val R²: 0.6757 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 765 - Val R²: 0.6757 | Reg Val Loss: 0.4001
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 766 - Val R²: 0.6757 | Reg Val Loss: 0.4001
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 767 - Val R²: 0.6757 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 768 - Val R²: 0.6757 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 769 - Val R²: 0.6757 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 770 - Val R²: 0.6757 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 771 - Val R²: 0.6757 | Reg Val Loss: 0.4001
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 772 - Val R²: 0.6755 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 773 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 774 - Val R²: 0.6757 | Reg Val Loss: 0.4001
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 775 - Val R²: 0.6757 | Reg Val Loss: 0.4001
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 776 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 777 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 778 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 779 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 780 - Val R²: 0.6757 | Reg Val Loss: 0.4001
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 781 - Val R²: 0.6757 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 782 - Val R²: 0.6757 | Reg Val Loss: 0.4001
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 783 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 784 - Val R²: 0.6756 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 785 - Val R²: 0.6757 | Reg Val Loss: 0.4001
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 786 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 787 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 788 - Val R²: 0.6756 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 789 - Val R²: 0.6755 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 790 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 791 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 792 - Val R²: 0.6755 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 793 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 794 - Val R²: 0.6754 | Reg Val Loss: 0.4004
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 795 - Val R²: 0.6754 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 796 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 797 - Val R²: 0.6755 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 798 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 799 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 800 - Val R²: 0.6755 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 801 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 802 - Val R²: 0.6755 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 803 - Val R²: 0.6755 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 804 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 805 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 806 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 807 - Val R²: 0.6756 | Reg Val Loss: 0.4001
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 808 - Val R²: 0.6755 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 809 - Val R²: 0.6755 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 810 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 811 - Val R²: 0.6756 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 812 - Val R²: 0.6755 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 813 - Val R²: 0.6754 | Reg Val Loss: 0.4004
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 814 - Val R²: 0.6754 | Reg Val Loss: 0.4004
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 815 - Val R²: 0.6755 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 816 - Val R²: 0.6755 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 817 - Val R²: 0.6754 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 818 - Val R²: 0.6755 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 819 - Val R²: 0.6754 | Reg Val Loss: 0.4003
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 820 - Val R²: 0.6755 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 821 - Val R²: 0.6755 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Epoch 822 - Val R²: 0.6755 | Reg Val Loss: 0.4002
# [Stage1] No improv. Best so far: 0.4000 (epoch 741)
# [Stage1] Patience exceeded. Restoring best retrieval model.
#
# [Stage 2] Adapter-only training for up to 7000 epochs (patience=80)
# [Stage2] Epoch 1 - Val R²: 0.3624 | Reg Val Loss: 0.7252
# [Stage2] New best (epoch 1) Val Loss: 0.7252 — saved: nnknn_regression_best_cdh.pth
# [Stage2] Epoch 2 - Val R²: 0.3416 | Reg Val Loss: 0.7468
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 3 - Val R²: 0.3173 | Reg Val Loss: 0.7720
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 4 - Val R²: 0.2764 | Reg Val Loss: 0.8145
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 5 - Val R²: 0.2642 | Reg Val Loss: 0.8271
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 6 - Val R²: 0.2443 | Reg Val Loss: 0.8478
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 7 - Val R²: 0.1726 | Reg Val Loss: 0.9221
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 8 - Val R²: 0.1491 | Reg Val Loss: 0.9465
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 9 - Val R²: 0.1505 | Reg Val Loss: 0.9450
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 10 - Val R²: 0.1165 | Reg Val Loss: 0.9803
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 11 - Val R²: 0.1094 | Reg Val Loss: 0.9877
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 12 - Val R²: 0.1018 | Reg Val Loss: 0.9956
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 13 - Val R²: 0.0958 | Reg Val Loss: 1.0018
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 14 - Val R²: 0.0709 | Reg Val Loss: 1.0276
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 15 - Val R²: 0.0823 | Reg Val Loss: 1.0158
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 16 - Val R²: 0.0678 | Reg Val Loss: 1.0308
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 17 - Val R²: 0.0699 | Reg Val Loss: 1.0287
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 18 - Val R²: 0.0656 | Reg Val Loss: 1.0331
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 19 - Val R²: 0.0767 | Reg Val Loss: 1.0216
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 20 - Val R²: 0.0420 | Reg Val Loss: 1.0577
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 21 - Val R²: 0.0478 | Reg Val Loss: 1.0516
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 22 - Val R²: 0.0507 | Reg Val Loss: 1.0486
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 23 - Val R²: 0.0248 | Reg Val Loss: 1.0755
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 24 - Val R²: 0.0271 | Reg Val Loss: 1.0731
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 25 - Val R²: -0.0134 | Reg Val Loss: 1.1152
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 26 - Val R²: 0.0123 | Reg Val Loss: 1.0884
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 27 - Val R²: -0.0192 | Reg Val Loss: 1.1211
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 28 - Val R²: -0.0403 | Reg Val Loss: 1.1430
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 29 - Val R²: -0.0502 | Reg Val Loss: 1.1533
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 30 - Val R²: -0.0511 | Reg Val Loss: 1.1542
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 31 - Val R²: -0.0358 | Reg Val Loss: 1.1383
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 32 - Val R²: -0.0454 | Reg Val Loss: 1.1483
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 33 - Val R²: -0.0528 | Reg Val Loss: 1.1559
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 34 - Val R²: -0.0641 | Reg Val Loss: 1.1677
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 35 - Val R²: -0.0557 | Reg Val Loss: 1.1591
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 36 - Val R²: -0.0493 | Reg Val Loss: 1.1524
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 37 - Val R²: -0.0808 | Reg Val Loss: 1.1850
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 38 - Val R²: -0.0548 | Reg Val Loss: 1.1580
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 39 - Val R²: -0.0732 | Reg Val Loss: 1.1771
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 40 - Val R²: -0.0893 | Reg Val Loss: 1.1938
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 41 - Val R²: -0.0746 | Reg Val Loss: 1.1786
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 42 - Val R²: -0.1085 | Reg Val Loss: 1.2137
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 43 - Val R²: -0.1208 | Reg Val Loss: 1.2265
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 44 - Val R²: -0.1021 | Reg Val Loss: 1.2072
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 45 - Val R²: -0.1056 | Reg Val Loss: 1.2108
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 46 - Val R²: -0.1119 | Reg Val Loss: 1.2173
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 47 - Val R²: -0.1190 | Reg Val Loss: 1.2247
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 48 - Val R²: -0.1042 | Reg Val Loss: 1.2093
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 49 - Val R²: -0.1110 | Reg Val Loss: 1.2164
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 50 - Val R²: -0.1150 | Reg Val Loss: 1.2206
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 51 - Val R²: -0.1236 | Reg Val Loss: 1.2294
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 52 - Val R²: -0.1497 | Reg Val Loss: 1.2566
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 53 - Val R²: -0.1406 | Reg Val Loss: 1.2470
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 54 - Val R²: -0.1368 | Reg Val Loss: 1.2431
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 55 - Val R²: -0.1213 | Reg Val Loss: 1.2271
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 56 - Val R²: -0.1333 | Reg Val Loss: 1.2395
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 57 - Val R²: -0.1504 | Reg Val Loss: 1.2573
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 58 - Val R²: -0.1370 | Reg Val Loss: 1.2434
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 59 - Val R²: -0.1469 | Reg Val Loss: 1.2537
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 60 - Val R²: -0.1512 | Reg Val Loss: 1.2581
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 61 - Val R²: -0.1940 | Reg Val Loss: 1.3024
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 62 - Val R²: -0.1482 | Reg Val Loss: 1.2550
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 63 - Val R²: -0.1832 | Reg Val Loss: 1.2913
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 64 - Val R²: -0.1716 | Reg Val Loss: 1.2792
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 65 - Val R²: -0.1787 | Reg Val Loss: 1.2866
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 66 - Val R²: -0.1708 | Reg Val Loss: 1.2784
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 67 - Val R²: -0.1911 | Reg Val Loss: 1.2994
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 68 - Val R²: -0.1949 | Reg Val Loss: 1.3035
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 69 - Val R²: -0.1763 | Reg Val Loss: 1.2841
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 70 - Val R²: -0.1887 | Reg Val Loss: 1.2970
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 71 - Val R²: -0.1874 | Reg Val Loss: 1.2956
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 72 - Val R²: -0.1806 | Reg Val Loss: 1.2886
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 73 - Val R²: -0.1974 | Reg Val Loss: 1.3060
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 74 - Val R²: -0.1877 | Reg Val Loss: 1.2960
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 75 - Val R²: -0.2195 | Reg Val Loss: 1.3290
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 76 - Val R²: -0.2018 | Reg Val Loss: 1.3106
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 77 - Val R²: -0.2157 | Reg Val Loss: 1.3250
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 78 - Val R²: -0.2177 | Reg Val Loss: 1.3271
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 79 - Val R²: -0.2170 | Reg Val Loss: 1.3264
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 80 - Val R²: -0.2355 | Reg Val Loss: 1.3456
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 81 - Val R²: -0.2284 | Reg Val Loss: 1.3382
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Epoch 82 - Val R²: -0.2138 | Reg Val Loss: 1.3230
# [Stage2] No improv. Best so far: 0.7252 (epoch 1)
# [Stage2] Patience exceeded. Restoring best adapter model.
# Training completed. Best Acc or R2:  0
# Final global feature weights: tensor([[0.1226, 0.0641, 0.0000, 0.0000, 0.0000, 0.1405, 0.3141, 0.3587]],
#        device='cuda:0')
# Best (R^2 proxy in logs).

# %% [markdown]
# ## Evaluate & visualize

# %%
import matplotlib.pyplot as plt
import torch.nn.functional as F
import torch

model.eval()
with torch.no_grad():
    preds = []
    B = 512
    for i in range(0, X_val.size(0), B):
        _, yhat, *_ = model(X_val[i:i+B].to(device))
        preds.append(yhat.detach().cpu())
    y_pred_z = torch.cat(preds, dim=0).view(-1)
    y_true_z = y_val.view(-1)   # <-- z-space

rmse_z = torch.sqrt(F.mse_loss(y_pred_z, y_true_z)).item()
print(f"Validation RMSE (z): {rmse_z:.4f}")

# Optional: convert to raw units (only if you kept the train-stat scaler)
y_mean_t = torch.as_tensor(y_mean_raw, dtype=torch.float32)
y_std_t  = torch.as_tensor(y_std_raw,  dtype=torch.float32).clamp_min(1e-6)

y_pred_raw = y_pred_z * y_std_t + y_mean_t
y_true_raw = y_true_z * y_std_t + y_mean_t
rmse_raw = torch.sqrt(F.mse_loss(y_pred_raw, y_true_raw)).item()
print(f"Validation RMSE (raw): {rmse_raw:.4f}")

plt.figure(figsize=(5,5))
plt.scatter(y_true_raw.numpy(), y_pred_raw.numpy(), s=8, alpha=0.7)
mn = float(min(y_true_raw.min().item(), y_pred_raw.min().item()))
mx = float(max(y_true_raw.max().item(), y_pred_raw.max().item()))
plt.plot([mn, mx], [mn, mx], linestyle='--')
plt.xlabel('True (raw)')
plt.ylabel('Predicted (raw)')
plt.title('Observed vs Predicted (Validation)')
plt.show()
# Out:
# Validation RMSE (z): 0.8133
# Validation RMSE (raw): 0.9350

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F

model.eval()
with torch.no_grad():
    pre_preds, post_preds = [], []
    B = 512
    for i in range(0, X_val.size(0), B):
        _, yhat, pre_adapt_yhat, *_ = model(X_val[i:i+B].to(device))

        # pre_adapt_yhat may come in different shapes depending on code path
        if pre_adapt_yhat.dim() == 3:
            pre_yhat = pre_adapt_yhat.sum(dim=1).squeeze(-1)  # [B]
        elif pre_adapt_yhat.dim() == 2:
            pre_yhat = pre_adapt_yhat.squeeze(-1)             # [B]
        else:
            pre_yhat = pre_adapt_yhat                         # [B]

        post_preds.append(yhat.detach().cpu().view(-1))
        pre_preds.append(pre_yhat.detach().cpu().view(-1))

    y_pred_post_z = torch.cat(post_preds, dim=0).to(torch.float32)  # z-space
    y_pred_pre_z  = torch.cat(pre_preds,  dim=0).to(torch.float32)  # z-space
    y_true_z      = y_val.detach().cpu().view(-1).to(torch.float32) # z-space

# --- Metrics in z-space (always correct for training/val consistency) ---
mse_pre_z  = F.mse_loss(y_pred_pre_z,  y_true_z).item()
mse_post_z = F.mse_loss(y_pred_post_z, y_true_z).item()
rmse_pre_z  = mse_pre_z ** 0.5
rmse_post_z = mse_post_z ** 0.5

print(f"[Z] Pre-adaptation  MSE: {mse_pre_z:.6f}, RMSE: {rmse_pre_z:.6f}")
print(f"[Z] Post-adaptation MSE: {mse_post_z:.6f}, RMSE: {rmse_post_z:.6f}")
print(f"[Z] ΔRMSE (pre - post):  {rmse_pre_z - rmse_post_z:.6f}")

# --- Optional: convert to raw units if you saved train-split scaler ---
# (RMSE_raw = RMSE_z * y_std_raw)
y_mean_t = torch.as_tensor(y_mean_raw, dtype=torch.float32)
y_std_t  = torch.as_tensor(y_std_raw,  dtype=torch.float32).clamp_min(1e-6)

y_pred_pre_raw  = y_pred_pre_z  * y_std_t + y_mean_t
y_pred_post_raw = y_pred_post_z * y_std_t + y_mean_t
y_true_raw      = y_true_z      * y_std_t + y_mean_t

rmse_pre_raw  = torch.sqrt(F.mse_loss(y_pred_pre_raw,  y_true_raw)).item()
rmse_post_raw = torch.sqrt(F.mse_loss(y_pred_post_raw, y_true_raw)).item()
print(f"[RAW] Pre-adaptation  RMSE: {rmse_pre_raw:.6f}")
print(f"[RAW] Post-adaptation RMSE: {rmse_post_raw:.6f}")

# Plots in raw units (more interpretable)
plt.figure(figsize=(5,5))
plt.scatter(y_true_raw.numpy(), y_pred_pre_raw.numpy(), s=8, alpha=0.7)
mn = float(min(y_true_raw.min().item(), y_pred_pre_raw.min().item()))
mx = float(max(y_true_raw.max().item(), y_pred_pre_raw.max().item()))
plt.plot([mn, mx], [mn, mx], linestyle='--')
plt.xlabel('True (raw)')
plt.ylabel('Predicted (raw)')
plt.title('Observed vs Predicted (Validation, pre-adaptation)')
plt.show()

plt.figure(figsize=(5,5))
plt.scatter(y_true_raw.numpy(), y_pred_post_raw.numpy(), s=8, alpha=0.7)
mn = float(min(y_true_raw.min().item(), y_pred_post_raw.min().item()))
mx = float(max(y_true_raw.max().item(), y_pred_post_raw.max().item()))
plt.plot([mn, mx], [mn, mx], linestyle='--')
plt.xlabel('True (raw)')
plt.ylabel('Predicted (raw)')
plt.title('Observed vs Predicted (Validation, post-adaptation)')
plt.show()
# Out:
# [Z] Pre-adaptation  MSE: 0.336309, RMSE: 0.579922
# [Z] Post-adaptation MSE: 0.661486, RMSE: 0.813318
# [Z] ΔRMSE (pre - post):  -0.233396
# [RAW] Pre-adaptation  RMSE: 0.666691
# [RAW] Post-adaptation RMSE: 0.935009

# %% [markdown]
# ## (Optional) Explanations — top activated cases

# %%
# Enable explanation mode and inspect the top-k contributing cases for a few samples
model.top_k_mode = True
k = model.top_k  # how many top cases to display (see model.top_k_explain default too)

sample_idx = torch.arange(min(5, X_val.size(0)))  # first few
with torch.no_grad():
    final_pred, pred_vals, _, cases, labels, acts = model(X_val[sample_idx].to(device))

final_pred = final_pred * y_std_t + y_mean_t
labels = labels * y_std_t + y_mean_t

print("\n The first few cases and their most activated neighbors: ")
for i in range(len(sample_idx)):
    print(f"\nSample {i} (True: {y_val[sample_idx[i]].item():.4f}, Pred: {final_pred[i].item():.4f}):")
    topk_acts, topk_indices = torch.topk(acts[i], k=k)
    #print the sample itself
    print(f"  Sample features: {X_val[sample_idx[i]].cpu().numpy()}")
    accumulated_label = 0.0
    for rank in range(k):
        case_idx = topk_indices[rank].item()
        case_act = topk_acts[rank].item()
        case_feat = cases[i][rank].cpu().numpy()
        case_label = labels[i][rank].item()
        print(f"  Neighbor {rank+1}: Index {case_idx}, Activation {case_act:.4f}, Label {case_label:.4f}, Features {case_feat}")
        accumulated_label += case_label * case_act
    print(f"case activations multiply case labels:{accumulated_label}")
# Out:
#  The first few cases and their most activated neighbors:
#
# Sample 0 (True: 0.7420, Pred: 2.0291):
#   Sample features: [ 0.10116176  0.28090268 -0.34365004  1.1694758   0.41261685]
#   Neighbor 1: Index 0, Activation 0.3045, Label 2.3648, Features [ 0.17812113  0.37049493 -0.50250465  1.1534084   0.40866366]
#   Neighbor 2: Index 1, Activation 0.1607, Label 3.3019, Features [ 0.43058568 -0.05480435 -0.49892533  1.0221723   0.34975144]
#   Neighbor 3: Index 2, Activation 0.1095, Label 0.4823, Features [ 0.00190834  0.24992174 -0.83103126  0.7249738   0.2397863 ]
#   Neighbor 4: Index 3, Activation 0.0934, Label 0.3427, Features [-0.1073172   0.70492274  0.06290717  1.2716851   0.21065405]
#   Neighbor 5: Index 4, Activation 0.0727, Label 0.4850, Features [0.05469473 0.2812928  0.08331491 1.6915126  0.25516424]
#   Neighbor 6: Index 5, Activation 0.0712, Label 3.5787, Features [ 0.29532745  0.4488094  -1.4478868   1.4320129   0.60688305]
#   Neighbor 7: Index 6, Activation 0.0701, Label 0.9472, Features [-0.23488551  0.29637516 -0.42732787  0.44537532  0.60574174]
#   Neighbor 8: Index 7, Activation 0.0628, Label 1.6624, Features [-0.07086854  0.05593606 -0.5939644   0.98310393  0.55190474]
#   Neighbor 9: Index 8, Activation 0.0233, Label 1.3384, Features [0.45990106 0.5508604  0.23621999 1.1527628  0.25136903]
#   Neighbor 10: Index 9, Activation 0.0193, Label 2.3085, Features [-0.10260482  0.15106668 -1.4926491   0.95924056  0.5147171 ]
#   Neighbor 11: Index 10, Activation 0.0110, Label 0.8291, Features [-0.06928149  0.26177716 -0.67682135  1.5508963   0.10843352]
#   Neighbor 12: Index 11, Activation 0.0015, Label 1.6910, Features [-0.23023312  0.5459847   0.3488656   1.4582306   0.5421355 ]
#   Neighbor 13: Index 12, Activation 0.0000, Label 1.4925, Features [ 0.7050381  1.3120816 -1.0957417  0.0442711  0.584024 ]
#   Neighbor 14: Index 13, Activation 0.0000, Label -8.8695, Features [-1.9572417   1.1054946   0.01993194 -0.8709738   0.2110607 ]
#   Neighbor 15: Index 14, Activation 0.0000, Label 1.3194, Features [-1.2089705  -0.95133865  0.08509063  0.05936976  0.701434  ]
#   Neighbor 16: Index 15, Activation 0.0000, Label 0.6924, Features [-1.2778436  -0.7858232   2.1661963   0.31499243  0.8994238 ]
#   Neighbor 17: Index 16, Activation 0.0000, Label -9.0509, Features [-2.5545104   1.3564584  -0.51538026  0.70751995 -0.862952  ]
#   Neighbor 18: Index 17, Activation 0.0000, Label -4.7806, Features [-1.0027245   0.95789814 -1.7043116   1.5810525  -0.94057655]
#   Neighbor 19: Index 18, Activation 0.0000, Label 4.7620, Features [-0.7228717  -1.0635778  -1.2101126   0.23755023  1.2400916 ]
#   Neighbor 20: Index 19, Activation 0.0000, Label 1.7556, Features [ 0.5983173   0.42507586  1.4053191   1.126113   -0.07378596]
#   Neighbor 21: Index 20, Activation 0.0000, Label 3.2361, Features [-0.6413219  -1.8959925  -0.19174309  0.14081709  0.05344944]
#   Neighbor 22: Index 21, Activation 0.0000, Label 0.6791, Features [ 0.01165601  0.38167182 -0.04644571 -0.31831834  0.31959018]
#   Neighbor 23: Index 22, Activation 0.0000, Label 5.7095, Features [-0.11791248  0.6669063  -2.5317872   1.353939    1.9963126 ]
#   Neighbor 24: Index 23, Activation 0.0000, Label 2.4920, Features [ 1.3931694  -1.2651844  -0.3958946  -1.6762156  -0.08123998]
#   Neighbor 25: Index 24, Activation 0.0000, Label -1.8193, Features [ 0.47101998  0.55128217  0.9423355  -1.9956017  -0.04616585]
#   Neighbor 26: Index 25, Activation 0.0000, Label 1.7267, Features [-0.5172092  -0.87707275 -0.78810054  0.6489467   0.29928124]
#   Neighbor 27: Index 26, Activation 0.0000, Label 3.7437, Features [ 3.2267706  -0.10869756 -0.09908574 -0.13262323 -1.4529102 ]
#   Neighbor 28: Index 27, Activation 0.0000, Label -6.0474, Features [-1.2710639  -0.68942714  0.26341864  1.3690995  -2.0154514 ]
#   Neighbor 29: Index 28, Activation 0.0000, Label -1.0719, Features [ 0.7426288 -1.0701536 -0.7936088  1.164777  -1.3780818]
#   Neighbor 30: Index 29, Activation 0.0000, Label -8.0802, Features [-0.48576835  0.6459403  -0.11229443  0.4165808  -1.7724625 ]
#   Neighbor 31: Index 30, Activation 0.0000, Label -2.1984, Features [-0.32728523 -1.5953716   0.1805918   1.206297   -1.340802  ]
#   Neighbor 32: Index 31, Activation 0.0000, Label -7.2837, Features [-2.0998275   1.5765268   2.5927525  -0.15123731  0.19581193]
#   Neighbor 33: Index 32, Activation 0.0000, Label -3.3653, Features [-0.7574525  -1.0299623  -0.02763777 -0.37761936 -1.1372073 ]
#   Neighbor 34: Index 33, Activation 0.0000, Label -0.8511, Features [-1.8757879 -1.9338131  0.4846591  0.5206317  0.5731338]
#   Neighbor 35: Index 34, Activation 0.0000, Label 0.4216, Features [ 0.07115386  0.12316042 -1.0734009   0.80051786 -0.498972  ]
#   Neighbor 36: Index 35, Activation 0.0000, Label 4.8166, Features [ 0.16163395 -0.09045839  0.28772765  0.4648354   1.2586142 ]
#   Neighbor 37: Index 36, Activation 0.0000, Label 4.3282, Features [ 0.25639835 -0.11133689  0.7958195  -1.1480738   0.94444126]
#   Neighbor 38: Index 37, Activation 0.0000, Label 6.4419, Features [ 1.4796789  -0.96904975 -0.76967096 -1.2617589   0.87687284]
#   Neighbor 39: Index 38, Activation 0.0000, Label 5.4690, Features [0.70636743 0.04630924 0.6579562  0.7071902  0.6620716 ]
#   Neighbor 40: Index 39, Activation 0.0000, Label -4.7790, Features [-0.9502247  -0.15709159  1.0579629   0.15302205 -0.29699492]
# case activations multiply case labels:1.88376761656593
#
# Sample 1 (True: 0.3989, Pred: 1.0924):
#   Sample features: [ 0.6873436  0.3984625  1.7333994  1.1327175 -0.2655854]
#   Neighbor 1: Index 0, Activation 0.2780, Label 1.7556, Features [ 0.5983173   0.42507586  1.4053191   1.126113   -0.07378596]
#   Neighbor 2: Index 1, Activation 0.2319, Label 2.2469, Features [ 0.92674714  0.21312322  0.7202089   1.1979398  -0.3472772 ]
#   Neighbor 3: Index 2, Activation 0.2198, Label 0.1554, Features [ 0.4354438   0.3608081   0.78907514  1.1459067  -0.43556687]
#   Neighbor 4: Index 3, Activation 0.1848, Label -1.9034, Features [ 0.63488394  0.16989145  1.661012    1.2260777  -0.6506281 ]
#   Neighbor 5: Index 4, Activation 0.0648, Label 1.0285, Features [ 0.12778455  0.4480385   0.76635635  1.5029962  -0.14000906]
#   Neighbor 6: Index 5, Activation 0.0162, Label 1.0614, Features [0.3613461  0.57999873 0.94437605 0.63644856 0.21056928]
#   Neighbor 7: Index 6, Activation 0.0044, Label 0.6659, Features [ 0.3518373   0.7297038   1.4428359   0.65344733 -0.16593973]
#   Neighbor 8: Index 7, Activation 0.0000, Label 1.4925, Features [ 0.7050381  1.3120816 -1.0957417  0.0442711  0.584024 ]
#   Neighbor 9: Index 8, Activation 0.0000, Label -8.8695, Features [-1.9572417   1.1054946   0.01993194 -0.8709738   0.2110607 ]
#   Neighbor 10: Index 9, Activation 0.0000, Label 1.3194, Features [-1.2089705  -0.95133865  0.08509063  0.05936976  0.701434  ]
#   Neighbor 11: Index 10, Activation 0.0000, Label 0.6924, Features [-1.2778436  -0.7858232   2.1661963   0.31499243  0.8994238 ]
#   Neighbor 12: Index 11, Activation 0.0000, Label -9.0509, Features [-2.5545104   1.3564584  -0.51538026  0.70751995 -0.862952  ]
#   Neighbor 13: Index 12, Activation 0.0000, Label -4.7806, Features [-1.0027245   0.95789814 -1.7043116   1.5810525  -0.94057655]
#   Neighbor 14: Index 13, Activation 0.0000, Label 4.7620, Features [-0.7228717  -1.0635778  -1.2101126   0.23755023  1.2400916 ]
#   Neighbor 15: Index 14, Activation 0.0000, Label 3.2361, Features [-0.6413219  -1.8959925  -0.19174309  0.14081709  0.05344944]
#   Neighbor 16: Index 15, Activation 0.0000, Label 0.6791, Features [ 0.01165601  0.38167182 -0.04644571 -0.31831834  0.31959018]
#   Neighbor 17: Index 16, Activation 0.0000, Label 5.7095, Features [-0.11791248  0.6669063  -2.5317872   1.353939    1.9963126 ]
#   Neighbor 18: Index 17, Activation 0.0000, Label 2.4920, Features [ 1.3931694  -1.2651844  -0.3958946  -1.6762156  -0.08123998]
#   Neighbor 19: Index 18, Activation 0.0000, Label -1.8193, Features [ 0.47101998  0.55128217  0.9423355  -1.9956017  -0.04616585]
#   Neighbor 20: Index 19, Activation 0.0000, Label 1.7267, Features [-0.5172092  -0.87707275 -0.78810054  0.6489467   0.29928124]
#   Neighbor 21: Index 20, Activation 0.0000, Label 3.7437, Features [ 3.2267706  -0.10869756 -0.09908574 -0.13262323 -1.4529102 ]
#   Neighbor 22: Index 21, Activation 0.0000, Label -6.0474, Features [-1.2710639  -0.68942714  0.26341864  1.3690995  -2.0154514 ]
#   Neighbor 23: Index 22, Activation 0.0000, Label -1.0719, Features [ 0.7426288 -1.0701536 -0.7936088  1.164777  -1.3780818]
#   Neighbor 24: Index 23, Activation 0.0000, Label -8.0802, Features [-0.48576835  0.6459403  -0.11229443  0.4165808  -1.7724625 ]
#   Neighbor 25: Index 24, Activation 0.0000, Label -2.1984, Features [-0.32728523 -1.5953716   0.1805918   1.206297   -1.340802  ]
#   Neighbor 26: Index 25, Activation 0.0000, Label -7.2837, Features [-2.0998275   1.5765268   2.5927525  -0.15123731  0.19581193]
#   Neighbor 27: Index 26, Activation 0.0000, Label -3.3653, Features [-0.7574525  -1.0299623  -0.02763777 -0.37761936 -1.1372073 ]
#   Neighbor 28: Index 27, Activation 0.0000, Label -0.8511, Features [-1.8757879 -1.9338131  0.4846591  0.5206317  0.5731338]
#   Neighbor 29: Index 28, Activation 0.0000, Label 0.4216, Features [ 0.07115386  0.12316042 -1.0734009   0.80051786 -0.498972  ]
#   Neighbor 30: Index 29, Activation 0.0000, Label 4.8166, Features [ 0.16163395 -0.09045839  0.28772765  0.4648354   1.2586142 ]
#   Neighbor 31: Index 30, Activation 0.0000, Label 4.3282, Features [ 0.25639835 -0.11133689  0.7958195  -1.1480738   0.94444126]
#   Neighbor 32: Index 31, Activation 0.0000, Label 6.4419, Features [ 1.4796789  -0.96904975 -0.76967096 -1.2617589   0.87687284]
#   Neighbor 33: Index 32, Activation 0.0000, Label 5.4690, Features [0.70636743 0.04630924 0.6579562  0.7071902  0.6620716 ]
#   Neighbor 34: Index 33, Activation 0.0000, Label -4.7790, Features [-0.9502247  -0.15709159  1.0579629   0.15302205 -0.29699492]
#   Neighbor 35: Index 34, Activation 0.0000, Label -1.0129, Features [ 1.3993696 -0.237925  -0.5160629 -1.1781677 -1.4851475]
#   Neighbor 36: Index 35, Activation 0.0000, Label -5.6905, Features [ 0.76827693  1.8241379  -0.5501651  -0.68753475 -0.5673279 ]
#   Neighbor 37: Index 36, Activation 0.0000, Label 0.4968, Features [-1.2876467   0.16377153  0.8706905   0.25307423  0.8702751 ]
#   Neighbor 38: Index 37, Activation 0.0000, Label 4.3276, Features [-0.7313865  -1.830517    0.21224712 -1.4676735   1.4046111 ]
#   Neighbor 39: Index 38, Activation 0.0000, Label 8.2482, Features [ 1.3998686  -0.80732596 -0.01366528 -0.7942361   1.757353  ]
#   Neighbor 40: Index 39, Activation 0.0000, Label -1.2375, Features [-0.43093818 -0.5389923  -0.12975006 -1.0741143  -0.44717202]
# case activations multiply case labels:0.7782575800631553
#
# Sample 2 (True: -1.3972, Pred: -6.8112):
#   Sample features: [-0.7004179  -0.43797916  0.36869866 -0.55322224 -1.7802169 ]
#   Neighbor 1: Index 0, Activation 0.2356, Label -7.7569, Features [-0.69475394 -0.79965365 -0.05404326 -0.5233666  -2.2098925 ]
#   Neighbor 2: Index 1, Activation 0.1898, Label -6.1439, Features [-0.88823754 -0.35678262 -0.25760347  0.09255392 -1.6044905 ]
#   Neighbor 3: Index 2, Activation 0.1629, Label -4.1863, Features [-0.5592774  -0.3412526   0.25887278 -0.3940958  -1.2554473 ]
#   Neighbor 4: Index 3, Activation 0.1617, Label -10.2787, Features [-0.99771065 -0.30163962  0.79231375 -0.9561629  -2.311165  ]
#   Neighbor 5: Index 4, Activation 0.1272, Label -5.6683, Features [-0.79605085 -0.5696337   0.07874292 -0.78475976 -1.4186609 ]
#   Neighbor 6: Index 5, Activation 0.0533, Label -6.6387, Features [-0.501756   -0.26553765  0.5882756  -1.1533145  -1.5033038 ]
#   Neighbor 7: Index 6, Activation 0.0469, Label -8.3961, Features [-1.136427   -0.7423063  -0.6791179  -0.44424003 -1.5310435 ]
#   Neighbor 8: Index 7, Activation 0.0189, Label -8.6236, Features [-8.0006313e-01 -1.2316024e-03  6.6009212e-01  4.1119766e-01
#  -1.5482107e+00]
#   Neighbor 9: Index 8, Activation 0.0037, Label -5.2799, Features [-0.6405157  -0.41348732 -0.7312597  -0.1342408  -1.5399531 ]
#   Neighbor 10: Index 9, Activation 0.0000, Label 1.4925, Features [ 0.7050381  1.3120816 -1.0957417  0.0442711  0.584024 ]
#   Neighbor 11: Index 10, Activation 0.0000, Label -8.8695, Features [-1.9572417   1.1054946   0.01993194 -0.8709738   0.2110607 ]
#   Neighbor 12: Index 11, Activation 0.0000, Label 1.3194, Features [-1.2089705  -0.95133865  0.08509063  0.05936976  0.701434  ]
#   Neighbor 13: Index 12, Activation 0.0000, Label 0.6924, Features [-1.2778436  -0.7858232   2.1661963   0.31499243  0.8994238 ]
#   Neighbor 14: Index 13, Activation 0.0000, Label -9.0509, Features [-2.5545104   1.3564584  -0.51538026  0.70751995 -0.862952  ]
#   Neighbor 15: Index 14, Activation 0.0000, Label -4.7806, Features [-1.0027245   0.95789814 -1.7043116   1.5810525  -0.94057655]
#   Neighbor 16: Index 15, Activation 0.0000, Label 4.7620, Features [-0.7228717  -1.0635778  -1.2101126   0.23755023  1.2400916 ]
#   Neighbor 17: Index 16, Activation 0.0000, Label 1.7556, Features [ 0.5983173   0.42507586  1.4053191   1.126113   -0.07378596]
#   Neighbor 18: Index 17, Activation 0.0000, Label 3.2361, Features [-0.6413219  -1.8959925  -0.19174309  0.14081709  0.05344944]
#   Neighbor 19: Index 18, Activation 0.0000, Label 0.6791, Features [ 0.01165601  0.38167182 -0.04644571 -0.31831834  0.31959018]
#   Neighbor 20: Index 19, Activation 0.0000, Label 5.7095, Features [-0.11791248  0.6669063  -2.5317872   1.353939    1.9963126 ]
#   Neighbor 21: Index 20, Activation 0.0000, Label 2.4920, Features [ 1.3931694  -1.2651844  -0.3958946  -1.6762156  -0.08123998]
#   Neighbor 22: Index 21, Activation 0.0000, Label -1.8193, Features [ 0.47101998  0.55128217  0.9423355  -1.9956017  -0.04616585]
#   Neighbor 23: Index 22, Activation 0.0000, Label 1.7267, Features [-0.5172092  -0.87707275 -0.78810054  0.6489467   0.29928124]
#   Neighbor 24: Index 23, Activation 0.0000, Label 3.7437, Features [ 3.2267706  -0.10869756 -0.09908574 -0.13262323 -1.4529102 ]
#   Neighbor 25: Index 24, Activation 0.0000, Label -6.0474, Features [-1.2710639  -0.68942714  0.26341864  1.3690995  -2.0154514 ]
#   Neighbor 26: Index 25, Activation 0.0000, Label -1.0719, Features [ 0.7426288 -1.0701536 -0.7936088  1.164777  -1.3780818]
#   Neighbor 27: Index 26, Activation 0.0000, Label -8.0802, Features [-0.48576835  0.6459403  -0.11229443  0.4165808  -1.7724625 ]
#   Neighbor 28: Index 27, Activation 0.0000, Label -2.1984, Features [-0.32728523 -1.5953716   0.1805918   1.206297   -1.340802  ]
#   Neighbor 29: Index 28, Activation 0.0000, Label -7.2837, Features [-2.0998275   1.5765268   2.5927525  -0.15123731  0.19581193]
#   Neighbor 30: Index 29, Activation 0.0000, Label -3.3653, Features [-0.7574525  -1.0299623  -0.02763777 -0.37761936 -1.1372073 ]
#   Neighbor 31: Index 30, Activation 0.0000, Label -0.8511, Features [-1.8757879 -1.9338131  0.4846591  0.5206317  0.5731338]
#   Neighbor 32: Index 31, Activation 0.0000, Label 0.4216, Features [ 0.07115386  0.12316042 -1.0734009   0.80051786 -0.498972  ]
#   Neighbor 33: Index 32, Activation 0.0000, Label 4.8166, Features [ 0.16163395 -0.09045839  0.28772765  0.4648354   1.2586142 ]
#   Neighbor 34: Index 33, Activation 0.0000, Label 4.3282, Features [ 0.25639835 -0.11133689  0.7958195  -1.1480738   0.94444126]
#   Neighbor 35: Index 34, Activation 0.0000, Label 6.4419, Features [ 1.4796789  -0.96904975 -0.76967096 -1.2617589   0.87687284]
#   Neighbor 36: Index 35, Activation 0.0000, Label 5.4690, Features [0.70636743 0.04630924 0.6579562  0.7071902  0.6620716 ]
#   Neighbor 37: Index 36, Activation 0.0000, Label -4.7790, Features [-0.9502247  -0.15709159  1.0579629   0.15302205 -0.29699492]
#   Neighbor 38: Index 37, Activation 0.0000, Label -1.0129, Features [ 1.3993696 -0.237925  -0.5160629 -1.1781677 -1.4851475]
#   Neighbor 39: Index 38, Activation 0.0000, Label -5.6905, Features [ 0.76827693  1.8241379  -0.5501651  -0.68753475 -0.5673279 ]
#   Neighbor 40: Index 39, Activation 0.0000, Label 0.4968, Features [-1.2876467   0.16377153  0.8706905   0.25307423  0.8702751 ]
# case activations multiply case labels:-6.988952782301842
#
# Sample 3 (True: -0.6652, Pred: -1.0344):
#   Sample features: [-0.75766903  0.43209    -0.6107686  -0.05447528  0.28155217]
#   Neighbor 1: Index 0, Activation 0.2815, Label -1.0907, Features [-0.6840076   0.27647054 -0.7328393  -0.04782474  0.01354026]
#   Neighbor 2: Index 1, Activation 0.1708, Label 0.2580, Features [-0.6891327   0.46711496 -1.4109293   0.11649198  0.58867073]
#   Neighbor 3: Index 2, Activation 0.1162, Label 1.2522, Features [-0.43626577  0.37298745 -0.153586    0.20869741  0.45613304]
#   Neighbor 4: Index 3, Activation 0.1036, Label 0.1851, Features [-0.48295775 -0.03239803 -0.9763475   0.42052215  0.2233956 ]
#   Neighbor 5: Index 4, Activation 0.0930, Label -2.4682, Features [-0.7106729   0.9188228  -0.40151927 -0.50421405  0.43649045]
#   Neighbor 6: Index 5, Activation 0.0717, Label -2.1203, Features [-1.0407233  -0.10515002 -0.9054274   0.20793469  0.056063  ]
#   Neighbor 7: Index 6, Activation 0.0415, Label -2.2477, Features [-1.0509081   0.15444167  0.00186865 -0.05540055 -0.07627951]
#   Neighbor 8: Index 7, Activation 0.0385, Label 0.9472, Features [-0.23488551  0.29637516 -0.42732787  0.44537532  0.60574174]
#   Neighbor 9: Index 8, Activation 0.0380, Label -1.2520, Features [-1.0838943   0.01284054  0.10207535  0.16653475  0.37023836]
#   Neighbor 10: Index 9, Activation 0.0257, Label -1.1934, Features [-1.0151372   0.3411809   0.6067476  -0.41611838  0.41317832]
#   Neighbor 11: Index 10, Activation 0.0170, Label -4.1007, Features [-0.7883712   0.6758762  -0.26571408  0.13506322 -0.21380983]
#   Neighbor 12: Index 11, Activation 0.0025, Label 0.2310, Features [-0.5823531  -0.23636529 -0.6890529   0.13268374  0.02584007]
#   Neighbor 13: Index 12, Activation 0.0000, Label 1.4925, Features [ 0.7050381  1.3120816 -1.0957417  0.0442711  0.584024 ]
#   Neighbor 14: Index 13, Activation 0.0000, Label -8.8695, Features [-1.9572417   1.1054946   0.01993194 -0.8709738   0.2110607 ]
#   Neighbor 15: Index 14, Activation 0.0000, Label 1.3194, Features [-1.2089705  -0.95133865  0.08509063  0.05936976  0.701434  ]
#   Neighbor 16: Index 15, Activation 0.0000, Label 0.6924, Features [-1.2778436  -0.7858232   2.1661963   0.31499243  0.8994238 ]
#   Neighbor 17: Index 16, Activation 0.0000, Label -9.0509, Features [-2.5545104   1.3564584  -0.51538026  0.70751995 -0.862952  ]
#   Neighbor 18: Index 17, Activation 0.0000, Label -4.7806, Features [-1.0027245   0.95789814 -1.7043116   1.5810525  -0.94057655]
#   Neighbor 19: Index 18, Activation 0.0000, Label 4.7620, Features [-0.7228717  -1.0635778  -1.2101126   0.23755023  1.2400916 ]
#   Neighbor 20: Index 19, Activation 0.0000, Label 1.7556, Features [ 0.5983173   0.42507586  1.4053191   1.126113   -0.07378596]
#   Neighbor 21: Index 20, Activation 0.0000, Label 3.2361, Features [-0.6413219  -1.8959925  -0.19174309  0.14081709  0.05344944]
#   Neighbor 22: Index 21, Activation 0.0000, Label 0.6791, Features [ 0.01165601  0.38167182 -0.04644571 -0.31831834  0.31959018]
#   Neighbor 23: Index 22, Activation 0.0000, Label 5.7095, Features [-0.11791248  0.6669063  -2.5317872   1.353939    1.9963126 ]
#   Neighbor 24: Index 23, Activation 0.0000, Label 2.4920, Features [ 1.3931694  -1.2651844  -0.3958946  -1.6762156  -0.08123998]
#   Neighbor 25: Index 24, Activation 0.0000, Label -1.8193, Features [ 0.47101998  0.55128217  0.9423355  -1.9956017  -0.04616585]
#   Neighbor 26: Index 25, Activation 0.0000, Label 1.7267, Features [-0.5172092  -0.87707275 -0.78810054  0.6489467   0.29928124]
#   Neighbor 27: Index 26, Activation 0.0000, Label 3.7437, Features [ 3.2267706  -0.10869756 -0.09908574 -0.13262323 -1.4529102 ]
#   Neighbor 28: Index 27, Activation 0.0000, Label -6.0474, Features [-1.2710639  -0.68942714  0.26341864  1.3690995  -2.0154514 ]
#   Neighbor 29: Index 28, Activation 0.0000, Label -1.0719, Features [ 0.7426288 -1.0701536 -0.7936088  1.164777  -1.3780818]
#   Neighbor 30: Index 29, Activation 0.0000, Label -8.0802, Features [-0.48576835  0.6459403  -0.11229443  0.4165808  -1.7724625 ]
#   Neighbor 31: Index 30, Activation 0.0000, Label -2.1984, Features [-0.32728523 -1.5953716   0.1805918   1.206297   -1.340802  ]
#   Neighbor 32: Index 31, Activation 0.0000, Label -7.2837, Features [-2.0998275   1.5765268   2.5927525  -0.15123731  0.19581193]
#   Neighbor 33: Index 32, Activation 0.0000, Label -3.3653, Features [-0.7574525  -1.0299623  -0.02763777 -0.37761936 -1.1372073 ]
#   Neighbor 34: Index 33, Activation 0.0000, Label -0.8511, Features [-1.8757879 -1.9338131  0.4846591  0.5206317  0.5731338]
#   Neighbor 35: Index 34, Activation 0.0000, Label 0.4216, Features [ 0.07115386  0.12316042 -1.0734009   0.80051786 -0.498972  ]
#   Neighbor 36: Index 35, Activation 0.0000, Label 4.8166, Features [ 0.16163395 -0.09045839  0.28772765  0.4648354   1.2586142 ]
#   Neighbor 37: Index 36, Activation 0.0000, Label 4.3282, Features [ 0.25639835 -0.11133689  0.7958195  -1.1480738   0.94444126]
#   Neighbor 38: Index 37, Activation 0.0000, Label 6.4419, Features [ 1.4796789  -0.96904975 -0.76967096 -1.2617589   0.87687284]
#   Neighbor 39: Index 38, Activation 0.0000, Label 5.4690, Features [0.70636743 0.04630924 0.6579562  0.7071902  0.6620716 ]
#   Neighbor 40: Index 39, Activation 0.0000, Label -4.7790, Features [-0.9502247  -0.15709159  1.0579629   0.15302205 -0.29699492]
# case activations multiply case labels:-0.6835069453310582
#
# Sample 4 (True: 1.4250, Pred: 5.8413):
#   Sample features: [-2.7547052  -1.893696    0.94438094  0.09729501  2.7360997 ]
#   Neighbor 1: Index 0, Activation 0.6736, Label 5.3736, Features [-2.5279171e+00 -2.5181587e+00  6.5017043e-04 -5.7786983e-01
#   2.0001161e+00]
#   Neighbor 2: Index 1, Activation 0.2026, Label -0.0153, Features [-2.7132304 -0.6107025  1.2159308 -0.5022539  2.1746583]
#   Neighbor 3: Index 2, Activation 0.1238, Label 6.1384, Features [-1.7373672  -1.2831852   0.85936373  0.5750527   2.0107136 ]
#   Neighbor 4: Index 3, Activation 0.0000, Label 1.4925, Features [ 0.7050381  1.3120816 -1.0957417  0.0442711  0.584024 ]
#   Neighbor 5: Index 4, Activation 0.0000, Label -8.8695, Features [-1.9572417   1.1054946   0.01993194 -0.8709738   0.2110607 ]
#   Neighbor 6: Index 5, Activation 0.0000, Label 1.3194, Features [-1.2089705  -0.95133865  0.08509063  0.05936976  0.701434  ]
#   Neighbor 7: Index 6, Activation 0.0000, Label 0.6924, Features [-1.2778436  -0.7858232   2.1661963   0.31499243  0.8994238 ]
#   Neighbor 8: Index 7, Activation 0.0000, Label -9.0509, Features [-2.5545104   1.3564584  -0.51538026  0.70751995 -0.862952  ]
#   Neighbor 9: Index 8, Activation 0.0000, Label -4.7806, Features [-1.0027245   0.95789814 -1.7043116   1.5810525  -0.94057655]
#   Neighbor 10: Index 9, Activation 0.0000, Label 4.7620, Features [-0.7228717  -1.0635778  -1.2101126   0.23755023  1.2400916 ]
#   Neighbor 11: Index 10, Activation 0.0000, Label 1.7556, Features [ 0.5983173   0.42507586  1.4053191   1.126113   -0.07378596]
#   Neighbor 12: Index 11, Activation 0.0000, Label 3.2361, Features [-0.6413219  -1.8959925  -0.19174309  0.14081709  0.05344944]
#   Neighbor 13: Index 12, Activation 0.0000, Label 0.6791, Features [ 0.01165601  0.38167182 -0.04644571 -0.31831834  0.31959018]
#   Neighbor 14: Index 13, Activation 0.0000, Label 5.7095, Features [-0.11791248  0.6669063  -2.5317872   1.353939    1.9963126 ]
#   Neighbor 15: Index 14, Activation 0.0000, Label 2.4920, Features [ 1.3931694  -1.2651844  -0.3958946  -1.6762156  -0.08123998]
#   Neighbor 16: Index 15, Activation 0.0000, Label -1.8193, Features [ 0.47101998  0.55128217  0.9423355  -1.9956017  -0.04616585]
#   Neighbor 17: Index 16, Activation 0.0000, Label 1.7267, Features [-0.5172092  -0.87707275 -0.78810054  0.6489467   0.29928124]
#   Neighbor 18: Index 17, Activation 0.0000, Label 3.7437, Features [ 3.2267706  -0.10869756 -0.09908574 -0.13262323 -1.4529102 ]
#   Neighbor 19: Index 18, Activation 0.0000, Label -6.0474, Features [-1.2710639  -0.68942714  0.26341864  1.3690995  -2.0154514 ]
#   Neighbor 20: Index 19, Activation 0.0000, Label -1.0719, Features [ 0.7426288 -1.0701536 -0.7936088  1.164777  -1.3780818]
#   Neighbor 21: Index 20, Activation 0.0000, Label -8.0802, Features [-0.48576835  0.6459403  -0.11229443  0.4165808  -1.7724625 ]
#   Neighbor 22: Index 21, Activation 0.0000, Label -2.1984, Features [-0.32728523 -1.5953716   0.1805918   1.206297   -1.340802  ]
#   Neighbor 23: Index 22, Activation 0.0000, Label -7.2837, Features [-2.0998275   1.5765268   2.5927525  -0.15123731  0.19581193]
#   Neighbor 24: Index 23, Activation 0.0000, Label -3.3653, Features [-0.7574525  -1.0299623  -0.02763777 -0.37761936 -1.1372073 ]
#   Neighbor 25: Index 24, Activation 0.0000, Label -0.8511, Features [-1.8757879 -1.9338131  0.4846591  0.5206317  0.5731338]
#   Neighbor 26: Index 25, Activation 0.0000, Label 0.4216, Features [ 0.07115386  0.12316042 -1.0734009   0.80051786 -0.498972  ]
#   Neighbor 27: Index 26, Activation 0.0000, Label 4.8166, Features [ 0.16163395 -0.09045839  0.28772765  0.4648354   1.2586142 ]
#   Neighbor 28: Index 27, Activation 0.0000, Label 4.3282, Features [ 0.25639835 -0.11133689  0.7958195  -1.1480738   0.94444126]
#   Neighbor 29: Index 28, Activation 0.0000, Label 6.4419, Features [ 1.4796789  -0.96904975 -0.76967096 -1.2617589   0.87687284]
#   Neighbor 30: Index 29, Activation 0.0000, Label 5.4690, Features [0.70636743 0.04630924 0.6579562  0.7071902  0.6620716 ]
#   Neighbor 31: Index 30, Activation 0.0000, Label -4.7790, Features [-0.9502247  -0.15709159  1.0579629   0.15302205 -0.29699492]
#   Neighbor 32: Index 31, Activation 0.0000, Label -1.0129, Features [ 1.3993696 -0.237925  -0.5160629 -1.1781677 -1.4851475]
#   Neighbor 33: Index 32, Activation 0.0000, Label -5.6905, Features [ 0.76827693  1.8241379  -0.5501651  -0.68753475 -0.5673279 ]
#   Neighbor 34: Index 33, Activation 0.0000, Label 0.4968, Features [-1.2876467   0.16377153  0.8706905   0.25307423  0.8702751 ]
#   Neighbor 35: Index 34, Activation 0.0000, Label 4.3276, Features [-0.7313865  -1.830517    0.21224712 -1.4676735   1.4046111 ]
#   Neighbor 36: Index 35, Activation 0.0000, Label 8.2482, Features [ 1.3998686  -0.80732596 -0.01366528 -0.7942361   1.757353  ]
#   Neighbor 37: Index 36, Activation 0.0000, Label -1.2375, Features [-0.43093818 -0.5389923  -0.12975006 -1.0741143  -0.44717202]
#   Neighbor 38: Index 37, Activation 0.0000, Label 5.0696, Features [ 0.48973563 -1.0321254   0.18612374 -0.368607    0.7246656 ]
#   Neighbor 39: Index 38, Activation 0.0000, Label -2.3642, Features [-0.51561797 -0.02151416 -0.5046236   0.29718727 -0.4232281 ]
#   Neighbor 40: Index 39, Activation 0.0000, Label -2.9195, Features [-0.43867067 -0.06347954 -1.1814249  -1.293592   -0.41897866]
# case activations multiply case labels:4.37657341983087

# %%
#print out model weights for cases
print("\nGlocal Feature Weights:")
for i, fw in enumerate(model.glocal_weightor.feature_weights):
    print(f" Feature Weightor {i+1}: Weights: {fw}")

# for i, cw in enumerate(model.weights):
#     print(f" Case {i+1}: Weights: {cw}")
# Out:
# Glocal Feature Weights:
#  Feature Weightor 1: Weights: tensor([0.9303, 0.6281, 0.1910, 0.4156, 0.9493], device='cuda:0')

# %%
for i, cb in enumerate(model.biases):
    print(f" Case {i+1}: biases: {cb}")
# Out:
#  Case 1: biases: -0.05121937394142151
#  Case 2: biases: 0.04184364527463913
#  Case 3: biases: 0.012342185713350773
#  Case 4: biases: -1.5947254723869264e-05
#  Case 5: biases: 0.09445814788341522
#  Case 6: biases: 0.11211098730564117
#  Case 7: biases: 0.013775235041975975
#  Case 8: biases: -0.08827827125787735
#  Case 9: biases: 0.08931104838848114
#  Case 10: biases: 0.1261523962020874
#  Case 11: biases: 0.05427481234073639
#  Case 12: biases: -0.11705224961042404
#  Case 13: biases: -0.06183934584259987
#  Case 14: biases: -0.10364057123661041
#  Case 15: biases: -0.10973528027534485
#  Case 16: biases: -0.11380130797624588
#  Case 17: biases: -0.030011579394340515
#  Case 18: biases: 0.017874211072921753
#  Case 19: biases: 0.05723975598812103
#  Case 20: biases: 0.016260871663689613
#  Case 21: biases: -0.0804751068353653
#  Case 22: biases: -0.092520572245121
#  Case 23: biases: 0.04656539857387543
#  Case 24: biases: -0.01548167783766985
#  Case 25: biases: -0.0076560042798519135
#  Case 26: biases: 0.025150220841169357
#  Case 27: biases: 0.020843505859375
#  Case 28: biases: 0.006343841552734375
#  Case 29: biases: 0.03351595997810364
#  Case 30: biases: 0.14080730080604553
#  Case 31: biases: -0.09194062650203705
#  Case 32: biases: 0.03512564301490784
#  Case 33: biases: -0.09355814009904861
#  Case 34: biases: 0.001568639767356217
#  Case 35: biases: -0.054097775369882584
#  Case 36: biases: -0.13209643959999084
#  Case 37: biases: -0.08833999931812286
#  Case 38: biases: 0.09420234709978104
#  Case 39: biases: 0.0014160607242956758
#  Case 40: biases: 0.029718028381466866
#  Case 41: biases: -0.05277791619300842
#  Case 42: biases: 0.13750585913658142
#  Case 43: biases: -0.04276541247963905
#  Case 44: biases: 0.05957590043544769
#  Case 45: biases: -0.025151899084448814
#  Case 46: biases: 0.031187251210212708
#  Case 47: biases: -0.04003283008933067
#  Case 48: biases: -0.12887009978294373
#  Case 49: biases: -0.05259869247674942
#  Case 50: biases: -0.060995686799287796
#  Case 51: biases: -0.06828510761260986
#  Case 52: biases: 0.004052311182022095
#  Case 53: biases: 0.08209347724914551
#  Case 54: biases: 0.08379321545362473
#  Case 55: biases: 0.02851773239672184
#  Case 56: biases: 0.06797996908426285
#  Case 57: biases: 0.047244127839803696
#  Case 58: biases: -0.10342614352703094
#  Case 59: biases: 0.01607433706521988
#  Case 60: biases: 0.05130705237388611
#  Case 61: biases: 0.021979931741952896
#  Case 62: biases: -0.11198621243238449
#  Case 63: biases: -0.1268935352563858
#  Case 64: biases: 0.06074037775397301
#  Case 65: biases: 0.0018471466610208154
#  Case 66: biases: 0.07377240061759949
#  Case 67: biases: -0.007167378440499306
#  Case 68: biases: 0.06414280831813812
#  Case 69: biases: 0.010374180972576141
#  Case 70: biases: -0.01488528773188591
#  Case 71: biases: 0.025726381689310074
#  Case 72: biases: 0.04166542366147041
#  Case 73: biases: -0.0737689733505249
#  Case 74: biases: 0.07581701129674911
#  Case 75: biases: -0.07538526505231857
#  Case 76: biases: -0.03342568501830101
#  Case 77: biases: 0.010186968371272087
#  Case 78: biases: 0.15167935192584991
#  Case 79: biases: -0.05683910846710205
#  Case 80: biases: 0.026163442060351372
#  Case 81: biases: 0.03452938422560692
#  Case 82: biases: 0.014142366126179695
#  Case 83: biases: 0.0030110878869891167
#  Case 84: biases: 0.05532652139663696
#  Case 85: biases: 0.040410034358501434
#  Case 86: biases: 0.10518307983875275
#  Case 87: biases: -0.05451827868819237
#  Case 88: biases: 0.02923690155148506
#  Case 89: biases: -0.000869319133926183
#  Case 90: biases: 0.021837975829839706
#  Case 91: biases: -0.03649992123246193
#  Case 92: biases: -0.08111598342657089
#  Case 93: biases: 0.030778348445892334
#  Case 94: biases: -0.09967689216136932
#  Case 95: biases: -0.08034273236989975
#  Case 96: biases: 0.021222038194537163
#  Case 97: biases: 0.05345327407121658
#  Case 98: biases: -0.12788891792297363
#  Case 99: biases: -0.035911675542593
#  Case 100: biases: -0.07991013675928116
#  Case 101: biases: -0.019098103046417236
#  Case 102: biases: -0.11036882549524307
#  Case 103: biases: -0.08023392409086227
#  Case 104: biases: 0.0602586530148983
#  Case 105: biases: 0.02762424200773239
#  Case 106: biases: -0.07831524312496185
#  Case 107: biases: 0.12725137174129486
#  Case 108: biases: 0.05013769119977951
#  Case 109: biases: -0.0865919291973114
#  Case 110: biases: 0.055500537157058716
#  Case 111: biases: -0.06957882642745972
#  Case 112: biases: -0.07862637937068939
#  Case 113: biases: 0.05428193137049675
#  Case 114: biases: 0.005184190813452005
#  Case 115: biases: 0.05891857296228409
#  Case 116: biases: -0.09583570063114166
#  Case 117: biases: 0.0681392252445221
#  Case 118: biases: 0.012545309029519558
#  Case 119: biases: 0.02376582659780979
#  Case 120: biases: -0.07344826310873032
#  Case 121: biases: -0.08402471244335175
#  Case 122: biases: -0.017500579357147217
#  Case 123: biases: 0.08319436758756638
#  Case 124: biases: 0.12632909417152405
#  Case 125: biases: -0.06895525008440018
#  Case 126: biases: -0.06603726744651794
#  Case 127: biases: 0.05691489949822426
#  Case 128: biases: -0.02352863922715187
#  Case 129: biases: -0.07449980825185776
#  Case 130: biases: -0.045526742935180664
#  Case 131: biases: -0.04709208756685257
#  Case 132: biases: 0.02701750583946705
#  Case 133: biases: -0.051494989544153214
#  Case 134: biases: -0.06983686983585358
#  Case 135: biases: -0.03594015911221504
#  Case 136: biases: 0.05313384532928467
#  Case 137: biases: 0.12423780560493469
#  Case 138: biases: -0.044628970324993134
#  Case 139: biases: -0.06577534228563309
#  Case 140: biases: -0.07419150322675705
#  Case 141: biases: -0.06181929260492325
#  Case 142: biases: -0.024896692484617233
#  Case 143: biases: -0.10754314064979553
#  Case 144: biases: 0.11033989489078522
#  Case 145: biases: 0.11916907131671906
#  Case 146: biases: -0.03410394862294197
#  Case 147: biases: -0.044790931046009064
#  Case 148: biases: -0.00816124677658081
#  Case 149: biases: 0.09771161526441574
#  Case 150: biases: 0.019517695531249046
#  Case 151: biases: 0.004434656817466021
#  Case 152: biases: 0.038145873695611954
#  Case 153: biases: 0.022266313433647156
#  Case 154: biases: 0.12966233491897583
#  Case 155: biases: -0.0279572494328022
#  Case 156: biases: -0.01849137619137764
#  Case 157: biases: -0.11548762023448944
#  Case 158: biases: 0.014509592205286026
#  Case 159: biases: -0.0243984442204237
#  Case 160: biases: -0.06135605648159981
#  Case 161: biases: 0.12392289191484451
#  Case 162: biases: -0.03747205808758736
#  Case 163: biases: 0.12049977481365204
#  Case 164: biases: 0.016241364181041718
#  Case 165: biases: 0.040423016995191574
#  Case 166: biases: 0.034327130764722824
#  Case 167: biases: -0.0041557298973202705
#  Case 168: biases: 0.08038780838251114
#  Case 169: biases: 0.018640771508216858
#  Case 170: biases: -0.10163958370685577
#  Case 171: biases: -0.03339584544301033
#  Case 172: biases: 0.02547040954232216
#  Case 173: biases: 0.08324575424194336
#  Case 174: biases: -0.07807102799415588
#  Case 175: biases: -0.05429678037762642
#  Case 176: biases: 0.06863706558942795
#  Case 177: biases: 0.10468272864818573
#  Case 178: biases: -0.020878007635474205
#  Case 179: biases: 0.12560774385929108
#  Case 180: biases: 0.03913356363773346
#  Case 181: biases: -0.02072569541633129
#  Case 182: biases: -0.05142703652381897
#  Case 183: biases: 0.03832855820655823
#  Case 184: biases: -0.06676895916461945
#  Case 185: biases: -0.010804673656821251
#  Case 186: biases: 0.050778016448020935
#  Case 187: biases: -0.055214773863554
#  Case 188: biases: -0.07479941844940186
#  Case 189: biases: -0.07560642808675766
#  Case 190: biases: 0.04183518514037132
#  Case 191: biases: -0.021189920604228973
#  Case 192: biases: -0.05269668996334076
#  Case 193: biases: -0.050393156707286835
#  Case 194: biases: -0.04817467927932739
#  Case 195: biases: -0.06421003490686417
#  Case 196: biases: 0.010441344231367111
#  Case 197: biases: 0.12346109747886658
#  Case 198: biases: -0.03416876122355461
#  Case 199: biases: -0.006475027650594711
#  Case 200: biases: -0.006222253665328026
#  Case 201: biases: -0.07589637488126755
#  Case 202: biases: -0.07651063799858093
#  Case 203: biases: -0.03954864293336868
#  Case 204: biases: 0.009580504149198532
#  Case 205: biases: -0.1032305508852005
#  Case 206: biases: 0.06117072328925133
#  Case 207: biases: -0.025637920945882797
#  Case 208: biases: -0.02291065640747547
#  Case 209: biases: 0.031579796224832535
#  Case 210: biases: -0.05637809634208679
#  Case 211: biases: -0.017221402376890182
#  Case 212: biases: -0.09415409713983536
#  Case 213: biases: -0.10962117463350296
#  Case 214: biases: 0.08014647662639618
#  Case 215: biases: 0.09819888323545456
#  Case 216: biases: -0.12566664814949036
#  Case 217: biases: 0.06043510511517525
#  Case 218: biases: 0.011394169181585312
#  Case 219: biases: -0.14247283339500427
#  Case 220: biases: 0.027827966958284378
#  Case 221: biases: 0.035939671099185944
#  Case 222: biases: 0.05016517639160156
#  Case 223: biases: -0.09675770252943039
#  Case 224: biases: -0.03707265481352806
#  Case 225: biases: 0.03193238750100136
#  Case 226: biases: -0.03240020573139191
#  Case 227: biases: -0.07118251174688339
#  Case 228: biases: 0.045902956277132034
#  Case 229: biases: 0.06147610396146774
#  Case 230: biases: -0.021994009613990784
#  Case 231: biases: 0.013876833021640778
#  Case 232: biases: -0.12144818156957626
#  Case 233: biases: 0.021399298682808876
#  Case 234: biases: -0.10417299717664719
#  Case 235: biases: -0.06708671152591705
#  Case 236: biases: 0.028673574328422546
#  Case 237: biases: -0.003222427796572447
#  Case 238: biases: 0.008066480979323387
#  Case 239: biases: 0.03290348872542381
#  Case 240: biases: -0.12000212073326111
#  Case 241: biases: -0.03497584909200668
#  Case 242: biases: -0.08519072830677032
#  Case 243: biases: 0.0382063202559948
#  Case 244: biases: 0.11926882714033127
#  Case 245: biases: -0.051297951489686966
#  Case 246: biases: -0.09679792821407318
#  Case 247: biases: -0.10893743485212326
#  Case 248: biases: -0.04651172459125519
#  Case 249: biases: -0.06793256849050522
#  Case 250: biases: -0.08735579252243042
#  Case 251: biases: -0.050954561680555344
#  Case 252: biases: -0.047666408121585846
#  Case 253: biases: 0.10795975476503372
#  Case 254: biases: 0.1488584578037262
#  Case 255: biases: 0.054413676261901855
#  Case 256: biases: 0.030676288530230522
#  Case 257: biases: -0.07072454690933228
#  Case 258: biases: -0.0034265832509845495
#  Case 259: biases: -0.009091874584555626
#  Case 260: biases: 0.08431483805179596
#  Case 261: biases: -0.12025222927331924
#  Case 262: biases: 0.10368991643190384
#  Case 263: biases: -0.008972500450909138
#  Case 264: biases: -0.01762985624372959
#  Case 265: biases: -0.11571965366601944
#  Case 266: biases: 0.029120778664946556
#  Case 267: biases: 0.10393370687961578
#  Case 268: biases: -0.08105108886957169
#  Case 269: biases: 0.019281554967164993
#  Case 270: biases: -0.08216354995965958
#  Case 271: biases: 0.12150585651397705
#  Case 272: biases: 0.11026786267757416
#  Case 273: biases: 0.035698626190423965
#  Case 274: biases: 0.015048947185277939
#  Case 275: biases: -0.004375473130494356
#  Case 276: biases: -0.01907539553940296
#  Case 277: biases: 0.07788751274347305
#  Case 278: biases: 0.061217837035655975
#  Case 279: biases: 0.11097587645053864
#  Case 280: biases: 0.007250391412526369
#  Case 281: biases: -0.014013498090207577
#  Case 282: biases: 0.031066562980413437
#  Case 283: biases: -0.10136520117521286
#  Case 284: biases: -0.11236853152513504
#  Case 285: biases: -0.07306965440511703
#  Case 286: biases: -0.016500504687428474
#  Case 287: biases: -0.04015214368700981
#  Case 288: biases: -0.045144420117139816
#  Case 289: biases: -0.012170328758656979
#  Case 290: biases: 0.016365107148885727
#  Case 291: biases: -0.03654251992702484
#  Case 292: biases: 0.12984943389892578
#  Case 293: biases: 0.04170006141066551
#  Case 294: biases: -0.06413991749286652
#  Case 295: biases: 0.07823510468006134
#  Case 296: biases: -0.0071126134134829044
#  Case 297: biases: 0.09836786240339279
#  Case 298: biases: 0.038098499178886414
#  Case 299: biases: -0.007389378733932972
#  Case 300: biases: 0.07463613152503967
#  Case 301: biases: 0.025960229337215424
#  Case 302: biases: 0.014529203996062279
#  Case 303: biases: 0.008073892444372177
#  Case 304: biases: 0.026361294090747833
#  Case 305: biases: 0.04519817605614662
#  Case 306: biases: -0.12161856144666672
#  Case 307: biases: -0.11717963963747025
#  Case 308: biases: -0.02466477081179619
#  Case 309: biases: 0.117264024913311
#  Case 310: biases: -0.05605551227927208
#  Case 311: biases: 0.04497803747653961
#  Case 312: biases: 0.08111852407455444
#  Case 313: biases: -0.0542425774037838
#  Case 314: biases: -0.05950299650430679
#  Case 315: biases: -0.11496900022029877
#  Case 316: biases: 0.11274512857198715
#  Case 317: biases: -0.13430264592170715
#  Case 318: biases: -0.03797372430562973
#  Case 319: biases: -0.06042616814374924
#  Case 320: biases: -0.0025433190166950226
#  Case 321: biases: -0.038460973650217056
#  Case 322: biases: 0.05872496962547302
#  Case 323: biases: 0.020737579092383385
#  Case 324: biases: -0.05665276572108269
#  Case 325: biases: -0.07021953910589218
#  Case 326: biases: -0.05126592144370079
#  Case 327: biases: -0.009293870069086552
#  Case 328: biases: 0.06058067828416824
#  Case 329: biases: -0.10096500813961029
#  Case 330: biases: -0.0017486232100054622
#  Case 331: biases: -0.04841185733675957
#  Case 332: biases: -0.10469760745763779
#  Case 333: biases: -0.02573913335800171
#  Case 334: biases: -0.07820318639278412
#  Case 335: biases: -0.06443340331315994
#  Case 336: biases: 0.07801241427659988
#  Case 337: biases: 0.08020403236150742
#  Case 338: biases: -0.07059303671121597
#  Case 339: biases: -0.07287713885307312
#  Case 340: biases: -0.04465872049331665
#  Case 341: biases: 0.021016743034124374
#  Case 342: biases: 0.08219386637210846
#  Case 343: biases: -0.0492570698261261
#  Case 344: biases: -0.14486154913902283
#  Case 345: biases: 0.05555146560072899
#  Case 346: biases: -0.11441820114850998
#  Case 347: biases: -0.08580891042947769
#  Case 348: biases: -0.049581337720155716
#  Case 349: biases: -0.03812720626592636
#  Case 350: biases: -0.015185290947556496
#  Case 351: biases: 0.06722931563854218
#  Case 352: biases: -0.045585718005895615
#  Case 353: biases: 0.01622883602976799
#  Case 354: biases: 0.0
#  Case 355: biases: -0.059453900903463364
#  Case 356: biases: 0.05367547646164894
#  Case 357: biases: 0.025477619841694832
#  Case 358: biases: -0.05203906074166298
#  Case 359: biases: -0.06354860961437225
#  Case 360: biases: 0.07765210419893265
#  Case 361: biases: -0.0776059553027153
#  Case 362: biases: -0.00569541659206152
#  Case 363: biases: 0.09421727806329727
#  Case 364: biases: -0.00814544502645731
#  Case 365: biases: 0.029251335188746452
#  Case 366: biases: -0.0839567556977272
#  Case 367: biases: -0.12339747697114944
#  Case 368: biases: -0.11815417557954788
#  Case 369: biases: 0.0495724231004715
#  Case 370: biases: 0.07244841009378433
#  Case 371: biases: -0.08554282039403915
#  Case 372: biases: 0.01774514466524124
#  Case 373: biases: -0.045208413153886795
#  Case 374: biases: 0.02097460627555847
#  Case 375: biases: 0.11567915230989456
#  Case 376: biases: -0.13461969792842865
#  Case 377: biases: 0.08318202942609787
#  Case 378: biases: 0.0843147560954094
#  Case 379: biases: 0.07038767635822296
#  Case 380: biases: -0.07183762639760971
#  Case 381: biases: 0.03131993114948273
#  Case 382: biases: -0.1021353155374527
#  Case 383: biases: 0.09176453948020935
#  Case 384: biases: 0.05239299312233925
#  Case 385: biases: -0.09332329034805298
#  Case 386: biases: -0.05749337375164032
#  Case 387: biases: -0.09620312601327896
#  Case 388: biases: 0.010103358887135983
#  Case 389: biases: -0.010461377911269665
#  Case 390: biases: -0.00011809980787802488
#  Case 391: biases: -0.06624478846788406
#  Case 392: biases: 0.05203568935394287
#  Case 393: biases: 0.07049266248941422
#  Case 394: biases: -0.0797775536775589
#  Case 395: biases: 0.03978840634226799
#  Case 396: biases: -0.0004680490237660706
#  Case 397: biases: -0.10635848343372345
#  Case 398: biases: -0.05371732637286186
#  Case 399: biases: 0.028594378381967545
#  Case 400: biases: 0.0365217886865139
#  Case 401: biases: -0.04150150716304779
#  Case 402: biases: -0.0129086310043931
#  Case 403: biases: 0.08241661638021469
#  Case 404: biases: -0.06678500771522522
#  Case 405: biases: -0.0006143589853309095
#  Case 406: biases: 0.013834227807819843
#  Case 407: biases: -0.04154488444328308
#  Case 408: biases: 0.00037450974923558533
#  Case 409: biases: -0.06422197073698044
#  Case 410: biases: -0.11400721967220306
#  Case 411: biases: 0.0888405293226242
#  Case 412: biases: -0.09980542212724686
#  Case 413: biases: 0.03495098650455475
#  Case 414: biases: -0.06106174737215042
#  Case 415: biases: -0.018139779567718506
#  Case 416: biases: 0.011323655024170876
#  Case 417: biases: -0.019584283232688904
#  Case 418: biases: -0.06601634621620178
#  Case 419: biases: -0.05586642026901245
#  Case 420: biases: 0.15281841158866882
#  Case 421: biases: -0.06963326781988144
#  Case 422: biases: 0.01657240092754364
#  Case 423: biases: -0.05979005619883537
#  Case 424: biases: -0.026934882625937462
#  Case 425: biases: -0.07069862633943558
#  Case 426: biases: -0.08656854182481766
#  Case 427: biases: -0.12631218135356903
#  Case 428: biases: -0.04540060833096504
#  Case 429: biases: 0.06986258924007416
#  Case 430: biases: 0.019422374665737152
#  Case 431: biases: 0.009559416212141514
#  Case 432: biases: -0.043760672211647034
#  Case 433: biases: 0.07624325156211853
#  Case 434: biases: -0.03589198365807533
#  Case 435: biases: 0.048549387603998184
#  Case 436: biases: -0.05922776833176613
#  Case 437: biases: -0.07965939491987228
#  Case 438: biases: 0.021557588130235672
#  Case 439: biases: 0.03461894392967224
#  Case 440: biases: 0.0195541363209486
#  Case 441: biases: 0.030107880011200905
#  Case 442: biases: -0.016415433958172798
#  Case 443: biases: 0.02026662789285183
#  Case 444: biases: -0.04326935112476349
#  Case 445: biases: 0.06709899753332138
#  Case 446: biases: -0.00923763308674097
#  Case 447: biases: -0.13131919503211975
#  Case 448: biases: 0.09747635573148727
#  Case 449: biases: 0.11724645644426346
#  Case 450: biases: -0.009893035516142845
#  Case 451: biases: -0.00569006847217679
#  Case 452: biases: -0.13040272891521454
#  Case 453: biases: 0.02118782326579094
#  Case 454: biases: 0.06055712327361107
#  Case 455: biases: 0.0561099611222744
#  Case 456: biases: 0.06131729483604431
#  Case 457: biases: -0.13438627123832703
#  Case 458: biases: 0.0053295958787202835
#  Case 459: biases: -0.06544698029756546
#  Case 460: biases: -0.08690466731786728
#  Case 461: biases: 0.008669297210872173
#  Case 462: biases: -0.04370427504181862
#  Case 463: biases: 0.05648219957947731
#  Case 464: biases: -0.008479389362037182
#  Case 465: biases: 0.0008371230214834213
#  Case 466: biases: -0.029030155390501022
#  Case 467: biases: 0.02954910881817341
#  Case 468: biases: -0.159812331199646
#  Case 469: biases: 0.06703588366508484
#  Case 470: biases: 0.07053040713071823
#  Case 471: biases: 0.022397015243768692
#  Case 472: biases: 0.06720825284719467
#  Case 473: biases: 0.10077929496765137
#  Case 474: biases: 0.0998559519648552
#  Case 475: biases: 0.009248481132090092
#  Case 476: biases: 0.11182655394077301
#  Case 477: biases: 0.06227846071124077
#  Case 478: biases: 0.10213389992713928
#  Case 479: biases: -0.03195102885365486
#  Case 480: biases: -0.0082019018009305
#  Case 481: biases: -0.00549540389329195
#  Case 482: biases: -0.007832634262740612
#  Case 483: biases: -0.07765382528305054
#  Case 484: biases: -0.11689099669456482
#  Case 485: biases: 0.031198522076010704
#  Case 486: biases: -0.10060261934995651
#  Case 487: biases: 0.11393310874700546
#  Case 488: biases: -0.05600161850452423
#  Case 489: biases: 0.01912263035774231
#  Case 490: biases: -0.037566397339105606
#  Case 491: biases: 0.08538851141929626
#  Case 492: biases: 0.011537178419530392
#  Case 493: biases: -0.16229163110256195
#  Case 494: biases: 0.005870780907571316
#  Case 495: biases: 0.03300514072179794
#  Case 496: biases: -0.017171066254377365
#  Case 497: biases: -0.06658028066158295
#  Case 498: biases: 0.06626690179109573
#  Case 499: biases: -0.06787838041782379
#  Case 500: biases: -0.02706957422196865
#  Case 501: biases: -0.01719978079199791
#  Case 502: biases: 0.08077438920736313
#  Case 503: biases: -0.1044759526848793
#  Case 504: biases: 0.0810486376285553
#  Case 505: biases: 0.013410369865596294
#  Case 506: biases: 0.010128906928002834
#  Case 507: biases: 0.09409500658512115
#  Case 508: biases: -0.11840733140707016
#  Case 509: biases: 0.029926015064120293
#  Case 510: biases: -0.04033587500452995
#  Case 511: biases: -0.05417756736278534
#  Case 512: biases: -0.028842821717262268
#  Case 513: biases: -0.08208447694778442
#  Case 514: biases: -0.10240751504898071
#  Case 515: biases: -0.09524378925561905
#  Case 516: biases: 0.04183298721909523
#  Case 517: biases: 0.036622315645217896
#  Case 518: biases: 0.09716220945119858
#  Case 519: biases: -0.021708877757191658
#  Case 520: biases: 0.10054773092269897
#  Case 521: biases: -0.027019323781132698
#  Case 522: biases: 0.026941215619444847
#  Case 523: biases: -0.03528304025530815
#  Case 524: biases: 0.026799961924552917
#  Case 525: biases: -0.034606460481882095
#  Case 526: biases: -0.058832187205553055
#  Case 527: biases: 0.014703716151416302
#  Case 528: biases: 0.0822809487581253
#  Case 529: biases: -0.07434047758579254
#  Case 530: biases: 0.055836886167526245
#  Case 531: biases: -0.05680597573518753
#  Case 532: biases: 0.04808545857667923
#  Case 533: biases: 0.1319606602191925
#  Case 534: biases: 0.04562672972679138
#  Case 535: biases: 0.08090411126613617
#  Case 536: biases: 0.1333375722169876
#  Case 537: biases: 0.04054221883416176
#  Case 538: biases: 0.08755096048116684
#  Case 539: biases: 0.06265680491924286
#  Case 540: biases: 0.013628593645989895
#  Case 541: biases: -0.019244257360696793
#  Case 542: biases: -0.11862818896770477
#  Case 543: biases: 0.11811504513025284
#  Case 544: biases: 0.07833019644021988
#  Case 545: biases: -0.0695311576128006
#  Case 546: biases: 0.1314779371023178
#  Case 547: biases: 0.06536950170993805
#  Case 548: biases: -0.06041634455323219
#  Case 549: biases: 0.06248253956437111
#  Case 550: biases: -0.041255686432123184
#  Case 551: biases: -0.07892787456512451
#  Case 552: biases: 0.015326719731092453
#  Case 553: biases: -0.00023121622507460415
#  Case 554: biases: 0.04220173507928848
#  Case 555: biases: -0.09611918032169342
#  Case 556: biases: -0.08869042247533798
#  Case 557: biases: -0.17456941306591034
#  Case 558: biases: -0.06973643600940704
#  Case 559: biases: -0.09495219588279724
#  Case 560: biases: -0.03843166306614876
#  Case 561: biases: -0.08568680286407471
#  Case 562: biases: -0.07719559222459793
#  Case 563: biases: 0.012862433679401875
#  Case 564: biases: 0.012984709814190865
#  Case 565: biases: -0.07817557454109192
#  Case 566: biases: -0.06050894409418106
#  Case 567: biases: -0.12745900452136993
#  Case 568: biases: -0.02556423842906952
#  Case 569: biases: -0.01984279416501522
#  Case 570: biases: -0.04561040922999382
#  Case 571: biases: -0.02237040549516678
#  Case 572: biases: -0.1000639796257019
#  Case 573: biases: -0.037266191095113754
#  Case 574: biases: -0.07693853974342346
#  Case 575: biases: -0.08052865415811539
#  Case 576: biases: -0.022559188306331635
#  Case 577: biases: 0.009415795095264912
#  Case 578: biases: 0.14003658294677734
#  Case 579: biases: -0.1085241287946701
#  Case 580: biases: 0.020005077123641968
#  Case 581: biases: -0.04980814829468727
#  Case 582: biases: 0.014103342778980732
#  Case 583: biases: -0.02905121073126793
#  Case 584: biases: -0.07338421791791916
#  Case 585: biases: -0.03810972720384598
#  Case 586: biases: -0.08898202329874039
#  Case 587: biases: 0.011004123836755753
#  Case 588: biases: 0.09472363442182541
#  Case 589: biases: -0.11583109945058823
#  Case 590: biases: -0.036952853202819824
#  Case 591: biases: -0.11827260255813599
#  Case 592: biases: 0.06557872146368027
#  Case 593: biases: -0.07806405425071716
#  Case 594: biases: -0.03440326824784279
#  Case 595: biases: 0.14410540461540222
#  Case 596: biases: 0.08284758031368256
#  Case 597: biases: -0.015188965015113354
#  Case 598: biases: -0.030260512605309486
#  Case 599: biases: 0.04377397149801254
#  Case 600: biases: -0.052009593695402145
#  Case 601: biases: 0.03099750727415085
#  Case 602: biases: -0.021065186709165573
#  Case 603: biases: -0.05862407758831978
#  Case 604: biases: 0.06534033268690109
#  Case 605: biases: -0.05927976220846176
#  Case 606: biases: -0.015371792949736118
#  Case 607: biases: -0.02794383466243744
#  Case 608: biases: 0.16265156865119934
#  Case 609: biases: 0.009035170078277588
#  Case 610: biases: -0.02312762849032879
#  Case 611: biases: 0.051325760781764984
#  Case 612: biases: 0.03339802473783493
#  Case 613: biases: -0.08515889197587967
#  Case 614: biases: 0.13374735414981842
#  Case 615: biases: -0.04058792069554329
#  Case 616: biases: -0.07685758173465729
#  Case 617: biases: 0.08774758875370026
#  Case 618: biases: -0.024786140769720078
#  Case 619: biases: 0.06093750149011612
#  Case 620: biases: 0.10369053483009338
#  Case 621: biases: 0.07846654951572418
#  Case 622: biases: -0.07242932915687561
#  Case 623: biases: -0.09155655652284622
#  Case 624: biases: 0.07110293209552765
#  Case 625: biases: 0.027448885142803192
#  Case 626: biases: -0.027623534202575684
#  Case 627: biases: -0.04661361128091812
#  Case 628: biases: -0.003597332863137126
#  Case 629: biases: -0.06553466618061066
#  Case 630: biases: -0.040842391550540924
#  Case 631: biases: 0.05876545608043671
#  Case 632: biases: -0.030952701345086098
#  Case 633: biases: -0.00335353403352201
#  Case 634: biases: -0.06434120237827301
#  Case 635: biases: 0.04998520389199257
#  Case 636: biases: 0.05620952323079109
#  Case 637: biases: -0.09771186113357544
#  Case 638: biases: -0.03882579505443573
#  Case 639: biases: -0.10973316431045532
#  Case 640: biases: -0.030211785808205605
#  Case 641: biases: -0.05076280236244202
#  Case 642: biases: -0.07934398949146271
#  Case 643: biases: -0.06958858668804169
#  Case 644: biases: 0.07916315644979477
#  Case 645: biases: -0.07674933969974518
#  Case 646: biases: -0.015690961852669716
#  Case 647: biases: 0.1532629132270813
#  Case 648: biases: -0.00042613482219167054
#  Case 649: biases: -0.007559614721685648
#  Case 650: biases: 0.05006065219640732
#  Case 651: biases: -0.1320166140794754
#  Case 652: biases: 0.0011749628465622663
#  Case 653: biases: 0.06622233986854553
#  Case 654: biases: -0.09359326213598251
#  Case 655: biases: 0.057677045464515686
#  Case 656: biases: -0.10336077958345413
#  Case 657: biases: -0.037017107009887695
#  Case 658: biases: 0.05987492948770523
#  Case 659: biases: 0.07179956883192062
#  Case 660: biases: 0.06323017925024033
#  Case 661: biases: -0.05042422190308571
#  Case 662: biases: -0.005739108193665743
#  Case 663: biases: 0.02512502297759056
#  Case 664: biases: -0.0028032921254634857
#  Case 665: biases: 0.09248853474855423
#  Case 666: biases: -0.11874078959226608
#  Case 667: biases: -0.01079392060637474
#  Case 668: biases: 0.02684619463980198
#  Case 669: biases: -0.003593335160985589
#  Case 670: biases: 0.09816573560237885
#  Case 671: biases: 0.07633422315120697
#  Case 672: biases: 0.16386178135871887
#  Case 673: biases: -0.0049314964562654495
#  Case 674: biases: 0.09480059146881104
#  Case 675: biases: 0.018331974744796753
#  Case 676: biases: -0.1321859508752823
#  Case 677: biases: 0.05871708691120148
#  Case 678: biases: 0.07662201672792435
#  Case 679: biases: -0.088749960064888
#  Case 680: biases: -0.010389101691544056
#  Case 681: biases: -0.054646268486976624
#  Case 682: biases: -0.07971060276031494
#  Case 683: biases: -0.08886986970901489
#  Case 684: biases: -0.03395622596144676
#  Case 685: biases: 0.06298930943012238
#  Case 686: biases: -0.023582402616739273
#  Case 687: biases: 0.05023384466767311
#  Case 688: biases: 0.09504219144582748
#  Case 689: biases: -0.01861889846622944
#  Case 690: biases: 0.08738547563552856
#  Case 691: biases: -0.009550769813358784
#  Case 692: biases: -0.10791738331317902
#  Case 693: biases: 0.10331302881240845
#  Case 694: biases: -0.015219774097204208
#  Case 695: biases: -0.07734948396682739
#  Case 696: biases: 0.062232520431280136
#  Case 697: biases: -0.04249291494488716
#  Case 698: biases: 0.06682654470205307
#  Case 699: biases: -0.01017247885465622
#  Case 700: biases: -0.10080286860466003
#  Case 701: biases: -0.04143310710787773
#  Case 702: biases: 0.010509351268410683
#  Case 703: biases: -0.0038219939451664686
#  Case 704: biases: -0.1293659806251526
#  Case 705: biases: -0.030883826315402985
#  Case 706: biases: -0.0980893149971962
#  Case 707: biases: 0.051112301647663116
#  Case 708: biases: 0.04186005890369415
#  Case 709: biases: -0.03093806467950344
#  Case 710: biases: -0.026589620858430862
#  Case 711: biases: 0.003899640403687954
#  Case 712: biases: -0.017746219411492348
#  Case 713: biases: -0.07228779792785645
#  Case 714: biases: 0.028216257691383362
#  Case 715: biases: -0.053802844136953354
#  Case 716: biases: -0.018751658499240875
#  Case 717: biases: -0.04240565747022629
#  Case 718: biases: -0.1292753964662552
#  Case 719: biases: -0.0003907563805114478
#  Case 720: biases: -0.05126334726810455
#  Case 721: biases: 0.05889606848359108
#  Case 722: biases: 0.07395850121974945
#  Case 723: biases: -0.029315782710909843
#  Case 724: biases: -0.07184141874313354
#  Case 725: biases: 0.05202497914433479
#  Case 726: biases: -0.021091675385832787
#  Case 727: biases: 0.08748368918895721
#  Case 728: biases: -0.02281360886991024
#  Case 729: biases: 0.10275325179100037
#  Case 730: biases: -0.06167413666844368
#  Case 731: biases: -0.05928337201476097
#  Case 732: biases: -0.15015044808387756
#  Case 733: biases: -0.11381297558546066
#  Case 734: biases: 0.025295261293649673
#  Case 735: biases: -0.0419345423579216
#  Case 736: biases: -0.056095730513334274
#  Case 737: biases: 0.06720039248466492
#  Case 738: biases: -0.012802195735275745
#  Case 739: biases: -0.08460735529661179
#  Case 740: biases: -0.06164303794503212
#  Case 741: biases: -0.056665193289518356
#  Case 742: biases: -0.10333715379238129
#  Case 743: biases: 0.09098219126462936
#  Case 744: biases: 0.0160521287471056
#  Case 745: biases: -0.07694495469331741
#  Case 746: biases: 0.12765097618103027
#  Case 747: biases: -0.013171958737075329
#  Case 748: biases: -0.10747203975915909
#  Case 749: biases: -0.012371715158224106
#  Case 750: biases: -0.07326316833496094
#  Case 751: biases: -0.03496572747826576
#  Case 752: biases: 0.06332268565893173
#  Case 753: biases: 0.012692940421402454
#  Case 754: biases: -0.03854074329137802
#  Case 755: biases: -0.020167095586657524
#  Case 756: biases: 0.10105501860380173
#  Case 757: biases: 0.07689476758241653
#  Case 758: biases: 0.027300314977765083
#  Case 759: biases: -0.08114635944366455
#  Case 760: biases: 0.18745729327201843
#  Case 761: biases: -0.02673226036131382
#  Case 762: biases: 0.08576671034097672
#  Case 763: biases: 0.053730595856904984
#  Case 764: biases: -0.0916978269815445
#  Case 765: biases: -0.0510251522064209
#  Case 766: biases: 0.0009024332393892109
#  Case 767: biases: -0.06990176439285278
#  Case 768: biases: -0.047603245824575424
#  Case 769: biases: -0.06386686116456985
#  Case 770: biases: 0.006930598057806492
#  Case 771: biases: -0.04334593936800957
#  Case 772: biases: 0.07228966057300568
#  Case 773: biases: 0.03907730430364609
#  Case 774: biases: 0.165154829621315
#  Case 775: biases: 0.06152351200580597
#  Case 776: biases: -0.1232910007238388
#  Case 777: biases: 0.037593308836221695
#  Case 778: biases: -0.009753248654305935
#  Case 779: biases: -0.08699090778827667
#  Case 780: biases: 0.06068968400359154
#  Case 781: biases: 0.007321026176214218
#  Case 782: biases: 0.015742367133498192
#  Case 783: biases: -0.03198736533522606
#  Case 784: biases: -0.1253688931465149
#  Case 785: biases: -0.08442448079586029
#  Case 786: biases: -0.06347969174385071
#  Case 787: biases: -0.05546640232205391
#  Case 788: biases: -0.004528386518359184
#  Case 789: biases: -0.14945010840892792
#  Case 790: biases: -0.003923128824681044
#  Case 791: biases: 0.01856379024684429
#  Case 792: biases: 0.08542519062757492
#  Case 793: biases: 0.08761370182037354
#  Case 794: biases: -0.10199318081140518
#  Case 795: biases: 0.09044625610113144
#  Case 796: biases: -0.09119834750890732
#  Case 797: biases: -0.0860939621925354
#  Case 798: biases: 0.02926631085574627
#  Case 799: biases: -0.08385450392961502
#  Case 800: biases: -0.04506008327007294
#  Case 801: biases: -0.06827526539564133
#  Case 802: biases: -0.053169816732406616
#  Case 803: biases: 0.11088195443153381
#  Case 804: biases: 0.05375228449702263
#  Case 805: biases: -0.0755108967423439
#  Case 806: biases: -0.05011187121272087
#  Case 807: biases: -0.027571305632591248
#  Case 808: biases: 0.05959282070398331
#  Case 809: biases: -0.028620414435863495
#  Case 810: biases: 0.0020566009916365147
#  Case 811: biases: -0.07631773501634598
#  Case 812: biases: -0.07936699688434601
#  Case 813: biases: -0.0300094336271286
#  Case 814: biases: 0.007030809298157692
#  Case 815: biases: 0.11389195919036865
#  Case 816: biases: -0.020463870838284492
#  Case 817: biases: -0.0871940553188324
#  Case 818: biases: -0.15450410544872284
#  Case 819: biases: -0.00925949402153492
#  Case 820: biases: -0.05539259314537048
#  Case 821: biases: -0.06137571856379509
#  Case 822: biases: -0.0960373729467392
#  Case 823: biases: 0.009539912454783916
#  Case 824: biases: -0.01940285414457321
#  Case 825: biases: -0.09815072268247604
#  Case 826: biases: -0.0480806864798069
#  Case 827: biases: 0.06581342220306396
#  Case 828: biases: 0.07633649557828903
#  Case 829: biases: -0.1063782274723053
#  Case 830: biases: -0.009046735242009163
#  Case 831: biases: -0.08950495719909668
#  Case 832: biases: 0.007455411832779646
#  Case 833: biases: 0.017635846510529518
#  Case 834: biases: 0.10656469315290451
#  Case 835: biases: 0.14190524816513062
#  Case 836: biases: 0.046467483043670654
#  Case 837: biases: -0.08322978764772415
#  Case 838: biases: -0.03231612220406532
#  Case 839: biases: 0.011705638840794563
#  Case 840: biases: -0.10589766502380371
#  Case 841: biases: -0.06224748119711876
#  Case 842: biases: -0.05002693086862564
#  Case 843: biases: -0.00977739691734314
#  Case 844: biases: -0.06065898388624191
#  Case 845: biases: -0.07499611377716064
#  Case 846: biases: 0.03896800056099892
#  Case 847: biases: -0.005835729651153088
#  Case 848: biases: -0.05472736060619354
#  Case 849: biases: -0.044652629643678665
#  Case 850: biases: -0.07523331791162491
#  Case 851: biases: -0.004180556628853083
#  Case 852: biases: 0.1343686431646347
#  Case 853: biases: -0.09836159646511078
#  Case 854: biases: -0.019551856443285942
#  Case 855: biases: 0.14310768246650696
#  Case 856: biases: -0.11936312168836594
#  Case 857: biases: 0.032272521406412125
#  Case 858: biases: -0.04442485421895981
#  Case 859: biases: -0.023329297080636024
#  Case 860: biases: -0.012813841924071312
#  Case 861: biases: -0.06286582350730896
#  Case 862: biases: 0.032539233565330505
#  Case 863: biases: -0.13040481507778168
#  Case 864: biases: -0.10612370818853378
#  Case 865: biases: -0.07515151798725128
#  Case 866: biases: 0.10490789264440536
#  Case 867: biases: 0.0029185849707573652
#  Case 868: biases: -0.1064557284116745
#  Case 869: biases: 0.09122111648321152
#  Case 870: biases: -0.10889577120542526
#  Case 871: biases: -0.06637679040431976
#  Case 872: biases: -0.015220689587295055
#  Case 873: biases: 0.09132382273674011
#  Case 874: biases: 0.005063344724476337
#  Case 875: biases: -0.050891052931547165
#  Case 876: biases: -0.013292595744132996
#  Case 877: biases: -0.020363561809062958
#  Case 878: biases: -0.05879078805446625
#  Case 879: biases: -0.0546729750931263
#  Case 880: biases: 0.015227271243929863
#  Case 881: biases: -0.0021473898086696863
#  Case 882: biases: -0.052977267652750015
#  Case 883: biases: 0.009267893619835377
#  Case 884: biases: 0.06535603106021881
#  Case 885: biases: -0.141851007938385
#  Case 886: biases: 0.015249480493366718
#  Case 887: biases: -0.11524106562137604
#  Case 888: biases: -0.0865558460354805
#  Case 889: biases: -0.07887037843465805
#  Case 890: biases: 0.005466560833156109
#  Case 891: biases: -0.006087018642574549
#  Case 892: biases: 0.03802570328116417
#  Case 893: biases: -0.09430953860282898
#  Case 894: biases: 0.003032528795301914
#  Case 895: biases: 0.06418449431657791
#  Case 896: biases: -0.10009383410215378
#  Case 897: biases: 0.05506032332777977
#  Case 898: biases: 0.0501864030957222
#  Case 899: biases: -0.041711051017045975
#  Case 900: biases: 0.025978149846196175
#  Case 901: biases: 0.08706408739089966
#  Case 902: biases: -0.056727129966020584
#  Case 903: biases: -0.014536884613335133
#  Case 904: biases: -0.03934759646654129
#  Case 905: biases: 0.023474015295505524
#  Case 906: biases: 0.13318365812301636
#  Case 907: biases: 0.02923423796892166
#  Case 908: biases: -0.028905125334858894
#  Case 909: biases: -0.05597756803035736
#  Case 910: biases: 0.04108752682805061
#  Case 911: biases: -0.07908637821674347
#  Case 912: biases: -0.052647434175014496
#  Case 913: biases: 0.06421716511249542
#  Case 914: biases: 0.03642464056611061
#  Case 915: biases: 0.07317590713500977
#  Case 916: biases: 0.04897785931825638
#  Case 917: biases: -0.0958888903260231
#  Case 918: biases: 0.007857531309127808
#  Case 919: biases: 0.06235814094543457
#  Case 920: biases: -0.000262710265815258
#  Case 921: biases: -0.11988525837659836
#  Case 922: biases: 0.13987606763839722
#  Case 923: biases: 0.035976674407720566
#  Case 924: biases: -0.042022377252578735
#  Case 925: biases: -0.03930116444826126
#  Case 926: biases: -0.024612557142972946
#  Case 927: biases: 0.061686255037784576
#  Case 928: biases: -0.05242093279957771
#  Case 929: biases: -0.04574897512793541
#  Case 930: biases: 0.033866915851831436
#  Case 931: biases: -0.040225252509117126
#  Case 932: biases: -0.12744487822055817
#  Case 933: biases: 0.029602574184536934
#  Case 934: biases: -0.13670074939727783
#  Case 935: biases: -0.02378568798303604
#  Case 936: biases: -0.006336443591862917
#  Case 937: biases: -0.06813187152147293
#  Case 938: biases: 0.02678765542805195
#  Case 939: biases: -0.06668845564126968
#  Case 940: biases: -0.08266027271747589
#  Case 941: biases: -0.023064587265253067
#  Case 942: biases: -0.04237472265958786
#  Case 943: biases: -0.09393949806690216
#  Case 944: biases: 0.010613448917865753
#  Case 945: biases: -0.07471451908349991
#  Case 946: biases: -0.022450169548392296
#  Case 947: biases: -0.031205706298351288
#  Case 948: biases: 0.0166420079767704
#  Case 949: biases: 0.09845088422298431
#  Case 950: biases: 0.09492430090904236
#  Case 951: biases: 0.053458813577890396
#  Case 952: biases: -0.07582971453666687
#  Case 953: biases: -0.01819816790521145
#  Case 954: biases: -0.062097612768411636
#  Case 955: biases: -0.07552888989448547
#  Case 956: biases: 0.007949279621243477
#  Case 957: biases: 0.05630192160606384
#  Case 958: biases: -0.009734424762427807
#  Case 959: biases: 0.020009808242321014
#  Case 960: biases: 0.06078742817044258
#  Case 961: biases: -0.10033877938985825
#  Case 962: biases: 0.09493263810873032
#  Case 963: biases: -0.021519726142287254
#  Case 964: biases: -0.05594548583030701
#  Case 965: biases: -0.026110446080565453
#  Case 966: biases: 0.11686502397060394
#  Case 967: biases: -0.11297350376844406
#  Case 968: biases: 0.0024638711474835873
#  Case 969: biases: -0.08189978450536728
#  Case 970: biases: -0.15905427932739258
#  Case 971: biases: 0.08489961922168732
#  Case 972: biases: 0.021549537777900696
#  Case 973: biases: 0.07779022306203842
#  Case 974: biases: -0.033190324902534485
#  Case 975: biases: 0.01969849318265915
#  Case 976: biases: 0.06691938638687134
#  Case 977: biases: 0.0027635004371404648
#  Case 978: biases: -0.02490580454468727
#  Case 979: biases: -0.024166705086827278
#  Case 980: biases: -0.08272946625947952
#  Case 981: biases: 0.08570009469985962
#  Case 982: biases: -0.07074906677007675
#  Case 983: biases: -0.07984567433595657
#  Case 984: biases: -0.07051265984773636
#  Case 985: biases: -0.06678716838359833
#  Case 986: biases: -0.029494309797883034
#  Case 987: biases: 0.08069167286157608
#  Case 988: biases: -0.09423056989908218
#  Case 989: biases: -0.07050175219774246
#  Case 990: biases: -0.091620534658432
#  Case 991: biases: 0.09093242138624191
#  Case 992: biases: -0.03735663741827011
#  Case 993: biases: 0.036951351910829544
#  Case 994: biases: 0.0016444968059659004
#  Case 995: biases: -0.0604235976934433
#  Case 996: biases: 0.03230222314596176
#  Case 997: biases: 0.03253151848912239
#  Case 998: biases: -0.00892515666782856
#  Case 999: biases: 0.10103123635053635
#  Case 1000: biases: 0.09474194794893265
#  Case 1001: biases: 0.1136263757944107
#  Case 1002: biases: 0.008289278484880924
#  Case 1003: biases: 0.09610415250062943
#  Case 1004: biases: 0.11252401769161224
#  Case 1005: biases: 0.03779631480574608
#  Case 1006: biases: -0.0686473622918129
#  Case 1007: biases: -0.023934701457619667
#  Case 1008: biases: 0.1172630563378334
#  Case 1009: biases: 0.0023523455020040274
#  Case 1010: biases: -0.0891839861869812
#  Case 1011: biases: -0.07289130240678787
#  Case 1012: biases: 0.058051399886608124
#  Case 1013: biases: 0.07573225349187851
#  Case 1014: biases: -0.020586036145687103
#  Case 1015: biases: 0.07335580140352249
#  Case 1016: biases: 0.060813017189502716
#  Case 1017: biases: 0.06322071701288223
#  Case 1018: biases: 0.07974521815776825
#  Case 1019: biases: 0.022999582812190056
#  Case 1020: biases: -0.05940903350710869
#  Case 1021: biases: -0.09704539179801941
#  Case 1022: biases: 0.06331514567136765
#  Case 1023: biases: -0.019183434545993805
#  Case 1024: biases: -0.07638315111398697
#  Case 1025: biases: 0.06288150697946548
#  Case 1026: biases: -0.0547751858830452
#  Case 1027: biases: 0.026689279824495316
#  Case 1028: biases: 0.10141918808221817
#  Case 1029: biases: -0.11603844165802002
#  Case 1030: biases: 0.08806996047496796
#  Case 1031: biases: -0.07466623187065125
#  Case 1032: biases: -0.056098438799381256
#  Case 1033: biases: 0.08180876821279526
#  Case 1034: biases: -0.0649217739701271
#  Case 1035: biases: 0.01688344031572342
#  Case 1036: biases: -0.10565919429063797
#  Case 1037: biases: -0.11116676032543182
#  Case 1038: biases: -0.07435254752635956
#  Case 1039: biases: -0.10165195167064667
#  Case 1040: biases: 0.03956199064850807
#  Case 1041: biases: 0.00403936393558979
#  Case 1042: biases: 0.0060973153449594975
#  Case 1043: biases: -0.05688183009624481
#  Case 1044: biases: -0.07801467925310135
#  Case 1045: biases: -0.00539083918556571
#  Case 1046: biases: 0.04561406746506691
#  Case 1047: biases: 0.03993712365627289
#  Case 1048: biases: 0.0861671194434166
#  Case 1049: biases: -0.059973735362291336
#  Case 1050: biases: -0.0865456610918045
#  Case 1051: biases: -0.13193468749523163
#  Case 1052: biases: 0.10440286993980408
#  Case 1053: biases: 0.016584614291787148
#  Case 1054: biases: 0.0586567223072052
#  Case 1055: biases: 0.011312711052596569
#  Case 1056: biases: -0.0739646777510643
#  Case 1057: biases: -0.02383076772093773
#  Case 1058: biases: -0.028662536293268204
#  Case 1059: biases: 0.01191335916519165
#  Case 1060: biases: -0.0620536170899868
#  Case 1061: biases: -0.06090560927987099
#  Case 1062: biases: -0.11640305072069168
#  Case 1063: biases: -0.029678894206881523
#  Case 1064: biases: 0.07810155302286148
#  Case 1065: biases: 0.004933146294206381
#  Case 1066: biases: -0.010473656468093395
#  Case 1067: biases: 0.017072578892111778
#  Case 1068: biases: -0.051377516239881516
#  Case 1069: biases: 0.03689315915107727
#  Case 1070: biases: -0.10166727006435394
#  Case 1071: biases: 0.037052202969789505
#  Case 1072: biases: -0.021472180262207985
#  Case 1073: biases: -0.04269981011748314
#  Case 1074: biases: -0.018232956528663635
#  Case 1075: biases: -0.11282357573509216
#  Case 1076: biases: -0.027911964803934097
#  Case 1077: biases: 0.10832730680704117
#  Case 1078: biases: -0.03977806121110916
#  Case 1079: biases: 0.08764239400625229
#  Case 1080: biases: 0.022679569199681282
#  Case 1081: biases: -0.10189279168844223
#  Case 1082: biases: 0.028129635378718376
#  Case 1083: biases: 0.04281623288989067
#  Case 1084: biases: 0.1022087037563324
#  Case 1085: biases: 0.060016244649887085
#  Case 1086: biases: 0.00038418197073042393
#  Case 1087: biases: 0.027120064944028854
#  Case 1088: biases: -0.1343804895877838
#  Case 1089: biases: -0.1070445254445076
#  Case 1090: biases: -0.03202194720506668
#  Case 1091: biases: -0.09786082804203033
#  Case 1092: biases: 0.007083158474415541
#  Case 1093: biases: -0.0024183213245123625
#  Case 1094: biases: 0.07039619982242584
#  Case 1095: biases: 0.036235734820365906
#  Case 1096: biases: -0.015300625003874302
#  Case 1097: biases: -0.11649936437606812
#  Case 1098: biases: -0.025362329557538033
#  Case 1099: biases: -0.059306252747774124
#  Case 1100: biases: 0.009459830820560455
#  Case 1101: biases: 0.07872586697340012
#  Case 1102: biases: 0.07223015278577805
#  Case 1103: biases: -0.010064816102385521
#  Case 1104: biases: 0.028007835149765015
#  Case 1105: biases: -0.07705741375684738
#  Case 1106: biases: -0.035391777753829956
#  Case 1107: biases: -0.07776323705911636
#  Case 1108: biases: -0.048086702823638916
#  Case 1109: biases: -0.044395141303539276
#  Case 1110: biases: -0.06341595202684402
#  Case 1111: biases: -0.05087105557322502
#  Case 1112: biases: -0.057361092418432236
#  Case 1113: biases: 0.01831531710922718
#  Case 1114: biases: 0.06698264181613922
#  Case 1115: biases: -0.039927396923303604
#  Case 1116: biases: 0.03870970010757446
#  Case 1117: biases: 0.03930249437689781
#  Case 1118: biases: 0.035466115921735764
#  Case 1119: biases: 0.07650062441825867
#  Case 1120: biases: 0.024700094014406204
#  Case 1121: biases: -0.02372400090098381
#  Case 1122: biases: -0.11348390579223633
#  Case 1123: biases: -0.06947207450866699
#  Case 1124: biases: -0.040813930332660675
#  Case 1125: biases: 0.0628957524895668
#  Case 1126: biases: -0.04548261687159538
#  Case 1127: biases: -0.018512697890400887
#  Case 1128: biases: -0.034174855798482895
#  Case 1129: biases: -0.016467932611703873
#  Case 1130: biases: 0.062152594327926636
#  Case 1131: biases: -0.0962991937994957
#  Case 1132: biases: -0.15630175173282623
#  Case 1133: biases: -0.06176113337278366
#  Case 1134: biases: 0.013261757791042328
#  Case 1135: biases: -0.04021747410297394
#  Case 1136: biases: 0.03152596205472946
#  Case 1137: biases: 0.010668670758605003
#  Case 1138: biases: 0.027340127155184746
#  Case 1139: biases: 0.06237763538956642
#  Case 1140: biases: -0.09024704247713089
#  Case 1141: biases: 0.05645612254738808
#  Case 1142: biases: 0.059726912528276443
#  Case 1143: biases: -0.06341313570737839
#  Case 1144: biases: -0.0456516407430172
#  Case 1145: biases: 0.12030908465385437
#  Case 1146: biases: -0.07172460854053497
#  Case 1147: biases: -0.021593937650322914
#  Case 1148: biases: -0.049020953476428986
#  Case 1149: biases: -0.03133828565478325
#  Case 1150: biases: 0.04146602377295494
#  Case 1151: biases: 0.029414700344204903
#  Case 1152: biases: 0.060730669647455215
#  Case 1153: biases: 0.015607179142534733
#  Case 1154: biases: -0.1279565542936325
#  Case 1155: biases: 0.1269625872373581
#  Case 1156: biases: -0.021492591127753258
#  Case 1157: biases: -0.0659267008304596
#  Case 1158: biases: -0.10666093975305557
#  Case 1159: biases: -0.015254938043653965
#  Case 1160: biases: 0.12544655799865723
#  Case 1161: biases: -0.029108203947544098
#  Case 1162: biases: 0.054180584847927094
#  Case 1163: biases: -0.013813404366374016
#  Case 1164: biases: -6.305763236014172e-05
#  Case 1165: biases: 0.12445514649152756
#  Case 1166: biases: 0.01919018290936947
#  Case 1167: biases: 0.03331710770726204
#  Case 1168: biases: 0.04128227010369301
#  Case 1169: biases: -0.04680139198899269
#  Case 1170: biases: 0.02335268072783947
#  Case 1171: biases: 0.00020277277508284897
#  Case 1172: biases: -0.09105805307626724
#  Case 1173: biases: -0.1103045642375946
#  Case 1174: biases: 0.017354384064674377
#  Case 1175: biases: -0.01227877102792263
#  Case 1176: biases: 0.04668085277080536
#  Case 1177: biases: -0.007751063909381628
#  Case 1178: biases: 0.10119011253118515
#  Case 1179: biases: 0.04900436848402023
#  Case 1180: biases: 0.012119418941438198
#  Case 1181: biases: 0.10403785854578018
#  Case 1182: biases: -0.013516834005713463
#  Case 1183: biases: -0.1072293147444725
#  Case 1184: biases: -0.008755923248827457
#  Case 1185: biases: -0.1335315853357315
#  Case 1186: biases: -0.10947944223880768
#  Case 1187: biases: 0.031698405742645264
#  Case 1188: biases: -0.04814755916595459
#  Case 1189: biases: 0.03986087813973427
#  Case 1190: biases: 0.008571026846766472
#  Case 1191: biases: 0.012865367345511913
#  Case 1192: biases: 0.042109083384275436
#  Case 1193: biases: -0.05959859862923622
#  Case 1194: biases: -0.049330517649650574
#  Case 1195: biases: 0.039743270725011826
#  Case 1196: biases: 0.07404398918151855
#  Case 1197: biases: -0.09527452290058136
#  Case 1198: biases: 0.13496269285678864
#  Case 1199: biases: 0.07708825916051865
#  Case 1200: biases: 0.014354960061609745
#  Case 1201: biases: -0.09763684868812561
#  Case 1202: biases: 0.03540295735001564
#  Case 1203: biases: -0.017415933310985565
# ...
#  Case 2009: biases: -0.05897608399391174
#  Case 2010: biases: -0.05591880902647972
#  Case 2011: biases: -0.08946632593870163
#  Case 2012: biases: -0.016386304050683975
#  Case 2013: biases: 0.0945798009634018
#  Case 2014: biases: 0.0254047941416502
#  Case 2015: biases: 0.027124186977744102
#  Case 2016: biases: 0.05254631116986275
#  Case 2017: biases: -0.1521853357553482
#  Case 2018: biases: -0.042921412736177444
#  Case 2019: biases: -0.06870236992835999
#  Case 2020: biases: -0.014028734527528286
#  Case 2021: biases: -0.07467513531446457
#  Case 2022: biases: -0.107711561024189
#  Case 2023: biases: 0.03441987186670303
#  Case 2024: biases: 0.08416670560836792
#  Case 2025: biases: -0.10033536702394485
#  Case 2026: biases: -0.0904734656214714
#  Case 2027: biases: 0.03230464458465576
#  Case 2028: biases: 0.007879809476435184
#  Case 2029: biases: 0.03556249290704727
#  Case 2030: biases: 0.11216306686401367
#  Case 2031: biases: 0.06438062340021133
#  Case 2032: biases: 0.016966059803962708
#  Case 2033: biases: -0.025256093591451645
#  Case 2034: biases: -0.12352032214403152
#  Case 2035: biases: -0.008265765383839607
#  Case 2036: biases: -0.07775399088859558
#  Case 2037: biases: -0.0947832316160202
#  Case 2038: biases: -0.06251360476016998
#  Case 2039: biases: -0.0062819286249578
#  Case 2040: biases: 0.0021950630471110344
#  Case 2041: biases: -0.015512743964791298
#  Case 2042: biases: 0.01749468594789505
#  Case 2043: biases: 0.11426251381635666
#  Case 2044: biases: 0.03752867132425308
#  Case 2045: biases: 0.11548061668872833
#  Case 2046: biases: -0.10789632052183151
#  Case 2047: biases: -0.046758390963077545
#  Case 2048: biases: 0.026371948421001434
#  Case 2049: biases: 0.019998377189040184
#  Case 2050: biases: -0.026668835431337357
#  Case 2051: biases: -0.05528218299150467
#  Case 2052: biases: -0.07468543201684952
#  Case 2053: biases: 0.0013179891975596547
#  Case 2054: biases: 0.07302893698215485
#  Case 2055: biases: -0.11461426317691803
#  Case 2056: biases: -0.04818721115589142
#  Case 2057: biases: -0.0012046206975355744
#  Case 2058: biases: -0.01764337718486786
#  Case 2059: biases: 0.07690595835447311
#  Case 2060: biases: 0.03379067778587341
#  Case 2061: biases: -0.0557120256125927
#  Case 2062: biases: 0.06757479161024094
#  Case 2063: biases: 0.05087261274456978
#  Case 2064: biases: -0.01560444850474596
#  Case 2065: biases: 0.013918026350438595
#  Case 2066: biases: -0.03202629089355469
#  Case 2067: biases: 0.10175827890634537
#  Case 2068: biases: -0.04914132133126259
#  Case 2069: biases: -0.03596697375178337
#  Case 2070: biases: 0.051237378269433975
#  Case 2071: biases: 0.0867401733994484
#  Case 2072: biases: -0.1120532676577568
#  Case 2073: biases: 0.021500075235962868
#  Case 2074: biases: -0.00792926549911499
#  Case 2075: biases: 0.07904236763715744
#  Case 2076: biases: -0.04843783751130104
#  Case 2077: biases: -0.021532656624913216
#  Case 2078: biases: -0.08031895756721497
#  Case 2079: biases: -0.041152480989694595
#  Case 2080: biases: -0.11238756030797958
#  Case 2081: biases: -0.0228930301964283
#  Case 2082: biases: -0.0903155654668808
#  Case 2083: biases: -0.04268719255924225
#  Case 2084: biases: -0.02561287395656109
#  Case 2085: biases: -0.020393865182995796
#  Case 2086: biases: 0.06277700513601303
#  Case 2087: biases: -0.05312862619757652
#  Case 2088: biases: 0.013060354627668858
#  Case 2089: biases: -0.093070849776268
#  Case 2090: biases: -0.01732536032795906
#  Case 2091: biases: 0.042081329971551895
#  Case 2092: biases: 0.049914080649614334
#  Case 2093: biases: -0.07407639175653458
#  Case 2094: biases: -0.09151579439640045
#  Case 2095: biases: -0.039724819362163544
#  Case 2096: biases: -0.058741141110658646
#  Case 2097: biases: -0.0652860552072525
#  Case 2098: biases: -0.04834276810288429
#  Case 2099: biases: -0.12053796648979187
#  Case 2100: biases: 0.17034661769866943
#  Case 2101: biases: -0.06311697512865067
#  Case 2102: biases: -0.09607875347137451
#  Case 2103: biases: -0.018882237374782562
#  Case 2104: biases: 0.07820992171764374
#  Case 2105: biases: 0.06106577813625336
#  Case 2106: biases: 0.011540602892637253
#  Case 2107: biases: 0.15385694801807404
#  Case 2108: biases: -0.019324176013469696
#  Case 2109: biases: -0.041118841618299484
#  Case 2110: biases: 0.035486847162246704
#  Case 2111: biases: 0.05254185572266579
#  Case 2112: biases: 0.15278556942939758
#  Case 2113: biases: -0.0037388477940112352
#  Case 2114: biases: 0.060868192464113235
#  Case 2115: biases: -0.09100864827632904
#  Case 2116: biases: -0.036389414221048355
#  Case 2117: biases: -0.1505575031042099
#  Case 2118: biases: 0.012411282397806644
#  Case 2119: biases: -0.05013762041926384
#  Case 2120: biases: 0.11335420608520508
#  Case 2121: biases: 0.1513516902923584
#  Case 2122: biases: -0.022952960804104805
#  Case 2123: biases: 0.07504646480083466
#  Case 2124: biases: -0.07093734294176102
#  Case 2125: biases: 0.1771942377090454
#  Case 2126: biases: -0.014371105469763279
#  Case 2127: biases: -0.07851801812648773
#  Case 2128: biases: -0.06515613198280334
#  Case 2129: biases: -0.0874728187918663
#  Case 2130: biases: -0.06572435796260834
#  Case 2131: biases: -0.07768618315458298
#  Case 2132: biases: -0.017459996044635773
#  Case 2133: biases: -0.053818993270397186
#  Case 2134: biases: 0.05767355114221573
#  Case 2135: biases: -0.03306950256228447
#  Case 2136: biases: 0.10001105070114136
#  Case 2137: biases: -0.03752440959215164
#  Case 2138: biases: -0.03296317532658577
#  Case 2139: biases: -0.01553652249276638
#  Case 2140: biases: -0.03233349695801735
#  Case 2141: biases: -0.10531529784202576
#  Case 2142: biases: 0.019428709521889687
#  Case 2143: biases: 0.018166612833738327
#  Case 2144: biases: -0.06374068558216095
#  Case 2145: biases: 0.05386219546198845
#  Case 2146: biases: -0.12929287552833557
#  Case 2147: biases: -0.0741017684340477
#  Case 2148: biases: -0.0162978395819664
#  Case 2149: biases: -0.009829247370362282
#  Case 2150: biases: -0.08112745732069016
#  Case 2151: biases: 0.027821023017168045
#  Case 2152: biases: 0.03975404426455498
#  Case 2153: biases: -0.038869090378284454
#  Case 2154: biases: 0.0466400645673275
#  Case 2155: biases: 0.043070364743471146
#  Case 2156: biases: 0.0013630626490339637
#  Case 2157: biases: 0.08143927156925201
#  Case 2158: biases: -0.03142997622489929
#  Case 2159: biases: 0.00928562693297863
#  Case 2160: biases: 0.012576235458254814
#  Case 2161: biases: -0.09231899678707123
#  Case 2162: biases: 0.09293671697378159
#  Case 2163: biases: -0.014605431817471981
#  Case 2164: biases: -0.06389120221138
#  Case 2165: biases: 0.1329350471496582
#  Case 2166: biases: -0.011983199045062065
#  Case 2167: biases: 0.036227747797966
#  Case 2168: biases: -0.050097815692424774
#  Case 2169: biases: 0.023196883499622345
#  Case 2170: biases: 0.10737726092338562
#  Case 2171: biases: 0.04973141476511955
#  Case 2172: biases: 0.03696849197149277
#  Case 2173: biases: -0.13749271631240845
#  Case 2174: biases: 0.0966910868883133
#  Case 2175: biases: 0.02231713756918907
#  Case 2176: biases: -0.07360585778951645
#  Case 2177: biases: 0.015961570665240288
#  Case 2178: biases: -0.04917238652706146
#  Case 2179: biases: 0.03630896285176277
#  Case 2180: biases: -0.019565001130104065
#  Case 2181: biases: 0.06971793621778488
#  Case 2182: biases: -0.10721743851900101
#  Case 2183: biases: 0.03985001519322395
#  Case 2184: biases: 0.09860237687826157
#  Case 2185: biases: -0.07131604105234146
#  Case 2186: biases: -0.09202254563570023
#  Case 2187: biases: -0.007364979479461908
#  Case 2188: biases: -0.07338464260101318
#  Case 2189: biases: -0.027958210557699203
#  Case 2190: biases: 0.1220647394657135
#  Case 2191: biases: -0.0770929753780365
#  Case 2192: biases: -0.09394657611846924
#  Case 2193: biases: 0.04845225438475609
#  Case 2194: biases: -0.06779973953962326
#  Case 2195: biases: -0.057396747171878815
#  Case 2196: biases: 0.06415101885795593
#  Case 2197: biases: -0.050588127225637436
#  Case 2198: biases: -0.08985775709152222
#  Case 2199: biases: -0.011635832488536835
#  Case 2200: biases: -0.036447010934352875
#  Case 2201: biases: 0.0664411410689354
#  Case 2202: biases: -0.09189753979444504
#  Case 2203: biases: -0.08009084314107895
#  Case 2204: biases: -0.027433497831225395
#  Case 2205: biases: -0.027546139433979988
#  Case 2206: biases: -0.059338703751564026
#  Case 2207: biases: 0.030972998589277267
#  Case 2208: biases: 0.03471679240465164
#  Case 2209: biases: 0.03180176392197609
#  Case 2210: biases: 0.029232097789645195
#  Case 2211: biases: 0.009687482379376888
#  Case 2212: biases: -0.043071430176496506
#  Case 2213: biases: -0.007822589948773384
#  Case 2214: biases: 0.054164230823516846
#  Case 2215: biases: 0.05849915370345116
#  Case 2216: biases: 0.014209244400262833
#  Case 2217: biases: -0.05806666985154152
#  Case 2218: biases: -0.0676843672990799
#  Case 2219: biases: -0.03692987933754921
#  Case 2220: biases: -0.04939372465014458
#  Case 2221: biases: -0.044194288551807404
#  Case 2222: biases: -0.07551226764917374
#  Case 2223: biases: -0.016673864796757698
#  Case 2224: biases: -0.07858173549175262
#  Case 2225: biases: -0.08204776793718338
#  Case 2226: biases: -0.12231354415416718
#  Case 2227: biases: 0.06204000487923622
#  Case 2228: biases: 0.12005651742219925
#  Case 2229: biases: -0.025362277403473854
#  Case 2230: biases: -0.10686784982681274
#  Case 2231: biases: -0.02879127860069275
#  Case 2232: biases: 0.04077459126710892
#  Case 2233: biases: 0.06661737710237503
#  Case 2234: biases: 0.06500410288572311
#  Case 2235: biases: -0.08268450945615768
#  Case 2236: biases: 0.042021479457616806
#  Case 2237: biases: 0.04120940715074539
#  Case 2238: biases: 0.08624204993247986
#  Case 2239: biases: -0.07976943999528885
#  Case 2240: biases: 0.034988563507795334
#  Case 2241: biases: 0.03472375497221947
#  Case 2242: biases: 0.04482148960232735
#  Case 2243: biases: -0.09814770519733429
#  Case 2244: biases: -0.05846339464187622
#  Case 2245: biases: 0.08325855433940887
#  Case 2246: biases: -0.062933549284935
#  Case 2247: biases: 0.07597185671329498
#  Case 2248: biases: -0.03708919137716293
#  Case 2249: biases: -0.12052077054977417
#  Case 2250: biases: -0.05637253820896149
#  Case 2251: biases: -0.002071813214570284
#  Case 2252: biases: 0.011364089325070381
#  Case 2253: biases: -0.09762194007635117
#  Case 2254: biases: -0.06110227108001709
#  Case 2255: biases: 0.005456198938190937
#  Case 2256: biases: -0.08768330514431
#  Case 2257: biases: -0.057094596326351166
#  Case 2258: biases: -0.07651881873607635
#  Case 2259: biases: -0.054677676409482956
#  Case 2260: biases: -0.029968159273266792
#  Case 2261: biases: 0.05294661596417427
#  Case 2262: biases: -0.05003407970070839
#  Case 2263: biases: -0.04774164780974388
#  Case 2264: biases: 0.07158926129341125
#  Case 2265: biases: -0.004770104773342609
#  Case 2266: biases: -0.06609503924846649
#  Case 2267: biases: 0.06353431940078735
#  Case 2268: biases: 0.016898207366466522
#  Case 2269: biases: -0.025358736515045166
#  Case 2270: biases: 0.13014103472232819
#  Case 2271: biases: -0.12322931736707687
#  Case 2272: biases: 0.028920941054821014
#  Case 2273: biases: 0.06419709324836731
#  Case 2274: biases: -0.1101701632142067
#  Case 2275: biases: -0.05791439116001129
#  Case 2276: biases: -0.036565180867910385
#  Case 2277: biases: -0.07382999360561371
#  Case 2278: biases: -0.024278687313199043
#  Case 2279: biases: -0.005184058099985123
#  Case 2280: biases: -0.07841703295707703
#  Case 2281: biases: -0.03429367393255234
#  Case 2282: biases: -0.11354303359985352
#  Case 2283: biases: -0.10271641612052917
#  Case 2284: biases: 0.003991599660366774
#  Case 2285: biases: -0.05145968496799469
#  Case 2286: biases: -0.006640974432229996
#  Case 2287: biases: 0.03145334869623184
#  Case 2288: biases: -0.04459197074174881
#  Case 2289: biases: -0.036952439695596695
#  Case 2290: biases: 0.008363045752048492
#  Case 2291: biases: 0.08062302321195602
#  Case 2292: biases: 0.00858699344098568
#  Case 2293: biases: -0.0962517112493515
#  Case 2294: biases: 0.08782760053873062
#  Case 2295: biases: -0.0457359179854393
#  Case 2296: biases: -0.0731520727276802
#  Case 2297: biases: -0.0033054512459784746
#  Case 2298: biases: -0.026219123974442482
#  Case 2299: biases: -0.04747714102268219
#  Case 2300: biases: -0.11701531708240509
#  Case 2301: biases: 0.061004363000392914
#  Case 2302: biases: -0.052453309297561646
#  Case 2303: biases: -0.07894861698150635
#  Case 2304: biases: -0.17364594340324402
#  Case 2305: biases: 0.0984659194946289
#  Case 2306: biases: 0.006543947383761406
#  Case 2307: biases: 0.08867518603801727
#  Case 2308: biases: 0.04572417587041855
#  Case 2309: biases: 0.06236007437109947
#  Case 2310: biases: 0.019008444622159004
#  Case 2311: biases: -0.05222945660352707
#  Case 2312: biases: 0.05948338657617569
#  Case 2313: biases: -0.07790388911962509
#  Case 2314: biases: -0.0338149294257164
#  Case 2315: biases: 0.021199986338615417
#  Case 2316: biases: -0.0810185894370079
#  Case 2317: biases: 0.0024470065254718065
#  Case 2318: biases: -0.1081312969326973
#  Case 2319: biases: 0.10143709182739258
#  Case 2320: biases: 0.001365652191452682
#  Case 2321: biases: 0.007787902839481831
#  Case 2322: biases: 0.0503477081656456
#  Case 2323: biases: 0.02465694770216942
#  Case 2324: biases: 0.011717253364622593
#  Case 2325: biases: -0.006467108149081469
#  Case 2326: biases: 0.05899893119931221
#  Case 2327: biases: -0.04759632796049118
#  Case 2328: biases: 0.1416534185409546
#  Case 2329: biases: -0.03358494117856026
#  Case 2330: biases: -0.14165401458740234
#  Case 2331: biases: -0.01578672043979168
#  Case 2332: biases: 0.09240970015525818
#  Case 2333: biases: -0.0007482171058654785
#  Case 2334: biases: -0.09764731675386429
#  Case 2335: biases: -0.059965670108795166
#  Case 2336: biases: 0.09887970238924026
#  Case 2337: biases: 0.04907168447971344
#  Case 2338: biases: -0.08725562691688538
#  Case 2339: biases: -0.10562910884618759
#  Case 2340: biases: 0.06100974977016449
#  Case 2341: biases: -0.0240925345569849
#  Case 2342: biases: 0.1021290123462677
#  Case 2343: biases: 0.049329161643981934
#  Case 2344: biases: 0.0367562361061573
#  Case 2345: biases: 0.09085839986801147
#  Case 2346: biases: 0.014753005467355251
#  Case 2347: biases: -0.019242025911808014
#  Case 2348: biases: -0.0020718753803521395
#  Case 2349: biases: -0.055808600038290024
#  Case 2350: biases: 0.04887542128562927
#  Case 2351: biases: 0.026302708312869072
#  Case 2352: biases: 0.07408569008111954
#  Case 2353: biases: 0.009687699377536774
#  Case 2354: biases: -0.10546250641345978
#  Case 2355: biases: 0.01111693400889635
#  Case 2356: biases: -0.09120308607816696
#  Case 2357: biases: -0.02134907804429531
#  Case 2358: biases: 0.12267564982175827
#  Case 2359: biases: -0.09749185293912888
#  Case 2360: biases: 0.06379351019859314
#  Case 2361: biases: 0.002762732794508338
#  Case 2362: biases: -0.0945148691534996
#  Case 2363: biases: -0.1184922382235527
#  Case 2364: biases: 0.0237420741468668
#  Case 2365: biases: -0.04125364124774933
#  Case 2366: biases: 0.02905748412013054
#  Case 2367: biases: -0.03512749820947647
#  Case 2368: biases: -0.025607919320464134
#  Case 2369: biases: -0.0583992525935173
#  Case 2370: biases: 0.0828293040394783
#  Case 2371: biases: -0.053246110677719116
#  Case 2372: biases: 0.10347598791122437
#  Case 2373: biases: -0.06616275757551193
#  Case 2374: biases: 0.12893493473529816
#  Case 2375: biases: 0.04297145456075668
#  Case 2376: biases: 0.06267456710338593
#  Case 2377: biases: 0.0876745730638504
#  Case 2378: biases: 0.10681511461734772
#  Case 2379: biases: 0.06462457776069641
#  Case 2380: biases: 0.13233791291713715
#  Case 2381: biases: 0.04059392586350441
#  Case 2382: biases: 0.059174131602048874
#  Case 2383: biases: 0.05739278346300125
#  Case 2384: biases: 0.06755974888801575
#  Case 2385: biases: 0.017729634419083595
#  Case 2386: biases: -0.02311749942600727
#  Case 2387: biases: -0.08283338695764542
#  Case 2388: biases: 0.0293808002024889
#  Case 2389: biases: 1.7171456420328468e-05
#  Case 2390: biases: 0.0010029004188254476
#  Case 2391: biases: -0.06463088095188141
#  Case 2392: biases: -0.057948023080825806
#  Case 2393: biases: -0.05212888866662979
#  Case 2394: biases: -0.005451337434351444
#  Case 2395: biases: -0.08637668192386627
#  Case 2396: biases: -0.0008593518869020045
#  Case 2397: biases: 0.0023505939170718193
#  Case 2398: biases: 0.02450243942439556
#  Case 2399: biases: -0.005540885962545872
#  Case 2400: biases: 0.08680036664009094

# %% [markdown]
# ### Oracle distance by best neighbors possible

# %%
import torch

def weighted_l2_distance(query, cases, feature_weights, regime_idx=None):
    """
    Ground-truth weighted L2 distance between a single query and a batch of cases.

    query:            [D] or [1, D]
    cases:            [N, D]
    feature_weights:  [D]           (single regime)
                      or [R, D]     (multiple regimes, when regime_idx is not None)
    regime_idx:       int or None   (which regime to use, if feature_weights is [R, D])
    """
    # Ensure query is [1, D]
    if query.dim() == 1:
        query = query.unsqueeze(0)  # [1, D]

    # Select weights depending on shape / regime_idx
    if feature_weights.dim() == 1:
        # Old behavior: single [D] vector
        fw = feature_weights.unsqueeze(0)  # [1, D]
    else:
        # feature_weights is [R, D]; pick row regime_idx if given
        if regime_idx is None:
            # Fallback: use first regime (keeps it from crashing if called like old code)
            fw = feature_weights[0].unsqueeze(0)  # [1, D]
        else:
            fw = feature_weights[regime_idx].unsqueeze(0)  # [1, D]

    # Broadcast query to [N, D]
    diffs = cases - query  # [N, D]
    sq = diffs ** 2
    # Multiply by true feature weights
    weighted_sq = sq * fw  # broadcast [1, D] -> [N, D]
    dist = weighted_sq.sum(dim=-1).sqrt()  # [N]
    return dist

# oracle evaluation: average true distance of top-k neighbors
def avg_true_distance_knn(
    X_train,
    X_query,
    feature_weights,
    k=5,
    device=device,
    use_regime_weights=False,
    regime_labels_query=None,
):
    """
    For each query in X_query, retrieve top-k neighbors from X_train
    using the true weighted distance, and return the average
    ground-truth distance of those neighbors.

    X_train:             [N_train, D]
    X_query:             [N_query, D]
    feature_weights:     [D]      (single-regime weights, old behavior)
                         or [R,D] (multi-regime weights when use_regime_weights=True)
    k:                   int, number of neighbors
    device:              torch device
    use_regime_weights:  if True and feature_weights is [R,D], select row per query
    regime_labels_query:
        - if use_regime_weights=False: ignored
        - if use_regime_weights=True: long tensor of shape [N_query] with regime indices (e.g., 0/1)
    """
    X_train = X_train.to(device)
    X_query = X_query.to(device)
    feature_weights = feature_weights.to(device)

    use_regime = False
    if use_regime_weights and feature_weights.dim() == 2:
        assert regime_labels_query is not None, \
            "regime_labels_query must be provided when use_regime_weights=True and feature_weights is [R,D]."
        regime_labels_query = regime_labels_query.to(device)
        assert regime_labels_query.shape[0] == X_query.shape[0], \
            "regime_labels_query must have same length as X_query."
        use_regime = True

    all_topk_dists = []

    with torch.no_grad():
        for i, q in enumerate(X_query):
            regime_idx = int(regime_labels_query[i].item()) if use_regime else None
            dists = weighted_l2_distance(q, X_train, feature_weights, regime_idx=regime_idx)
            topk = torch.topk(dists, k=k, largest=False).values
            all_topk_dists.append(topk.mean().item())

    return float(sum(all_topk_dists) / len(all_topk_dists))

# %%
k_eval = 5
if regime_weights:
    knn_avg_dist = avg_true_distance_knn(
        X_train=X_train,
        X_query=X_val,
        feature_weights=true_feature_weights_glocal,   # [2, D]
        k=k_eval,
        device=device,
        use_regime_weights=True,
        regime_labels_query=regime_labels_val          # [N_val]
    )
else:
    knn_avg_dist = avg_true_distance_knn(
        X_train=X_train,
        X_query=X_val,
        feature_weights=true_feature_weights,          # [D]
        k=k_eval,
        device=device
    )

print(f"Oracle k-NN — mean ground-truth distance of top-{k_eval} neighbors: {knn_avg_dist:.4f}")
# Out:
# Oracle k-NN — mean ground-truth distance of top-5 neighbors: 0.2402

# %% [markdown]
# ### NN-kNN

# %%
def avg_true_distance_nnknn(
    model,
    X_query,
    feature_weights,
    k=None,
    batch_size=256,
    device=device,
    use_regime_weights=False,
    regime_labels_query=None,
):
    """
    Use NN-kNN's own learned case-attention to get top-k neighbors,
    then measure ground-truth weighted distance in input space.

    X_query:
        [N_query, D]  (same feature space the model was trained on)

    feature_weights:
        [D]           single-regime ground-truth similarity weights
        or
        [R, D]        multi-regime weights (when use_regime_weights=True)

    use_regime_weights:
        - False (default): behave like the old version, ignoring regimes.
        - True: feature_weights must be [R, D] and regime_labels_query must be provided.
    """
    model.to(device)
    model.eval()
    model.top_k_mode = True   # ensure top-k outputs are produced

    X_query        = X_query.to(device)
    feature_weights = feature_weights.to(device)

    # Decide whether we actually use per-regime weights
    use_regime = False
    if use_regime_weights and feature_weights.dim() == 2:
        assert regime_labels_query is not None, \
            "regime_labels_query must be provided when use_regime_weights=True and feature_weights is [R,D]."
        regime_labels_query = regime_labels_query.to(device)
        assert regime_labels_query.shape[0] == X_query.shape[0], \
            "regime_labels_query must have same length as X_query."
        use_regime = True

    if k is None:
        # fall back to model.top_k if not specified
        k = getattr(model, "top_k", 5)

    all_topk_means = []

    with torch.no_grad():
        for start in range(0, X_query.size(0), batch_size):
            xb = X_query[start:start+batch_size]          # [B, D]
            if xb.size(0) == 0:
                continue

            # forward pass with top_k_mode enabled
            final_pred, pred_vals, pre_adapted, topk_cases, topk_labels, topk_acts = model(xb)
            # topk_cases: [B, K, ...] (case-space; flatten to [B, K, D])

            B, K = topk_cases.size(0), topk_cases.size(1)
            xb_flat         = xb.view(B, -1)             # [B, D]
            topk_cases_flat = topk_cases.view(B, K, -1)  # [B, K, D]

            for i in range(B):
                q     = xb_flat[i]          # [D]
                neigh = topk_cases_flat[i, :k]  # [k, D]

                if use_regime:
                    q_idx      = start + i           # global index into X_query
                    regime_idx = int(regime_labels_query[q_idx].item())
                else:
                    regime_idx = None

                d_true = weighted_l2_distance(q, neigh, feature_weights, regime_idx=regime_idx)  # [k]
                all_topk_means.append(d_true.mean().item())

    return float(sum(all_topk_means) / len(all_topk_means))

# %%
k_eval = 5  # same k as in your other evaluations

if regime_weights:
    nnknn_avg_dist = avg_true_distance_nnknn(
        model              = model,
        X_query            = X_val,
        feature_weights    = true_feature_weights_glocal,  # [2, D]
        k                  = k_eval,
        device             = device,
        use_regime_weights = True,
        regime_labels_query= regime_labels_val             # [N_val], 0/1
    )
else:
    nnknn_avg_dist = avg_true_distance_nnknn(
        model              = model,
        X_query            = X_val,
        feature_weights    = true_feature_weights,         # [D]
        k                  = k_eval,
        device             = device
    )

print(f"NN-kNN — mean ground-truth distance of top-{k_eval} neighbors: {nnknn_avg_dist:.4f}")
# Out:
# NN-kNN — mean ground-truth distance of top-5 neighbors: 0.2998

# %% [markdown]
# ### Vanilla kNN

# %%
@torch.no_grad()
def avg_true_distance_knn_vanilla(
    X_train,
    X_query,
    feature_weights,
    k=5,
    batch_size=512,
    device=device,
    use_regime_weights=False,
    regime_labels_query=None,
):
    """
    Vanilla k-NN retrieval in Euclidean X-space, evaluated with
    ground-truth weighted distance in the original feature space.

    Retrieval:
        d_euclid = torch.cdist(xq, Xtr, p=2)
        top-k by Euclidean distance.

    Evaluation:
        weighted_l2_distance(query, neighbors, feature_weights)

    feature_weights:
        [D]      single-regime weights (old behavior)
        or
        [R, D]   multi-regime weights when use_regime_weights=True
    """
    Xtr = X_train.to(device)
    Xq  = X_query.to(device)
    fw  = feature_weights.to(device)

    # Decide whether to use per-regime weights
    use_regime = False
    if use_regime_weights and fw.dim() == 2:
        assert regime_labels_query is not None, \
            "regime_labels_query must be provided when use_regime_weights=True and feature_weights is [R,D]."
        regime_labels_query = regime_labels_query.to(device)
        assert regime_labels_query.shape[0] == Xq.shape[0], \
            "regime_labels_query must have same length as X_query."
        use_regime = True

    all_topk_means = []

    for i in range(0, Xq.size(0), batch_size):
        xq_batch = Xq[i:i+batch_size]              # [b, D]
        if xq_batch.size(0) == 0:
            continue

        # --- Retrieval in Euclidean space ---
        d_euclid = torch.cdist(xq_batch, Xtr, p=2)              # [b, Ntr]
        vals, idx = torch.topk(d_euclid, k=k, largest=False)    # [b, k]

        # --- Evaluate those neighbors in "true" metric ---
        for j in range(xq_batch.size(0)):
            q     = xq_batch[j]        # [D]
            neigh = Xtr[idx[j]]        # [k, D]

            if use_regime:
                q_idx      = i + j
                regime_idx = int(regime_labels_query[q_idx].item())
            else:
                regime_idx = None

            d_true = weighted_l2_distance(q, neigh, fw, regime_idx=regime_idx)  # [k]
            all_topk_means.append(d_true.mean().item())

    return float(sum(all_topk_means) / len(all_topk_means))

# %%
k_eval = 5  # or set explicitly

if regime_weights:
    knn_vanilla_avg_dist = avg_true_distance_knn_vanilla(
        X_train           = X_train,
        X_query           = X_val,
        feature_weights   = true_feature_weights_glocal,  # [2, D]
        k                 = k_eval,
        batch_size        = 64,
        device            = device,
        use_regime_weights= True,
        regime_labels_query = regime_labels_val          # [N_val], 0/1
    )
else:
    knn_vanilla_avg_dist = avg_true_distance_knn_vanilla(
        X_train        = X_train,
        X_query        = X_val,
        feature_weights= true_feature_weights,           # [D]
        k              = k_eval,
        batch_size     = 64,
        device         = device
    )

print(
    f"Vanilla k-NN (Euclidean) — mean ground-truth distance of top-{k_eval} neighbors: "
    f"{knn_vanilla_avg_dist:.4f}"
)
# Out:
# Vanilla k-NN (Euclidean) — mean ground-truth distance of top-5 neighbors: 0.3284

# %% [markdown]
# ## Artificial Dataset: Case Randomness vs Case Weights/Biases
#
# This is only useful if you are using the synthetic regression data set

# %%
# --- Case Randomness vs Case Weights/Biases ---
# Requirements: torch, matplotlib
# Assumes:
#   - X : [N, D] torch.Tensor  (training cases used to build `model`)
#   - y : [N, 1] torch.Tensor  (training labels used to build `model`)
#   - model : nnknn_model.NN_KNN_Model (already trained), where model.weights / model.biases are per-case
#   - true_w : optional torch.Tensor of shape [D, 1]; if absent, we estimate w_hat via OLS on (X, y)

import torch
import matplotlib.pyplot as plt

def compute_case_randomness(X, y, true_w=None):
    """
    Returns a 1D tensor of length N with per-case 'randomness' magnitudes.
    If true_w is provided, randomness_i = | y_i - X_i @ true_w |.
    Otherwise, it fits an OLS w_hat and uses | y_i - X_i @ w_hat |.
    """
    X_ = X.detach()
    y_ = y.detach().view(-1, 1)

    if true_w is None:
        # OLS: w_hat = (X^T X)^{-1} X^T y   (PINV is safer numerically)
        w_hat = torch.pinverse(X_.T @ X_) @ (X_.T @ y_)
        resid = y_ - X_ @ w_hat
    else:
        resid = y_ - X_ @ true_w.detach()

    # Magnitude of the noise term; use absolute value (you can switch to square by **2 if preferred)
    case_randomness = resid.abs().view(-1)  # [N]
    return case_randomness

@torch.no_grad()
def plot_randomness_correlations(model, X, y, true_w=None, title_prefix=""):
    # 1) Compute per-case randomness
    rnd = compute_case_randomness(X, y, true_w=true_w).cpu()

    # 2) Pull learned per-case weights & biases from the NN-kNN model
    # w_case = model.weights.detach().cpu().view(-1)   # [N]
    b_case = model.biases.detach().cpu().view(-1)    # [N]

    # 3) Simple Pearson correlations (no scipy needed)
    def pearson_r(a, b, eps=1e-12):
        a = a - a.mean()
        b = b - b.mean()
        num = (a * b).sum()
        den = (a.pow(2).sum().sqrt() * b.pow(2).sum().sqrt()).clamp_min(eps)
        return (num / den).item()

    # r_w  = pearson_r(rnd, w_case)
    r_b  = pearson_r(rnd, b_case)

    # 4) Plots
    # plt.figure(figsize=(6,5))
    # plt.scatter(rnd.numpy(), w_case.numpy(), s=12)
    # plt.xlabel("Case randomness |y - X @ w|")
    # plt.ylabel("Case weight (model.weights)")
    # plt.title(f"{title_prefix}Randomness vs Case Weights (Pearson r = {r_w:.3f})")
    # plt.grid(True, alpha=0.25)
    # plt.tight_layout()
    # plt.show()

    plt.figure(figsize=(6,5))
    plt.scatter(rnd.numpy(), b_case.numpy(), s=12)
    plt.xlabel("Case randomness |y - X @ w|")
    plt.ylabel("Case bias (model.biases)")
    plt.title(f"{title_prefix}Randomness vs Case Biases (Pearson r = {r_b:.3f})")
    plt.grid(True, alpha=0.25)
    plt.tight_layout()
    plt.show()

    # print(f"Pearson correlation (randomness ↔ case weights): {r_w:.4f}")
    print(f"Pearson correlation (randomness ↔ case biases):  {r_b:.4f}")

# ---- Usage ----
# If you know true_w from your generator:
plot_randomness_correlations(model, X_train_raw, y_train_raw, true_w=true_w, title_prefix="NN-kNN: ")

# If you don't have true_w (e.g., on a real dataset), just omit it and it will use OLS residuals:
# plot_randomness_correlations(model, X, y, title_prefix="NN-kNN: ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 76
#      72     print(f"Pearson correlation (randomness ↔ case biases):  {r_b:.4f}")
#      74 # ---- Usage ----
#      75 # If you know true_w from your generator:
# ---> 76 plot_randomness_correlations(model, X_train, y_train, true_w=true_w, title_prefix="NN-kNN: ")
#      78 # If you don't have true_w (e.g., on a real dataset), just omit it and it will use OLS residuals:
#      79 # plot_randomness_correlations(model, X, y, title_prefix="NN-kNN: ")
#
# File c:\venvs\nnknn311\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# Cell In[59], line 71, in plot_randomness_correlations(model, X, y, true_w, title_prefix)
#      68 plt.tight_layout()
#      69 plt.show()
# ---> 71 print(f"Pearson correlation (randomness ↔ case weights): {r_w:.4f}")
#      72 print(f"Pearson correlation (randomness ↔ case biases):  {r_b:.4f}")
#
# NameError: name 'r_w' is not defined

# %% [markdown]
# ## Case Base Cleaning
#
# What happens if we only keep cases with weights and biases that is more than 1 (their initial default values).
#
# This experiment needs to generally applicable to whatever data set is being used

# %%
#TODO,

# %% [markdown]
# # Depression physical symptoms: Explanation by feature

# %%
import torch
import pandas as pd

# 1. Get the glocal feature weights from the trained model
# feature_weights shape: (set_num, feature_dim)
fw = model.glocal_weightor.feature_weights

print("feature_weights shape:", fw.shape)

# If you only have 1 weight set (most likely), take the first row
# If you have multiple, change set_idx to 1,2,... as needed
set_idx = 0
w = fw[set_idx].detach().cpu().view(-1)  # shape: [feature_dim]

# 2. Your column texts (exact list you gave)
columns = ['1. Most of the time I have difficulty concentrating on simple tasks',
 "2. I don't feel like doing my daily duties",
 '3. My friends or family have told me that I look different',
 '4. When I think about the future it is difficult for me to imagine it clearly',
 '5. People around me often ask me how I feel',
 '6. I consider that my life is full of good things',
 '7. My hobbies are still important to me',
 "8. I'm still as punctual as I have always been",
 '9. If I had the chance, I would spend all day in my bed',
 '10. I have found that I can spend a lot of time scrolling the screen \nof my cell phone without searching or stopping at anything in particular',
 '11. When someone asks me something, I have noticed that I take longer than normal to\nrespond',
 '12. I have noticed my body shaken without any cause',
 '13. I felt more encouraged to do my daily activities before',
 "14. Sometimes I wake up sad and I can't explain why",
 '15. In recent months I usually reproach myself for things from the past',
 '16. I think my thoughts are strange or different from before',
 '17. I feel guilty about the decisions that I have made',
 "18. I don't feel as comfortable with my body as I did before",
 "19. I don't feel successful compared to others",
 '20. It is difficult for me to make decisions even if they are simple',
 "21. I'm capable of achieving what I propose to myself",
 '22. It is not difficult for me to understand something the first time',
 '23. I have thought more than before about what my death would be like',
 '24. Being dead seems to be a solution to some problems',
 '25. I would rather stay home than go out with my friends',
 '26. I like to attend family gatherings',
 '27. I feel excited when thinking about my life project',
 '28. The decisions I have made so far have been the right ones',
 '29. I am able to carry out my activities as I have always been',
 '30. I like to be in touch with my friends and family through social media',
 '31. It is easy for me to choose a photograph of myself to show it on social media',
 '32. I am proud of what I have achieved so far',
 '33. I have trouble remembering things easily',
 '34. In recent months I have had discussions with my schoolmates or colleagues',
 '35. I constantly imagine that something will go wrong at my work or at school',
 '36. I am afraid of being worng when doing my homework',
 "37. I'm not too worried about what might happen in a few weeks",
 "38. Lately it's hard for me to calm down",
 '39. Everything will be alright',
 '40. I can easily blank my mind',
 '41. I am bothered by insignificant things that were not important before',
 '42. I find it uncomfortable to be in a crowded place',
 '43. Sometimes i feel trapped',
 '44. I am easily frightened by unexpected noises',
 '45. I have difficulties to do one task at a time',
 '46. I have the feeling that I am forgetting to do something',
 '47. I can clearly express to others how I feel',
 '48. I can sleep easily',
 '49. I enjoy every moment of the day',
 '50. I imagine that at any moment a disaster of the\nnature may occur',
 '51. Sometimes I feel like I get tired easily',
 '52. Being locked in an elevator would be the worst thing that could happen to me',
 "53. I'm bothered by people walking slowly in front of me ",
 "54. I don't usually get upset if something doesn't go as expected",
 '55. Sometimes it is as if some conversations with friends or family become\ninterrogations',
 '56. I manage my schedule as I always have',
 '57. It bothers me to feel that people on the street approach me',
 '58. I have no difficulty understanding what people explain to me',
 '59. I consider that I am good at controlling my emotions',
 '60. In new situations I feel calm and encouraged',
 '61. Sometimes I forget what I wanted to say because I have several thoughts at the same time',
 '62. I would like to know what will happen in the future',
 '63. When I get angry I can easily explode',
 '64. I can put down my cell phone and dedicate myself to reading without distractions',
 '65. I worry that people will not understand what I mean.',
 '66. Sometimes I do not listen to what people say to me because I am thinking about other things',
 '67. I get angry easily',
 "68. I'm afraid that something bad could happen to me",
 '69. It is not important for me to meet set dates',
 '70. I like to think clearly before giving my opinion',
 '71. I use lies just to get out of certain problems',
 '72. If I have the opportunity to get in line to avoid wasting time, I do it',
 '73. I have difficulty making elaborate plans',
 '74. People have problems because of themselves',
 '75. No me parece importante lo que los otros piensen sobre mí',
 '76. Laws are not as important as others think',
 '77. I would regret betraying a friend',
 '78. I prefer that a negotiation supports the largest possible number of people involved',
 '79. It is easy for me to work in a team',
 '80. It is important to help people when they need it',
 '81. I have punched someone or thought of doing it',
 '82. If it was necessary I would pretend to be someone else to get something',
 '83. I consider it important to ensure my physical safety and that of those around me',
 '84. After an argument I usually go over what happened in my head',
 '85. I have a hard time controlling myself when I get angry',
 '86. Loyalty is important',
 "87. If I can help a person I will stop what I'm doing to help him",
 '88',
 '89. It makes me laugh when my superiors at school or at work demand something',
 '90. Deceiving people is not wrong if it is to achieve something important',
 '91. I like to greet my neighbors',
 '92. It does not seem serious to me to have some debts',
 '93. People steal because they have needs',
 '94. I lose control easily',
 "95. Neighbors must put up with each other's noises without complaining",
 '96. Littering on public roads is wrong',
 '97. People who commit crimes have their reasons for doing it',
 '98. It is normal to change jobs several times a year',
 '99. It is important to respect turns',
 '100. I could pretend to be someone else to achieve what I want',
 '101. I consider it important that all people have the same rights',
 '102. I have a hard time taking  "no" for an answer']

assert len(columns) == len(w), f"{len(columns)=}, {len(w)=}"

# 3. Build a DataFrame and sort by descending weight
df = pd.DataFrame({
    "item_index": range(1, len(columns) + 1),
    "item_text": columns,
    "weight": w.numpy(),
})

df_sorted = df.sort_values("weight", ascending=False).reset_index(drop=True)
pd.set_option('display.max_colwidth', None)   # or a big number like 500

# Show top 15 most important items
df_sorted.head(15)
# Out:
# feature_weights shape: torch.Size([1, 5])
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[25], line 119
#      15 # 2. Your column texts (exact list you gave)
#      16 columns = ['1. Most of the time I have difficulty concentrating on simple tasks',
#      17  "2. I don't feel like doing my daily duties",
#      18  '3. My friends or family have told me that I look different',
#    (...)    116  '101. I consider it important that all people have the same rights',
#     117  '102. I have a hard time taking  "no" for an answer']
# --> 119 assert len(columns) == len(w), f"{len(columns)=}, {len(w)=}"
#     121 # 3. Build a DataFrame and sort by descending weight
#     122 df = pd.DataFrame({
#     123     "item_index": range(1, len(columns) + 1),
#     124     "item_text": columns,
#     125     "weight": w.numpy(),
#     126 })
#
# AssertionError: len(columns)=102, len(w)=5

# %%
df_sorted.tail(15)
# Out:
#      item_index  \
# 87           35
# 88           92
# 89           34
# 90           99
# 91           57
# 92           86
# 93           59
# 94           85
# 95           64
# 96           91
# 97           20
# 98           79
# 99           81
# 100         100
# 101          83
#
#                                                                                 item_text  \
# 87          35. I constantly imagine that something will go wrong at my work or at school
# 88                                  92. It does not seem serious to me to have some debts
# 89          34. In recent months I have had discussions with my schoolmates or colleagues
# 90                                                   99. It is important to respect turns
# 91                        57. It bothers me to feel that people on the street approach me
# 92                                                               86. Loyalty is important
# 93                               59. I consider that I am good at controlling my emotions
# 94                             85. I have a hard time controlling myself when I get angry
# 95   64. I can put down my cell phone and dedicate myself to reading without distractions
# 96                                                       91. I like to greet my neighbors
# 97                   20. It is difficult for me to make decisions even if they are simple
# 98                                                79. It is easy for me to work in a team
# 99                                      81. I have punched someone or thought of doing it
# 100                        100. I could pretend to be someone else to achieve what I want
# 101  83. I consider it important to ensure my physical safety and that of those around me
#
#        weight
# 87   0.456618
# 88   0.445569
# 89   0.440081
# 90   0.398854
# 91   0.389153
# 92   0.388535
# 93   0.369359
# 94   0.357962
# 95   0.354957
# 96   0.351390
# 97   0.350919
# 98   0.334496
# 99   0.314987
# 100  0.307118
# 101  0.229372

# %% [markdown]
# # Sanity Check

# %%
import sys
import pathlib

import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

# --- Make sure project root is on PYTHONPATH so `from model...` works ---
PROJECT_ROOT = pathlib.Path().resolve()  # assumes the notebook is run from project root
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# --- Optional: import your MLKR helper (model/mlkr.py) ---
try:
    from model.mlkr import run_mlkr_sklearn
except Exception as e:
    run_mlkr_sklearn = None
    print("[warn] Could not import `model.mlkr`. If needed, ensure `model/__init__.py` exists and restart the kernel.")
    print("       Import error:", repr(e))

K_BSL = 5
B_DIST = 512

@torch.no_grad()
def knn_predict_by_X(X_train, y_train, X_query, k=K_BSL, batch_size=B_DIST, device=device):
    Xtr = X_train.to(device)
    ytr = y_train.to(device).view(-1)
    preds = []
    for i in range(0, X_query.size(0), batch_size):
        xq = X_query[i:i+batch_size].to(device)
        d = torch.cdist(xq, Xtr, p=2)
        vals, idx = torch.topk(d, k=k, largest=False)
        nbr_y = ytr[idx]
        w = 1.0 / (vals + 1e-12)
        w = w / w.sum(dim=1, keepdim=True).clamp_min(1e-12)
        preds.append((w * nbr_y).sum(dim=1).cpu())
    return torch.cat(preds, dim=0)

@torch.no_grad()
def knn_oracle_predict_by_y(y_train, y_true_val, k=K_BSL, batch_size=B_DIST, device=device):
    # "Oracle" KNN that uses y_true distances (upper bound sanity check)
    ytr = y_train.to(device).view(1, -1)
    preds = []
    for i in range(0, y_true_val.numel(), batch_size):
        yq = y_true_val[i:i+batch_size].to(device).view(-1, 1)
        dy = torch.abs(ytr - yq)
        vals, idx = torch.topk(dy, k=k, largest=False)
        nbr_y = ytr.squeeze(0)[idx]
        w = 1.0 / (vals + 1e-12)
        w = w / w.sum(dim=1, keepdim=True).clamp_min(1e-12)
        preds.append((w * nbr_y).sum(dim=1).cpu())
    return torch.cat(preds, dim=0)

# --- Model predictions (z-space) ---
model.eval()
with torch.no_grad():
    preds = []
    B = 512
    for i in range(0, X_val.size(0), B):
        _, yhat, *_ = model(X_val[i:i+B].to(device))
        preds.append(yhat.detach().cpu().view(-1))
    y_pred_model_z = torch.cat(preds, dim=0).to(torch.float32)

y_true_z = y_val.detach().cpu().view(-1).to(torch.float32)

rmse_model_z = torch.sqrt(F.mse_loss(y_pred_model_z, y_true_z)).item()
print(f"Model Validation RMSE (z): {rmse_model_z:.4f}")

# --- Baselines (also z-space; y_train/y_val are z-scored in this notebook) ---
y_pred_knnX_z = knn_predict_by_X(X_train, y_train, X_val, k=K_BSL)
rmse_knnX_z = torch.sqrt(F.mse_loss(y_pred_knnX_z, y_true_z)).item()
print(f"Baseline KNN(X) RMSE (z):      {rmse_knnX_z:.4f}")

y_pred_knnY_z = knn_oracle_predict_by_y(y_train, y_true_z, k=K_BSL)
rmse_knnY_z = torch.sqrt(F.mse_loss(y_pred_knnY_z, y_true_z)).item()
print(f"Oracle KNN(y_true) RMSE (z):   {rmse_knnY_z:.4f}")

# --- MLKR baseline (metric-learn + sklearn KNN) ---
# NOTE: MLKR runs on CPU (sklearn); this is just a sanity-check baseline.
MLKR_K = 25
rmse_mlkr_z = None
y_pred_mlkr_z = None

try:
    from metric_learn import MLKR
    from sklearn.neighbors import KNeighborsRegressor

    Xtr_np = X_train.detach().cpu().numpy()
    ytr_np = y_train.detach().cpu().numpy().ravel()
    Xva_np = X_val.detach().cpu().numpy()

    print("Training MLKR...")
    mlkr = MLKR(
        n_components=None,         # set an int if you want a low-rank metric
        max_iter=1000,
        tol=1e-4,
        random_state=42,
    )
    mlkr.fit(Xtr_np, ytr_np)

    print("Training KNN (with learned metric)...")
    knn_mlkr = KNeighborsRegressor(
        n_neighbors=MLKR_K,
        weights="distance",
        metric=mlkr.get_metric(),   # Mahalanobis metric from MLKR
        algorithm="brute",
    )
    knn_mlkr.fit(Xtr_np, ytr_np)

    y_pred_mlkr_z = torch.from_numpy(knn_mlkr.predict(Xva_np)).to(torch.float32)
    rmse_mlkr_z = torch.sqrt(F.mse_loss(y_pred_mlkr_z, y_true_z)).item()
    print(f"MLKR+KNN RMSE (z):            {rmse_mlkr_z:.4f}")

    # If you want to verify via your helper function too (prints RAW RMSE):
    if run_mlkr_sklearn is not None:
        _ = run_mlkr_sklearn(
            X_train, y_train, X_val, y_val,
            cfg=dict(k=MLKR_K, n_components=None, max_iter=1000, dataset_name="(sanity-check)"),
            y_mean_raw=y_mean_raw,
            y_std_raw=y_std_raw,
        )

except ImportError:
    print("[warn] MLKR baseline skipped (missing deps). Install with:")
    print("       pip install metric-learn scikit-learn")

# --- Convert to raw units (since you stored y_std_raw from the original y) ---
if "y_std_raw" in globals():
    raw_std = float(y_std_raw)
    rmse_model_raw = rmse_model_z * raw_std
    rmse_knnX_raw  = rmse_knnX_z  * raw_std
    rmse_knnY_raw  = rmse_knnY_z  * raw_std
    print(f"Model RMSE (raw units):       {rmse_model_raw:.4f}")
    print(f"KNN(X) RMSE (raw units):      {rmse_knnX_raw:.4f}")
    print(f"Oracle RMSE (raw units):      {rmse_knnY_raw:.4f}")
    if rmse_mlkr_z is not None:
        rmse_mlkr_raw = rmse_mlkr_z * raw_std
        print(f"MLKR+KNN RMSE (raw units):    {rmse_mlkr_raw:.4f}")

# --- Plots in z-space (consistent) ---
def ovp_plot(y_t, y_p, title):
    plt.figure(figsize=(5,5))
    plt.scatter(y_t.numpy(), y_p.numpy(), s=8, alpha=0.7)
    mn = float(min(y_t.min().item(), y_p.min().item()))
    mx = float(max(y_t.max().item(), y_p.max().item()))
    plt.plot([mn, mx], [mn, mx], linestyle="--")
    plt.xlabel("True (z)")
    plt.ylabel("Predicted (z)")
    plt.title(title)
    plt.show()

ovp_plot(y_true_z, y_pred_model_z, f"Model (RMSEz={rmse_model_z:.3f})")
ovp_plot(y_true_z, y_pred_knnX_z,  f"KNN(X) (RMSEz={rmse_knnX_z:.3f})")
ovp_plot(y_true_z, y_pred_knnY_z,  f"Oracle KNN(y) (RMSEz={rmse_knnY_z:.3f})")
if y_pred_mlkr_z is not None:
    ovp_plot(y_true_z, y_pred_mlkr_z, f"MLKR+KNN (RMSEz={rmse_mlkr_z:.3f})")
# Out:
# [warn] Could not import `model.mlkr`. If needed, ensure `model/__init__.py` exists and restart the kernel.
#        Import error: ModuleNotFoundError("No module named 'metric_learn'")
# Model Validation RMSE (z): 0.8133
# Baseline KNN(X) RMSE (z):      0.5591
# Oracle KNN(y_true) RMSE (z):   0.0002
# [warn] MLKR baseline skipped (missing deps). Install with:
#        pip install metric-learn scikit-learn
# Model RMSE (raw units):       0.9350
# KNN(X) RMSE (raw units):      0.6427
# Oracle RMSE (raw units):      0.0003

# %%
X_train.device
# Out:
# device(type='cpu')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ##  MLP

# %%
# ===== Baseline 3: Multilayer Perceptron (regression) =====
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

# Use standardized tensors (you overwrote earlier)
X_train_z = X_train.to(device)
X_val_z   = X_val.to(device)
y_train_z = y_train.to(device).view(-1)
y_val_z   = y_val.to(device).view(-1)

train_ds = TensorDataset(X_train_z, y_train_z)
val_ds   = TensorDataset(X_val_z,   y_val_z)
train_loader = DataLoader(train_ds, batch_size=256, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=512, shuffle=False)

class MLPReg(nn.Module):
    def __init__(self, in_dim, hidden=(64, 32), dropout=0.10):
        super().__init__()
        layers = []
        d = in_dim
        for h in hidden:
            layers += [nn.Linear(d, h), nn.ReLU()]
            if dropout and dropout > 0:
                layers += [nn.Dropout(dropout)]
            d = h
        layers += [nn.Linear(d, 1)]
        self.net = nn.Sequential(*layers)
    def forward(self, x):
        return self.net(x).squeeze(1)   # predicts y in z-space

mlp = MLPReg(in_dim=X_train.shape[1], hidden=(64, 32), dropout=0.10).to(device)
opt = torch.optim.Adam(mlp.parameters(), lr=1e-3, weight_decay=1e-4)

@torch.no_grad()
def val_rmse_z(model):
    model.eval()
    preds, trues = [], []
    for xb, yb in val_loader:
        preds.append(model(xb.to(device)).cpu())
        trues.append(yb.cpu())
    yp = torch.cat(preds).view(-1)
    yt = torch.cat(trues).view(-1)
    return torch.sqrt(F.mse_loss(yp, yt)).item()

best_rmse, best_state = float("inf"), None
patience, wait = 20, 0
EPOCHS = 200

for epoch in range(1, EPOCHS + 1):
    mlp.train()
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        opt.zero_grad()
        pred = mlp(xb)
        loss = F.mse_loss(pred, yb)
        loss.backward()
        nn.utils.clip_grad_norm_(mlp.parameters(), 1.0)
        opt.step()

    rmse_val = val_rmse_z(mlp)
    if rmse_val + 1e-6 < best_rmse:
        best_rmse = rmse_val
        best_state = {k: v.detach().clone() for k, v in mlp.state_dict().items()}
        wait = 0
    else:
        wait += 1
        if wait > patience:
            break

if best_state is not None:
    mlp.load_state_dict(best_state)

# --- Predict on validation (z-space, consistent) ---
mlp.eval()
with torch.no_grad():
    preds_mlp_z = []
    for i in range(0, X_val_z.size(0), 512):
        preds_mlp_z.append(mlp(X_val_z[i:i+512]).cpu())
    y_pred_mlp_z = torch.cat(preds_mlp_z).view(-1).to(torch.float32)

y_true_z = y_val_z.detach().cpu().view(-1).to(torch.float32)
rmse_mlp_z = torch.sqrt(F.mse_loss(y_pred_mlp_z, y_true_z)).item()
print(f"MLP Baseline RMSE (z): {rmse_mlp_z:.4f}")

# --- Optional: convert to raw units if you saved train-split y scaler ---
if "y_mean_raw" in globals() and "y_std_raw" in globals():
    y_mean_t = torch.as_tensor(y_mean_raw, dtype=torch.float32)
    y_std_t  = torch.as_tensor(y_std_raw,  dtype=torch.float32).clamp_min(1e-6)

    y_pred_mlp_raw = y_pred_mlp_z * y_std_t + y_mean_t
    y_true_raw     = y_true_z     * y_std_t + y_mean_t

    rmse_mlp_raw = torch.sqrt(F.mse_loss(y_pred_mlp_raw, y_true_raw)).item()
    print(f"MLP Baseline RMSE (raw): {rmse_mlp_raw:.4f}")

    ovp_plot(y_true_raw, y_pred_mlp_raw, f"Observed vs Predicted — MLP (RMSE={rmse_mlp_raw:.3f})")
else:
    # Plot in z-space if raw scaler isn't available
    ovp_plot(y_true_z.cpu(), y_pred_mlp_z.cpu(), f"Observed vs Predicted — MLP (RMSEz={rmse_mlp_z:.3f})")
# Out:
# MLP Baseline RMSE (z): 0.4339
# MLP Baseline RMSE (raw): 0.4988

# %% [markdown]
# ## Extract MLP feature extractor

# %%
# # ===== Use pretrained MLP trunk as NN-kNN feature extractor =====
# import copy
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# class PretrainedMLPTrunkExtractor(nn.Module):
#     """
#     Standardize X using TRAIN stats, then run the pretrained MLP trunk (no last layer).
#     Output is the penultimate representation (embedding) used for NN-kNN distances.
#     """
#     def __init__(self, mlp_model: nn.Module, X_mean: torch.Tensor, X_std: torch.Tensor, remove_dropout: bool = True):
#         super().__init__()
#         # buffers so they move with .to(device) and get saved with the model
#         self.register_buffer("X_mean", X_mean.detach().clone())
#         self.register_buffer("X_std",  X_std.detach().clone())

#         # trunk = all layers except the last Linear->1
#         trunk = copy.deepcopy(mlp_model.net[:-1])

#         if remove_dropout:
#             trunk = nn.Sequential(*[
#                 nn.Identity() if isinstance(l, nn.Dropout) else l
#                 for l in trunk
#             ])

#         self.trunk = trunk

#         # optional: expose output dim
#         out_dim = None
#         for l in reversed(self.trunk):
#             if isinstance(l, nn.Linear):
#                 out_dim = l.out_features
#                 break
#         self.feature_dim = out_dim

#     def forward(self, x: torch.Tensor) -> torch.Tensor:
#         if x.dim() > 2:
#             x = x.view(x.size(0), -1)
#         x = (x - self.X_mean) / (self.X_std + 1e-8)
#         return self.trunk(x)

# # Build extractor from trained MLP (uses the SAME X_mean/X_std you computed in the MLP cell)
# mlp_extractor = PretrainedMLPTrunkExtractor(mlp, X_mean, X_std, remove_dropout=True).to(device)
# print("Extractor feature_dim:", mlp_extractor.feature_dim)

# # ---- NN-kNN config for this experiment (start simple + stable) ----
# import copy
# cfg_pt = copy.deepcopy(cfg)

# # IMPORTANT: don't stack another random post-MLP on top of the pretrained trunk
# cfg_pt["post_mlp_enabled"] = False

# # Start without NN-CDH and locality; add them back later once retrieval matches MLP
# cfg_pt["use_nn_cdh"] = False
# cfg_pt["nn_cdh_pretrain"] = False
# cfg_pt["regression_locality"] = False

# # Make retrieval as KNN-like as possible first
# cfg_pt["case_score_mode"] = "neg_distance"     # use pure distance ranking first
# cfg_pt["case_normalizer"] = "softmax"          # keep stable
# cfg_pt["tau"] = 1.0                            # sweep later: 0.3, 0.7, 1.0, 2.0

# # Since bias isn't used in neg_distance mode, turn off bias regularizer for this run
# cfg_pt["lambda_case_bias"] = 0.0

# # Feature-extractor LR will matter only after unfreezing; keep it small
# cfg_pt["feature_extractor_lr"] = 1e-5

# # Freeze schedule (requires tiny patch to train_model shown below)
# cfg_pt["freeze_feature_extractor_epochs"] = 500  # e.g., 200–800

# # Run training
# # use raw features since extractor does standardization internally
# best_acc, glocal_weightor, model = train_model(
#     X_train_raw, y_train,
#     X_val_raw,   y_val,
#     feature_extractor=mlp_extractor,
#     cfg=cfg_pt
# )

# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

model.eval()
with torch.no_grad():
    pre_preds, post_preds = [], []
    B = 512
    for i in range(0, X_val_raw.size(0), B):
        _, yhat, pre_adapt_yhat, *_ = model(X_val_raw[i:i+B].to(device))

        # normalize shape to [B]
        if pre_adapt_yhat.dim() == 3:
            pre_yhat = pre_adapt_yhat.sum(dim=1).squeeze(-1)
        elif pre_adapt_yhat.dim() == 2:
            pre_yhat = pre_adapt_yhat.squeeze(-1)
        else:
            pre_yhat = pre_adapt_yhat

        post_preds.append(yhat.detach().cpu().view(-1))
        pre_preds.append(pre_yhat.detach().cpu().view(-1))

    y_pred_post_z = torch.cat(post_preds, dim=0).to(torch.float32)
    y_pred_pre_z  = torch.cat(pre_preds,  dim=0).to(torch.float32)
    y_true_z      = y_val.detach().cpu().view(-1).to(torch.float32)  # assumes y_val is z-scored

# --- RMSE in z-space (always correct if y_val is z) ---
rmse_pre_z  = torch.sqrt(F.mse_loss(y_pred_pre_z,  y_true_z)).item()
rmse_post_z = torch.sqrt(F.mse_loss(y_pred_post_z, y_true_z)).item()
print(f"[Z] Pre-adaptation  RMSE: {rmse_pre_z:.4f}")
print(f"[Z] Post-adaptation RMSE: {rmse_post_z:.4f}")
print(f"[Z] ΔRMSE (pre - post):  {rmse_pre_z - rmse_post_z:.4f}")

# --- Optional: convert to raw units if you saved train-split scaler ---
if "y_mean_raw" in globals() and "y_std_raw" in globals():
    y_mean_t = torch.as_tensor(y_mean_raw, dtype=torch.float32)
    y_std_t  = torch.as_tensor(y_std_raw,  dtype=torch.float32).clamp_min(1e-6)

    y_true_raw      = y_true_z      * y_std_t + y_mean_t
    y_pred_pre_raw  = y_pred_pre_z  * y_std_t + y_mean_t
    y_pred_post_raw = y_pred_post_z * y_std_t + y_mean_t

    rmse_pre_raw  = torch.sqrt(F.mse_loss(y_pred_pre_raw,  y_true_raw)).item()
    rmse_post_raw = torch.sqrt(F.mse_loss(y_pred_post_raw, y_true_raw)).item()
    print(f"[RAW] Pre-adaptation  RMSE: {rmse_pre_raw:.4f}")
    print(f"[RAW] Post-adaptation RMSE: {rmse_post_raw:.4f}")

    # Plot in raw units
    def ovp_plot(y_t, y_p, title):
        plt.figure(figsize=(5,5))
        plt.scatter(y_t.numpy(), y_p.numpy(), s=8, alpha=0.7)
        mn = float(min(y_t.min().item(), y_p.min().item()))
        mx = float(max(y_t.max().item(), y_p.max().item()))
        plt.plot([mn, mx], [mn, mx], linestyle='--')
        plt.xlabel('True (raw)')
        plt.ylabel('Predicted (raw)')
        plt.title(title)
        plt.show()

    ovp_plot(y_true_raw.cpu(), y_pred_pre_raw.cpu(),  f"NN-kNN (pre-adapt) RMSE={rmse_pre_raw:.3f}")
    ovp_plot(y_true_raw.cpu(), y_pred_post_raw.cpu(), f"NN-kNN (post-adapt) RMSE={rmse_post_raw:.3f}")
else:
    print("Tip: define y_mean_raw/y_std_raw (train-split stats) if you want RMSE in raw units.")
# Out:
# [Z] Pre-adaptation  RMSE: 1.1916
# [Z] Post-adaptation RMSE: 7.8298
# [Z] ΔRMSE (pre - post):  -6.6382
# [RAW] Pre-adaptation  RMSE: 1.3698
# [RAW] Post-adaptation RMSE: 9.0013

# %% [markdown]
# ## MLP's most similar cases

# %%
# ---------------------------------------------------
# 2) Penultimate-layer features from your MLP
# ---------------------------------------------------
def mlp_penultimate_features(model, X_z, batch_size=512, device=device):
    """
    Compute penultimate-layer features for all samples in X_z using your MLPReg.

    X_z: standardized inputs (like X_train_z, X_val_z), shape [N, D]
    Returns: tensor of shape [N, H_penultimate]
    """
    model.eval()
    feats = []
    with torch.no_grad():
        for i in range(0, X_z.size(0), batch_size):
            xb = X_z[i:i+batch_size].to(device)
            # model.net is Sequential: [Linear, ReLU, Dropout, ..., Linear(->1)]
            # We take all but the last Linear to get the penultimate representation.
            hb = model.net[:-1](xb)            # [B, H_penultimate]
            feats.append(hb.cpu())
    return torch.cat(feats, dim=0)             # [N, H_penultimate]


# ---------------------------------------------------
# 3) Average ground-truth distance of MLP's top-k neighbors
# ---------------------------------------------------
def avg_true_distance_mlp(
    mlp_model,
    X_train_orig, X_train_z,
    X_query_orig, X_query_z,
    feature_weights,
    k=5,
    device=device,
    use_regime_weights=False,
    regime_labels_query=None,
):
    """
    Use MLP penultimate features for k-NN retrieval, but evaluate neighbor
    quality using ground-truth weighted distance in ORIGINAL feature space.

    X_train_orig:  [N_train, D]  original input space (not standardized)
    X_train_z:     [N_train, D]  standardized (what MLP was trained on)
    X_query_orig:  [N_query, D]  original input space
    X_query_z:     [N_query, D]  standardized

    feature_weights:
        [D]      single-regime ground-truth feature weights (old behavior)
        or
        [R, D]   multi-regime weights when use_regime_weights=True

    use_regime_weights:
        - False (default): behaves like the original version, ignores regimes.
        - True: feature_weights must be [R, D] and regime_labels_query must be provided.
    """
    X_train_orig   = X_train_orig.to(device)
    X_query_orig   = X_query_orig.to(device)
    feature_weights = feature_weights.to(device)

    # 1) Extract features in MLP representation space
    train_feats = mlp_penultimate_features(mlp_model, X_train_z, device=device).to(device)  # [N_train, H]
    query_feats = mlp_penultimate_features(mlp_model, X_query_z, device=device).to(device)  # [N_query, H]

    # Decide whether to use per-regime weights
    use_regime = False
    if use_regime_weights and feature_weights.dim() == 2:
        assert regime_labels_query is not None, \
            "regime_labels_query must be provided when use_regime_weights=True and feature_weights is [R,D]."
        regime_labels_query = regime_labels_query.to(device)
        assert regime_labels_query.shape[0] == X_query_orig.shape[0], \
            "regime_labels_query must have same length as X_query_orig."
        use_regime = True

    all_topk_means = []

    with torch.no_grad():
        for i in range(query_feats.size(0)):
            q_feat = query_feats[i]                     # [H]

            # --- k-NN in feature space (no need for sqrt, ranking is identical) ---
            diffs_feat = train_feats - q_feat.unsqueeze(0)   # [N_train, H]
            d_feat_sq  = (diffs_feat ** 2).sum(dim=-1)       # [N_train]
            topk_idx   = torch.topk(d_feat_sq, k=k, largest=False).indices  # [k]

            # --- Evaluate those neighbors in original space with true weights ---
            q_raw     = X_query_orig[i]               # [D]
            neigh_raw = X_train_orig[topk_idx]        # [k, D]

            if use_regime:
                regime_idx = int(regime_labels_query[i].item())
            else:
                regime_idx = None

            d_true = weighted_l2_distance(q_raw, neigh_raw, feature_weights, regime_idx=regime_idx)  # [k]
            all_topk_means.append(d_true.mean().item())

    return float(sum(all_topk_means) / len(all_topk_means))

# %%
k_eval = 5  # or whatever k you want for comparison

if regime_weights:
    mlp_avg_dist = avg_true_distance_mlp(
        mlp_model          = mlp,
        X_train_orig       = X_train,
        X_train_z          = X_train_z,
        X_query_orig       = X_val,
        X_query_z          = X_val_z,
        feature_weights    = true_feature_weights_glocal,  # [2, D]
        k                  = k_eval,
        device             = device,
        use_regime_weights = True,
        regime_labels_query= regime_labels_val             # [N_val], 0/1
    )
else:
    mlp_avg_dist = avg_true_distance_mlp(
        mlp_model          = mlp,
        X_train_orig       = X_train,
        X_train_z          = X_train_z,
        X_query_orig       = X_val,
        X_query_z          = X_val_z,
        feature_weights    = true_feature_weights,         # [D]
        k                  = k_eval,
        device             = device
    )

print(f"MLP — mean ground-truth distance of top-{k_eval} neighbors: {mlp_avg_dist:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 23
#       4     mlp_avg_dist = avg_true_distance_mlp(
#       5         mlp_model          = mlp,
#       6         X_train_orig       = X_train,
#    (...)     14         regime_labels_query= regime_labels_val             # [N_val], 0/1
#      15     )
#      16 else:
#      17     mlp_avg_dist = avg_true_distance_mlp(
#      18         mlp_model          = mlp,
#      19         X_train_orig       = X_train,
#      20         X_train_z          = X_train_z,
#      21         X_query_orig       = X_val,
#      22         X_query_z          = X_val_z,
# ---> 23         feature_weights    = true_feature_weights,         # [D]
#      24         k                  = k_eval,
#      25         device             = device
#      26     )
#      28 print(f"MLP — mean ground-truth distance of top-{k_eval} neighbors: {mlp_avg_dist:.4f}")
#
# NameError: name 'true_feature_weights' is not defined
