# %% [markdown]
# # DQN Atari Breakout Demo
#
# Thin demo surface for the repo-native DQN Atari workflow. The implementation lives in `model/rl_workflow.py`; this notebook configures a run, calls workflow functions, and inspects saved artifacts. Smoke and debug profiles validate plumbing only, not benchmark quality.

# %%
from pathlib import Path
import csv
import importlib
import json
import sys

import matplotlib.pyplot as plt


def find_repo_root(start=None):
    start = Path.cwd() if start is None else Path(start).resolve()
    for candidate in (start, *start.parents):
        if (candidate / "model").is_dir() and (candidate / "datasets").is_dir():
            return candidate
    raise RuntimeError("Could not find NN-kNN repo root from this notebook.")


ROOT = find_repo_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import model.rl_workflow as rl_workflow
rl_workflow = importlib.reload(rl_workflow)

evaluate_dqn = rl_workflow.evaluate_dqn
load_dqn_checkpoint = rl_workflow.load_dqn_checkpoint
make_dqn_config = rl_workflow.make_dqn_config
train_dqn = rl_workflow.train_dqn

ROOT
# Out:
# WindowsPath('c:/Users/ellio/OneDrive/Desktop/NN-kNN')

# %% [markdown]
# ## Configuration
#
# Atari requires Gymnasium Atari dependencies and accepted ROM license installation. Use `PROFILE = "smoke"` for a quick plumbing check, `"debug"` for an interactive development run, and reserve longer profiles for planned experiments.

# %%
TASK = "breakout"
PROFILE = "gold"  # use "debug" for an interactive run or "fast" for a longer exploratory run
SEED = 0
DEVICE = None  # use None for repo default, or set "cpu" / "cuda"

RUN_TRAINING = True  # set False to skip training and evaluate an existing checkpoint
CHECKPOINT_PATH = None  # set Path("results/rl/.../checkpoint.pt") to pin one run


def latest_dqn_checkpoint(task=TASK, profile=PROFILE, parent=Path("results/rl")):
    pattern = f"dqn_{task}_*/checkpoint.pt"
    checkpoints = sorted(parent.glob(pattern), key=lambda path: path.stat().st_mtime, reverse=True)
    for checkpoint_path in checkpoints:
        try:
            checkpoint = load_dqn_checkpoint(checkpoint_path, device=DEVICE)
        except Exception:
            continue
        config = checkpoint["config"]
        task_data = checkpoint["task"]
        if task_data.get("name") == task and config.profile == profile:
            return checkpoint_path
    return None


cfg = make_dqn_config(PROFILE, task_name=TASK, seed=SEED)
{
    "task": TASK,
    "profile": cfg.profile,
    "total_timesteps": cfg.total_timesteps,
    "eval_episodes": cfg.eval_episodes,
    "network_kind": cfg.network_kind,
    "run_training": RUN_TRAINING,
}
# Out:
# {'task': 'breakout',
#  'profile': 'gold',
#  'total_timesteps': 1000000,
#  'eval_episodes': 10,
#  'network_kind': 'cnn',
#  'run_training': True}

# %%
if RUN_TRAINING:
    state = train_dqn(TASK, cfg, device=DEVICE, progress=True)
    checkpoint_path = state["checkpoint_path"]
else:
    checkpoint_path = Path(CHECKPOINT_PATH) if CHECKPOINT_PATH is not None else latest_dqn_checkpoint()
    state = None
    if checkpoint_path is None:
        raise FileNotFoundError(
            f"No DQN checkpoint found for task={TASK!r} and profile={PROFILE!r}. "
            "Set RUN_TRAINING=True for a first smoke run, or set CHECKPOINT_PATH to an existing checkpoint."
        )

checkpoint_path
# Out:
# [dqn] step=123 episode=1 return=0.0 length=123 epsilon=1.000 loss=None
# [dqn] step=251 episode=2 return=0.0 length=128 epsilon=1.000 loss=None
# [dqn] step=426 episode=3 return=1.0 length=175 epsilon=0.999 loss=None
# [dqn] step=598 episode=4 return=1.0 length=172 epsilon=0.999 loss=None
# [dqn] step=865 episode=5 return=3.0 length=267 epsilon=0.998 loss=None
# [dqn] step=1888 episode=10 return=0.0 length=139 epsilon=0.996 loss=None
# [dqn] step=3730 episode=20 return=1.0 length=189 epsilon=0.993 loss=None
# [dqn] step=5410 episode=30 return=4.0 length=279 epsilon=0.990 loss=None
# [dqn] step=7291 episode=40 return=0.0 length=129 epsilon=0.986 loss=None
# [dqn] step=9002 episode=50 return=0.0 length=136 epsilon=0.983 loss=None
# [dqn] step=10781 episode=60 return=0.0 length=124 epsilon=0.980 loss=None
# [dqn] step=12344 episode=70 return=0.0 length=137 epsilon=0.977 loss=None
# [dqn] step=14318 episode=80 return=3.0 length=275 epsilon=0.973 loss=None
# [dqn] step=16032 episode=90 return=0.0 length=124 epsilon=0.970 loss=None
# [dqn] step=17541 episode=100 return=0.0 length=136 epsilon=0.967 loss=None
# [dqn] step=19305 episode=110 return=2.0 length=200 epsilon=0.963 loss=None
# [dqn] step=20865 episode=120 return=0.0 length=125 epsilon=0.960 loss=None
# [dqn] step=22345 episode=130 return=1.0 length=179 epsilon=0.958 loss=None
# [dqn] step=24591 episode=140 return=1.0 length=174 epsilon=0.953 loss=None
# [dqn] step=26165 episode=150 return=0.0 length=121 epsilon=0.950 loss=None
# [dqn] step=28114 episode=160 return=2.0 length=233 epsilon=0.947 loss=None
# [dqn] step=29795 episode=170 return=0.0 length=138 epsilon=0.943 loss=None
# [dqn] step=31636 episode=180 return=0.0 length=144 epsilon=0.940 loss=None
# [dqn] step=33596 episode=190 return=1.0 length=166 epsilon=0.936 loss=None
# [dqn] step=35286 episode=200 return=0.0 length=138 epsilon=0.933 loss=None
# [dqn] step=37202 episode=210 return=1.0 length=150 epsilon=0.929 loss=None
# [dqn] step=39160 episode=220 return=0.0 length=131 epsilon=0.926 loss=None
# [dqn] step=40937 episode=230 return=0.0 length=135 epsilon=0.922 loss=None
# [dqn] step=42812 episode=240 return=3.0 length=277 epsilon=0.919 loss=None
# [dqn] step=44488 episode=250 return=1.0 length=157 epsilon=0.915 loss=None
# [dqn] step=46612 episode=260 return=2.0 length=228 epsilon=0.911 loss=None
# [dqn] step=48406 episode=270 return=1.0 length=182 epsilon=0.908 loss=None
# [dqn][eval] step=50000 mean_return=0.00 max_return=0.00
# [dqn] step=50179 episode=280 return=2.0 length=212 epsilon=0.905 loss=2.256537482026033e-05
# [dqn] step=52230 episode=290 return=2.0 length=220 epsilon=0.901 loss=0.015655968338251114
# [dqn] step=53790 episode=300 return=1.0 length=166 epsilon=0.898 loss=2.025702633545734e-05
# [dqn] step=55719 episode=310 return=2.0 length=196 epsilon=0.894 loss=0.000306752510368824
# [dqn] step=57716 episode=320 return=0.0 length=125 epsilon=0.890 loss=0.0003121304325759411
# [dqn] step=59763 episode=330 return=6.0 length=396 epsilon=0.886 loss=2.793813109747134e-05
# [dqn] step=61545 episode=340 return=1.0 length=175 epsilon=0.883 loss=0.001137171289883554
# [dqn] step=63339 episode=350 return=0.0 length=124 epsilon=0.880 loss=0.0007881229394115508
# [dqn] step=65180 episode=360 return=2.0 length=234 epsilon=0.876 loss=0.001078376779332757
# [dqn] step=524495 episode=1960 return=16.0 length=824 epsilon=0.050 loss=0.007598568685352802
# [dqn] step=531622 episode=1970 return=11.0 length=536 epsilon=0.050 loss=0.07487499713897705
# [dqn] step=537958 episode=1980 return=15.0 length=589 epsilon=0.050 loss=0.014669178985059261
# [dqn] step=543506 episode=1990 return=9.0 length=408 epsilon=0.050 loss=0.002742334268987179
# [dqn][eval] step=550000 mean_return=10.00 max_return=14.00
# [dqn] step=550237 episode=2000 return=13.0 length=600 epsilon=0.050 loss=0.002792519982904196
# [dqn] step=556370 episode=2010 return=25.0 length=658 epsilon=0.050 loss=0.007538145408034325
# [dqn] step=562130 episode=2020 return=16.0 length=444 epsilon=0.050 loss=0.010751161724328995
# [dqn] step=569225 episode=2030 return=18.0 length=761 epsilon=0.050 loss=0.001259754179045558
# [dqn] step=576836 episode=2040 return=40.0 length=992 epsilon=0.050 loss=0.008158842101693153
# [dqn] step=584665 episode=2050 return=24.0 length=783 epsilon=0.050 loss=0.003254322800785303
# [dqn] step=592174 episode=2060 return=18.0 length=750 epsilon=0.050 loss=0.005838014185428619
# [dqn][eval] step=600000 mean_return=19.60 max_return=22.00
# [dqn] step=600395 episode=2070 return=33.0 length=1003 epsilon=0.050 loss=0.014394871890544891
# [dqn] step=608323 episode=2080 return=19.0 length=788 epsilon=0.050 loss=0.002732340944930911
# [dqn] step=616636 episode=2090 return=21.0 length=786 epsilon=0.050 loss=0.003158517414703965
# [dqn] step=623943 episode=2100 return=18.0 length=810 epsilon=0.050 loss=0.02391911670565605
# [dqn] step=633418 episode=2110 return=62.0 length=1371 epsilon=0.050 loss=0.062225982546806335
# [dqn] step=640698 episode=2120 return=16.0 length=535 epsilon=0.050 loss=0.0034838709980249405
# [dqn] step=649071 episode=2130 return=34.0 length=787 epsilon=0.050 loss=0.006893070414662361
# [dqn][eval] step=650000 mean_return=18.40 max_return=29.00
# [dqn] step=656844 episode=2140 return=51.0 length=1271 epsilon=0.050 loss=0.002162088407203555
# [dqn] step=665829 episode=2150 return=21.0 length=876 epsilon=0.050 loss=0.0027809706516563892
# [dqn] step=675323 episode=2160 return=25.0 length=654 epsilon=0.050 loss=0.007349774241447449
# [dqn] step=684495 episode=2170 return=35.0 length=1024 epsilon=0.050 loss=0.020367957651615143
# [dqn] step=693025 episode=2180 return=28.0 length=940 epsilon=0.050 loss=0.008803777396678925
# [dqn][eval] step=700000 mean_return=39.20 max_return=55.00
# [dqn] step=701101 episode=2190 return=16.0 length=521 epsilon=0.050 loss=0.0022355138789862394
# [dqn] step=708675 episode=2200 return=26.0 length=861 epsilon=0.050 loss=0.004401667974889278
# [dqn] step=718170 episode=2210 return=40.0 length=884 epsilon=0.050 loss=0.007831809110939503
# [dqn] step=724998 episode=2220 return=15.0 length=666 epsilon=0.050 loss=0.003128448501229286
# [dqn] step=733734 episode=2230 return=36.0 length=1108 epsilon=0.050 loss=0.011089980602264404
# [dqn] step=741092 episode=2240 return=8.0 length=383 epsilon=0.050 loss=0.004797930829226971
# [dqn] step=749741 episode=2250 return=36.0 length=1102 epsilon=0.050 loss=0.026001092046499252
# [dqn][eval] step=750000 mean_return=19.20 max_return=29.00
# [dqn] step=757243 episode=2260 return=16.0 length=723 epsilon=0.050 loss=0.004301934037357569
# [dqn] step=764675 episode=2270 return=44.0 length=782 epsilon=0.050 loss=0.019692255184054375
# [dqn] step=771646 episode=2280 return=15.0 length=640 epsilon=0.050 loss=0.07627314329147339
# [dqn] step=778070 episode=2290 return=9.0 length=447 epsilon=0.050 loss=0.00915917381644249
# [dqn] step=785679 episode=2300 return=40.0 length=977 epsilon=0.050 loss=0.11321698129177094
# [dqn] step=793430 episode=2310 return=32.0 length=839 epsilon=0.050 loss=0.013630911707878113
# [dqn] step=799862 episode=2320 return=29.0 length=779 epsilon=0.050 loss=0.021290231496095657
# [dqn][eval] step=800000 mean_return=11.40 max_return=17.00
# [dqn] step=804899 episode=2330 return=11.0 length=525 epsilon=0.050 loss=0.005599154159426689
# [dqn] step=810345 episode=2340 return=11.0 length=780 epsilon=0.050 loss=0.008543108589947224
# [dqn] step=816544 episode=2350 return=17.0 length=581 epsilon=0.050 loss=0.008188912644982338
# [dqn] step=822328 episode=2360 return=18.0 length=624 epsilon=0.050 loss=0.030957192182540894
# [dqn] step=829385 episode=2370 return=12.0 length=512 epsilon=0.050 loss=0.008425162173807621
# [dqn] step=836752 episode=2380 return=14.0 length=667 epsilon=0.050 loss=0.0058524832129478455
# [dqn] step=844442 episode=2390 return=22.0 length=886 epsilon=0.050 loss=0.010273508727550507
# [dqn][eval] step=850000 mean_return=14.80 max_return=28.00
# [dqn] step=850765 episode=2400 return=22.0 length=853 epsilon=0.050 loss=0.01290293037891388
# [dqn] step=857967 episode=2410 return=29.0 length=676 epsilon=0.050 loss=0.004833578132092953
# [dqn] step=864512 episode=2420 return=16.0 length=727 epsilon=0.050 loss=0.004555471707135439
# [dqn] step=871605 episode=2430 return=32.0 length=1096 epsilon=0.050 loss=0.00834735855460167
# [dqn] step=878665 episode=2440 return=17.0 length=667 epsilon=0.050 loss=0.01124077569693327
# [dqn] step=886124 episode=2450 return=13.0 length=648 epsilon=0.050 loss=0.006985675543546677
# [dqn] step=893898 episode=2460 return=18.0 length=747 epsilon=0.050 loss=0.002718742471188307
# [dqn][eval] step=900000 mean_return=14.00 max_return=20.00
# [dqn] step=900636 episode=2470 return=15.0 length=598 epsilon=0.050 loss=0.007881436496973038
# [dqn] step=907486 episode=2480 return=18.0 length=599 epsilon=0.050 loss=0.010725073516368866
# [dqn] step=914168 episode=2490 return=16.0 length=565 epsilon=0.050 loss=0.004484259523451328
# [dqn] step=921928 episode=2500 return=21.0 length=629 epsilon=0.050 loss=0.03262341395020485
# [dqn] step=929969 episode=2510 return=32.0 length=798 epsilon=0.050 loss=0.00707635935395956
# [dqn] step=938277 episode=2520 return=14.0 length=650 epsilon=0.050 loss=0.004213287029415369
# [dqn] step=945929 episode=2530 return=16.0 length=654 epsilon=0.050 loss=0.006424013525247574
# [dqn][eval] step=950000 mean_return=19.40 max_return=35.00
# [dqn] step=953958 episode=2540 return=21.0 length=572 epsilon=0.050 loss=0.1182652935385704
# [dqn] step=960941 episode=2550 return=32.0 length=843 epsilon=0.050 loss=0.04178238287568092
# [dqn] step=968978 episode=2560 return=26.0 length=802 epsilon=0.050 loss=0.011851061135530472
# [dqn] step=976585 episode=2570 return=22.0 length=634 epsilon=0.050 loss=0.004910661838948727
# [dqn] step=984372 episode=2580 return=31.0 length=999 epsilon=0.050 loss=0.009283158928155899
# [dqn] step=992157 episode=2590 return=22.0 length=640 epsilon=0.050 loss=0.0018614873988553882
# [dqn] step=998927 episode=2600 return=37.0 length=711 epsilon=0.050 loss=0.03593512251973152
# [dqn] finished profile=gold mean_eval_return=39.20 passed=True run_dir=results\rl\dqn_breakout_20260708_145549_959629
# WindowsPath('results/rl/dqn_breakout_20260708_145549_959629/checkpoint.pt')

# %%
loaded = load_dqn_checkpoint(checkpoint_path, device=DEVICE)
summary_path = checkpoint_path.parent / "summary.json"
summary = json.loads(summary_path.read_text(encoding="utf-8")) if summary_path.exists() else {}
{
    "checkpoint": str(checkpoint_path),
    "task": loaded["task"].get("name"),
    "env_id": loaded["task"].get("env_id"),
    "profile": loaded["config"].profile,
    "network_kind": loaded["config"].network_kind,
    "final_eval": summary.get("final_eval"),
    "training_efficiency": summary.get("training_efficiency"),
}
# Out:
# {'checkpoint': 'results\\rl\\dqn_breakout_20260708_145549_959629\\checkpoint.pt',
#  'task': 'breakout',
#  'env_id': 'ALE/Breakout-v5',
#  'profile': 'gold',
#  'network_kind': 'cnn',
#  'final_eval': {'episodes': 10,
#   'seed': 10000,
#   'mean_return': 39.20000076293945,
#   'std_return': 8.863408088684082,
#   'min_return': 32.0,
#   'max_return': 55.0,
#   'mean_length': 1064.5999755859375},
#  'training_efficiency': {'best_model_step': 700000,
#   'best_model_training_fraction': 0.7,
#   'first_success_step': None,
#   'first_success_training_fraction': None,
#   'best_minus_last_return': 10.80000114440918,
#   'budget_interpretation': 'regressed_after_best'}}

# %%
def read_csv_rows(path):
    if not path.exists() or path.stat().st_size == 0:
        return []
    with path.open(newline="", encoding="utf-8") as handle:
        return list(csv.DictReader(handle))

training_rows = read_csv_rows(checkpoint_path.parent / "training_metrics.csv")
eval_rows = read_csv_rows(checkpoint_path.parent / "eval_metrics.csv")
len(training_rows), len(eval_rows)
# Out:
# (2601, 19)

# %%
if training_rows:
    steps = [int(row["global_step"]) for row in training_rows]
    returns = [float(row["episode_return"]) for row in training_rows]
    plt.figure(figsize=(8, 3))
    plt.plot(steps, returns, linewidth=1)
    plt.xlabel("environment steps")
    plt.ylabel("episode return")
    plt.title(f"DQN {TASK} training returns")
    plt.show()

if eval_rows:
    eval_steps = [int(row["global_step"]) for row in eval_rows]
    mean_returns = [float(row["mean_return"]) for row in eval_rows]
    plt.figure(figsize=(8, 3))
    plt.plot(eval_steps, mean_returns, marker="o")
    plt.xlabel("environment steps")
    plt.ylabel("mean eval return")
    plt.title(f"DQN {TASK} eval returns")
    plt.show()

# %%
metrics = evaluate_dqn(
    TASK,
    loaded["model"],
    episodes=loaded["config"].eval_episodes,
    seed=loaded["config"].eval_seed,
    device=loaded["device"],
)
{k: v for k, v in metrics.items() if k != "episode_metrics"}
# Out:
# {'episodes': 10,
#  'seed': 10000,
#  'mean_return': 39.20000076293945,
#  'std_return': 8.863408088684082,
#  'min_return': 32.0,
#  'max_return': 55.0,
#  'mean_length': 1064.5999755859375}
